# %%
from glob import glob
from shutil import copyfile

# %%
msk_src_dir = '/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/SAFE_true_raw/'
msk_output_dir = '/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/MSK/'
scl_src_dir = '/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/SAFE_false_raw/'
scl_output_dir = '/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/SCL/'

# %%
Mask_list = glob(msk_src_dir + "*/*/MSK_CLDPRB_20m.jp2",recursive=True)
SCL_list = glob(scl_src_dir + "*/R20m/*SCL.jp2",recursive=True)

# %%
for msk in Mask_list:
    filename = msk.split("/")[-3] + "_" + msk.split("/")[-1]
    outpath = msk_output_dir + filename
    print(outpath)
#     copyfile(msk,outpath)
# Out:
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/MSK/L2A_T34MBC_A027031_20200825T092011_MSK_CLDPRB_20m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/MSK/L2A_T34NEF_A026945_20200819T084315_MSK_CLDPRB_20m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/MSK/L2A_T34NEF_A017965_20200814T085123_MSK_CLDPRB_20m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/MSK/L2A_T34MBB_A026845_20200812T090428_MSK_CLDPRB_20m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/MSK/L2A_T34MCB_A026845_20200812T090428_MSK_CLDPRB_20m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/MSK/L2A_T34MBC_A026845_20200812T090428_MSK_CLDPRB_20m.jp2
# ...

# %%
len(SCL_list)
# Out:
# 210

# %%
for scl in SCL_list:
    filename = scl.split("/")[-3].split(",")[0] + "_" + "".join(scl.split("/")[-3].split(",")[1].split("-")) + "_" + scl.split("/")[-1]
    outpath = scl_output_dir + filename
    copyfile(scl,outpath)
