# %%
import pandas as pd
import landsatxplore.api
from landsatxplore.earthexplorer import EarthExplorer
import pickle
from env_vars import *

# %%
# load PKL file instead

# df = pd.read_csv("./data/dataset_index.csv")

# %%
# PLK file created 

# pickle.dump( df, open( "landsat_index.pkl", "wb" ) )

# %%
df.dtypes
# Out:
# SCENE_ID                object
# PRODUCT_ID              object
# SPACECRAFT_ID           object
# SENSOR_ID               object
# DATE_ACQUIRED           object
# COLLECTION_NUMBER       object
# COLLECTION_CATEGORY     object
# SENSING_TIME            object
# DATA_TYPE               object
# WRS_PATH                 int64
# WRS_ROW                  int64
# CLOUD_COVER            float64
# NORTH_LAT              float64
# SOUTH_LAT              float64
# WEST_LON               float64
# EAST_LON               float64
# TOTAL_SIZE               int64
# BASE_URL                object
# dtype: object

# %%
df2 = df[(df["CLOUD_COVER"] < 11)]

# %%
df2["DATE_ACQUIRED"] = pd.to_datetime(df2["DATE_ACQUIRED"])
# Out:
# /Users/purgatorid/.local/share/virtualenvs/data_collection-Bxb0R3Gi/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.dtypes
# Out:
# SCENE_ID                       object
# PRODUCT_ID                     object
# SPACECRAFT_ID                  object
# SENSOR_ID                      object
# DATE_ACQUIRED          datetime64[ns]
# COLLECTION_NUMBER              object
# COLLECTION_CATEGORY            object
# SENSING_TIME                   object
# DATA_TYPE                      object
# WRS_PATH                        int64
# WRS_ROW                         int64
# CLOUD_COVER                   float64
# NORTH_LAT                     float64
# SOUTH_LAT                     float64
# WEST_LON                      float64
# EAST_LON                      float64
# TOTAL_SIZE                      int64
# BASE_URL                       object
# dtype: object

# %%
df2.head()
# Out:
#                  SCENE_ID                                PRODUCT_ID  \
# 3   LT52210712004218COA00                                       NaN
# 4   LE71380272017208EDC00  LE07_L1TP_138027_20170727_20170822_01_T1
# 5   LT51770752004214JSA00  LT05_L1TP_177075_20040801_20161130_01_T1
# 8   LT51380321995108BJC01  LT05_L1TP_138032_19950418_20170109_01_T1
# 13  LM50530121990090PAC00                                       NaN
#
#    SPACECRAFT_ID SENSOR_ID DATE_ACQUIRED COLLECTION_NUMBER  \
# 3      LANDSAT_5        TM    2004-08-05               PRE
# 4      LANDSAT_7       ETM    2017-07-27                01
# 5      LANDSAT_5        TM    2004-08-01                01
# 8      LANDSAT_5        TM    1995-04-18                01
# 13     LANDSAT_5       MSS    1990-03-31               PRE
#
#    COLLECTION_CATEGORY                  SENSING_TIME DATA_TYPE  WRS_PATH  \
# 3                  NaN  2004-08-05T12:57:29.4870250Z       L1T       221
# ...

# %%
df2.dtypes
# Out:
# SCENE_ID                       object
# PRODUCT_ID                     object
# SPACECRAFT_ID                  object
# SENSOR_ID                      object
# DATE_ACQUIRED          datetime64[ns]
# COLLECTION_NUMBER              object
# COLLECTION_CATEGORY            object
# SENSING_TIME                   object
# DATA_TYPE                      object
# WRS_PATH                        int64
# WRS_ROW                         int64
# CLOUD_COVER                   float64
# NORTH_LAT                     float64
# SOUTH_LAT                     float64
# WEST_LON                      float64
# EAST_LON                      float64
# TOTAL_SIZE                      int64
# BASE_URL                       object
# dtype: object

# %%
def pd_time_filter(df,year):
    return df2
[
        (df2["DATE_ACQUIRED"] 
         > (year + "-01-01")) 
        & (df2["DATE_ACQUIRED"]    
           < (year + "-12-31"))
        & (df2["NORTH_LAT"] <= -20)
    

              
    ]
    
pd_time_filter(df2,"2018").shape
# Out:
# (6099195, 18)

# %%
df2[(df2["NORTH_LAT"] <= -4)]
# Out:
#                        SCENE_ID                                PRODUCT_ID  \
# 3         LT52210712004218COA00                                       NaN
# 5         LT51770752004214JSA00  LT05_L1TP_177075_20040801_20161130_01_T1
# 16        LC81201092019064LGN00  LC08_L1GT_120109_20190305_20190305_01_RT
# 28        LC81301242017048LGN00  LC08_L1GT_130124_20170217_20170228_01_T2
# 43        LT51020812005203ASA01                                       NaN
# ...                         ...                                       ...
# 15905109  LE70050652008228EDC00  LE07_L1TP_005065_20080815_20161225_01_T1
# 15905140  LE72240842014290CUB00  LE07_L1TP_224084_20141017_20161101_01_T1
# 15905144  LE72190662013284CUB00                                       NaN
# 15905146  LM50910731987044ASA01                                       NaN
# 15905152  LC80661122016077LGN01  LC08_L1GT_066112_20160317_20170328_01_T2
#
#          SPACECRAFT_ID SENSOR_ID DATE_ACQUIRED COLLECTION_NUMBER  \
# ...

# %%
api = landsatxplore.api.API(username, password)

# %%
api.key
# Out:
# 'b4eb4866c2f54792adb542956e8e4b88'

# %%
dir(api)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'endpoint',
#  'key',
#  'login',
#  'logout',
#  'lookup',
#  'metadata',
#  'request',
#  'search',
#  'version']

# %%
scenes = api.search(
    dataset="LANDSAT_8",
    latitude=-6.0563692,
    longitude=21.3259403,
    start_date='2015-01-01',
    end_date='2016-01-01',
    max_cloud_cover=10)
# Out:
# ---------------------------------------------------------------------------
# EarthExplorerError                        Traceback (most recent call last)
# <ipython-input-12-bdfd7f528f1c> in <module>
#       5     start_date='2015-01-01',
#       6     end_date='2016-01-01',
# ----> 7     max_cloud_cover=10)
#
# ~/.local/share/virtualenvs/data_collection-Bxb0R3Gi/lib/python3.7/site-packages/landsatxplore/api.py in search(self, dataset, latitude, longitude, bbox, max_cloud_cover, start_date, end_date, months, max_results)
#     111             params.update(months=months)
#     112
# --> 113         response = self.request('search', **params)
#     114         return response['results']
#     115
#
# ~/.local/share/virtualenvs/data_collection-Bxb0R3Gi/lib/python3.7/site-packages/landsatxplore/api.py in request(self, request_code, **kwargs)
#      39         response = requests.get(url, params=params).json()
#      40         if response['error']:
# ...

# %%
scenes

# %%
print('{} scenes found.'.format(len(scenes)))
# Out:
# 7 scenes found.

# %%
test_scene_id = scenes[0]['entityId']

# %%
ee = EarthExplorer(username, password)

ee.download(scene_id=test_scene_id, output_dir='./data')
# Out:
# 833MB [15:36, 933kB/s]
# './data/LC08_L1TP_178064_20150212_20170413_01_T1.tar.gz'
