# %%
# Sentinel Hub Config

from env_vars import sentinel_hub_instance_id
from sentinelhub import SHConfig

# Import Area of Interest List

import pandas as pd
import json
from scripts.mgrs import encode,LLtoUTM


# Sentinel Hub Tile Look Up / Download

from sentinelhub import WebFeatureService, BBox, CRS, DataSource, AwsTileRequest


# Cloud Masking

import rasterio as rio
import numpy as np
import earthpy.mask as em

# Generate Product Detail DataFrame

import os
from glob import glob
import xml.etree.ElementTree as ET


# Sort / Organize Tiles by Individual Folders

from shutil import copyfile

# Reproject Masked Files 

import gdal
from glob import glob

# Create Master Raster


# Extract Polygon crops from products

import pandas as pd
from shapely.geometry import Polygon
import geopandas as gpd
from geopandas import GeoDataFrame
import earthpy.spatial as es
import traceback

# TIF to JPG

from PIL import Image

# %%
gdal.UseExceptions()

# %%
def add_trailing_slash(path):
    if path[-1] != '/':
        path += '/'
    return path

# %%
def create_dir(output_dir):
    # If the output folder doesn't exist, create it
    if not os.path.isdir(output_dir):
        os.mkdir(output_dir)

# %%
def shub_connect(sentinel_hub_instance_id):

    INSTANCE_ID = sentinel_hub_instance_id  

    if INSTANCE_ID:
        config = SHConfig()
        config.instance_id = INSTANCE_ID
    else:
        config = None
        
    return config

# %%
config = shub_connect(sentinel_hub_instance_id)

# %%
def import_aois(csv_loc):    

    df_labels = pd.read_csv(csv_loc)
    df_labels = df_labels[["center-lat","center-long","polygon","Labels combined"]]

    polygons = []
    for polygon in df_labels["polygon"]:
        polygons.append(json.loads(polygon)["coordinates"])


    tiles = []
    tiles_dic = {}
    polygon_id = 0 
    coordinates = []
    for items in polygons:
        polygon_id += 1 
        for item in items:
            for lon_lat in item:
                coordinates.append(lon_lat)
                tile = encode(LLtoUTM(lon_lat[1],lon_lat[0]),1)[:-2]
                

                if polygon_id in tiles_dic:

                    tiles_dic[polygon_id].append(tile)

                else:

                    tiles_dic[polygon_id] = [tile]

                tiles.append(tile)

            tiles_dic[polygon_id] = list(set(tiles_dic[polygon_id]))

    tiles = list(set(tiles))

    df_labels["tiles"] = tiles_dic.values()

    #bounding box

    min_lon = min([i[0] for i in coordinates])
    min_lat = min([i[1] for i in coordinates])
    max_lon = max([i[0] for i in coordinates])
    max_lat = max([i[1] for i in coordinates])

    bounding_box = min_lon,min_lat,max_lon,max_lat
    
    return df_labels,bounding_box,tiles

# %%
df,bounding_box,tile_list = import_aois("/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/Polygon_List/polygons_100720.csv")
# Out:
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
bounding_box
# Out:
# (8.42823, -3.373256, 25.688438, 5.845887)

# %%
len(tile_list)
# Out:
# 63

# %%
def shub_lookup_tiles(bounding_box,tile_list,search_time_interval = ('2019-01-01T00:00:00', '2020-12-31T23:59:59'),
                   product_type = DataSource.SENTINEL2_L2A):
    
    #Misha's Tiles of Interest
    search_bbox = BBox(bbox=bounding_box, crs=CRS.WGS84)

    search_time_interval = ('2019-01-01T00:00:00', '2020-12-31T23:59:59')
    wfs_iterator = WebFeatureService(
        search_bbox,
        search_time_interval,
        data_source=product_type,
        maxcc=.05,
        config=config
    )
    results = wfs_iterator.get_tiles()
    df = pd.DataFrame(results, columns=['Tilename','Date','AmazonID'])
    df_tiles_of_interest = df[df["Tilename"].isin(tile_list)]
    df2 = df_tiles_of_interest.groupby('Tilename').head(10)
    output2 = list(df2.itertuples(index=False,name=None))
    return output2

# %%
results_list = shub_lookup_tiles(bounding_box,tile_list,search_time_interval = ('2019-01-01T00:00:00', '2020-12-31T23:59:59'),
                   product_type = DataSource.SENTINEL2_L2A)

# %%
for tup_l in results_list:
    if tup_l[0] == "35NLB":
        print(tup_l)
# Out:
# ('35NLB', '2020-6-2', 0)
# ('35NLB', '2020-5-28', 0)
# ('35NLB', '2020-2-8', 0)
# ('35NLB', '2020-2-3', 0)
# ('35NLB', '2020-1-14', 0)
# ('35NLB', '2019-12-30', 0)
# ('35NLB', '2019-12-5', 0)
# ('35NLB', '2019-2-18', 0)
# ('35NLB', '2019-2-13', 0)
# ('35NLB', '2019-1-9', 0)

# %%
output_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw"

# downloaded_tiles = glob(f'{output_dir}/*')

downloaded = []
for direc in glob(f'{output_dir}/*'):
    downloaded_tile = direc.split("/")[-1].split("_")[1][1:]
    downloaded.append(downloaded_tile)

not_downloaded = []    
for tup_l in results_list:
    if tup_l[0] not in downloaded:
        not_downloaded.append(tup_l)
        
print("downloaded:",len(downloaded), "\n","not downloaded:",len(not_downloaded) )
# Out:
# downloaded: 462
#  not downloaded: 26

# %%
not_downloaded
# Out:
# [('34MCE', '2020-7-8', 0),
#  ('34MCE', '2020-6-18', 0),
#  ('34MCE', '2020-6-13', 0),
#  ('34MCE', '2020-6-3', 0),
#  ('35NLB', '2020-6-2', 0),
#  ('35NLB', '2020-5-28', 0),
#  ('34MCE', '2020-5-4', 0),
#  ('34MCE', '2020-4-29', 0),
#  ('34MCE', '2020-4-24', 0),
#  ('34MCE', '2020-4-24', 1),
#  ('32NQH', '2020-4-18', 0),
#  ('34MCE', '2020-4-14', 0),
#  ('34MCE', '2020-2-29', 0),
#  ('35NLB', '2020-2-8', 0),
#  ('35NLB', '2020-2-3', 0),
#  ('35NLB', '2020-1-14', 0),
#  ('32NQH', '2020-1-12', 0),
#  ('32NQH', '2020-1-4', 0),
#  ('35NLB', '2019-12-30', 0),
#  ('35NLB', '2019-12-5', 0),
#  ('32NQH', '2019-4-12', 0),
#  ('32NQH', '2019-4-9', 0),
#  ('35NLB', '2019-2-18', 0),
#  ('35NLB', '2019-2-13', 0),
#  ('32NQH', '2019-1-19', 0),
#  ('35NLB', '2019-1-9', 0)]

# %%
def shub_download_tiles(results_list,output_dir,bands=["R10m/TCI"],product_type = DataSource.SENTINEL2_L2A):
    
    #Additional Params
    bands = bands
    
    output_dir = add_trailing_slash(output_dir)
    create_dir(output_dir)
    
    
    for tile in results_list:
        tile_name, time, aws_index = tile

        #Download SAFE Files
        request = AwsTileRequest(
            tile=tile_name,
            time=time,
            bands = bands, 
            aws_index=aws_index,
            data_folder=output_dir,
            data_source=product_type,
            safe_format = True
        )

        request.save_data(redownload=True)

# %%
output_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw_v2"

shub_download_tiles(not_downloaded,output_dir,bands=["R10m/TCI"],product_type = DataSource.SENTINEL2_L2A)
# Out:
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)

# %%
def cloud_mask_tci(prod_dir):
    
    '''
    
    prod refers product directory 
    
    '''
    
    prod_dir = add_trailing_slash(prod_dir)
    
    msk_file_path = glob(prod_dir + "*/MSK_CLDPRB_20m.jp2")[0]
    tci_file_path = glob(prod_dir + "IMG_DATA/R10m/*.jp2")[0]
    tci_filename = tci_file_path.split("/")[-1]
    output_tci_file_path = prod_dir + "/IMG_DATA/R10m/" + "processed_2_" + tci_filename 

    nodatavalue = int(0)

    with rio.open(tci_file_path) as sen_TCI_src:
        sen_TCI = sen_TCI_src.read(masked=True)
        sen_TCI_meta = sen_TCI_src.meta

    with rio.open(msk_file_path) as sen_mask_src:
        sen_mask_pre = sen_mask_src.read(1)
        sen_mask = np.repeat(np.repeat(sen_mask_pre,2,axis=0),2,axis=1)

    # All pixels above 0 probability will be classified as True

    sen_mask_qa = sen_mask > 1


    # Apply mask to source TCI file
    if np.count_nonzero(sen_mask_qa) > 0:
        sen_TCI_cl_free_nan = em.mask_pixels(sen_TCI, sen_mask_qa)
        sen_TCI_cl_free_processed = np.ma.filled(sen_TCI_cl_free_nan, fill_value=nodatavalue)
        
    else:
        sen_TCI_cl_free_processed = sen_TCI
    
    # If file shape only has one band (dimension), generate correct shape for export
    
    if len(sen_TCI_cl_free_processed.shape) < 3:
        sen_TCI_cl_free_processed = np.array((sen_TCI_cl_free_processed,sen_TCI_cl_free_processed,sen_TCI_cl_free_processed))
        sen_TCI_cl_free_processed = sen_TCI_cl_free_processed.astype(np.uint8)

    # Export cloud-masked TCI file
    with rio.open(output_tci_file_path, 'w',**sen_TCI_meta) as outf:
        print(f"creating {output_tci_file_path}")
        outf.write(sen_TCI_cl_free_processed)

# %%
def apply_mask_tci_safe_list(products_dir):
    '''
    
    products_dir refers to parent directory containing multiple products
    
    
    '''
    
    products_dir = add_trailing_slash(products_dir)
    
    dir_list = glob(products_dir + "/*/" )
    
    
    for directory in dir_list:
        print(f'Processing {dir_list.index(directory) + 1} of {len(dir_list)}')
        cloud_mask_tci(directory)
        
    print(f"Applied masks to {len(dir_list)} products")

# %%
tci_folder_list = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw"
apply_mask_tci_safe_list(tci_folder_list)
# Out:
# Processing 1 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXB_A027603_20201004T091931//IMG_DATA/R10m/processed_2_T33NXB_20201004T085831_TCI_10m.jp2
# Processing 2 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYB_A027603_20201004T091931//IMG_DATA/R10m/processed_2_T33NYB_20201004T085831_TCI_10m.jp2
# Processing 3 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NCH_A027603_20201004T091931//IMG_DATA/R10m/processed_2_T34NCH_20201004T085831_TCI_10m.jp2
# Processing 4 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NZD_A027603_20201004T091931//IMG_DATA/R10m/processed_2_T33NZD_20201004T085831_TCI_10m.jp2
# Processing 5 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NZD_A027603_20201004T090335//IMG_DATA/R10m/processed_2_T33NZD_20201004T085831_TCI_10m.jp2
# Processing 6 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MVV_A018666_20201002T092142//IMG_DATA/R10m/processed_2_T33MVV_20201002T090719_TCI_10m.jp2
# Processing 7 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWC_A018666_20201002T092142//IMG_DATA/R10m/processed_2_T33NWC_20201002T090719_TCI_10m.jp2
# Processing 8 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NDH_A027560_20201001T085947//IMG_DATA/R10m/processed_2_T34NDH_20201001T084801_TCI_10m.jp2
# Processing 9 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYC_A027503_20200927T092758//IMG_DATA/R10m/processed_2_T33NYC_20200927T090731_TCI_10m.jp2
# Processing 10 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBB_A018580_20200926T090258//IMG_DATA/R10m/processed_2_T34MBB_20200926T084719_TCI_10m.jp2
# Processing 11 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NCH_A018580_20200926T090258//IMG_DATA/R10m/processed_2_T34NCH_20200926T084719_TCI_10m.jp2
# Processing 12 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYC_A018523_20200922T091949//IMG_DATA/R10m/processed_2_T33NYC_20200922T090659_TCI_10m.jp2
# Processing 13 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWE_A018523_20200922T091949//IMG_DATA/R10m/processed_2_T33NWE_20200922T090659_TCI_10m.jp2
# Processing 14 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVF_A018523_20200922T091949//IMG_DATA/R10m/processed_2_T33NVF_20200922T090659_TCI_10m.jp2
# Processing 15 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYB_A018337_20200909T091030//IMG_DATA/R10m/processed_2_T33NYB_20200909T085559_TCI_10m.jp2
# Processing 16 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MZT_A018294_20200906T090201//IMG_DATA/R10m/processed_2_T33MZT_20200906T084559_TCI_10m.jp2
# Processing 17 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEF_A018294_20200906T090201//IMG_DATA/R10m/processed_2_T34NEF_20200906T084559_TCI_10m.jp2
# Processing 18 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MZT_A027174_20200904T090335//IMG_DATA/R10m/processed_2_T33MZT_20200904T085601_TCI_10m.jp2
# Processing 19 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A027174_20200904T090335//IMG_DATA/R10m/processed_2_T34MBC_20200904T085601_TCI_10m.jp2
# Processing 20 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXB_A027174_20200904T090335//IMG_DATA/R10m/processed_2_T33NXB_20200904T085601_TCI_10m.jp2
# Processing 21 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYB_A027174_20200904T090335//IMG_DATA/R10m/processed_2_T33NYB_20200904T085601_TCI_10m.jp2
# Processing 22 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXC_A027174_20200904T090335//IMG_DATA/R10m/processed_2_T33NXC_20200904T085601_TCI_10m.jp2
# Processing 23 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYC_A027174_20200904T090335//IMG_DATA/R10m/processed_2_T33NYC_20200904T085601_TCI_10m.jp2
# Processing 24 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NCH_A027174_20200904T090335//IMG_DATA/R10m/processed_2_T34NCH_20200904T085601_TCI_10m.jp2
# Processing 25 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEH_A018251_20200903T085912//IMG_DATA/R10m/processed_2_T34NEH_20200903T083609_TCI_10m.jp2
# Processing 26 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A018194_20200830T091400//IMG_DATA/R10m/processed_2_T34MBC_20200830T085559_TCI_10m.jp2
# Processing 27 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A027031_20200825T092011//IMG_DATA/R10m/processed_2_T34MBC_20200825T085601_TCI_10m.jp2
# Processing 28 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEF_A026945_20200819T084315//IMG_DATA/R10m/processed_2_T34NEF_20200819T083611_TCI_10m.jp2
# Processing 29 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NCH_A018008_20200817T090516//IMG_DATA/R10m/processed_2_T34NCH_20200817T084559_TCI_10m.jp2
# Processing 30 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEF_A017965_20200814T085123//IMG_DATA/R10m/processed_2_T34NEF_20200814T083609_TCI_10m.jp2
# Processing 31 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBB_A026845_20200812T090428//IMG_DATA/R10m/processed_2_T34MBB_20200812T084601_TCI_10m.jp2
# Processing 32 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MCB_A026845_20200812T090428//IMG_DATA/R10m/processed_2_T34MCB_20200812T084601_TCI_10m.jp2
# Processing 33 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MZT_A026845_20200812T090428//IMG_DATA/R10m/processed_2_T33MZT_20200812T084601_TCI_10m.jp2
# Processing 34 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A026845_20200812T090428//IMG_DATA/R10m/processed_2_T34MBC_20200812T084601_TCI_10m.jp2
# Processing 35 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A017908_20200810T091451//IMG_DATA/R10m/processed_2_T34MBC_20200810T085559_TCI_10m.jp2
# Processing 36 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXB_A017908_20200810T091451//IMG_DATA/R10m/processed_2_T33NXB_20200810T085559_TCI_10m.jp2
# Processing 37 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MVV_A026788_20200808T093036//IMG_DATA/R10m/processed_2_T33MVV_20200808T090601_TCI_10m.jp2
# Processing 38 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MWV_A026788_20200808T093036//IMG_DATA/R10m/processed_2_T33MWV_20200808T090601_TCI_10m.jp2
# Processing 39 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVA_A026788_20200808T093036//IMG_DATA/R10m/processed_2_T33NVA_20200808T090601_TCI_10m.jp2
# Processing 40 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWA_A026788_20200808T093036//IMG_DATA/R10m/processed_2_T33NWA_20200808T090601_TCI_10m.jp2
# Processing 41 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MWV_A026788_20200808T091204//IMG_DATA/R10m/processed_2_T33MWV_20200808T090601_TCI_10m.jp2
# Processing 42 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVA_A026788_20200808T091204//IMG_DATA/R10m/processed_2_T33NVA_20200808T090601_TCI_10m.jp2
# Processing 43 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWA_A026788_20200808T091204//IMG_DATA/R10m/processed_2_T33NWA_20200808T090601_TCI_10m.jp2
# Processing 44 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBB_A017865_20200807T090515//IMG_DATA/R10m/processed_2_T34MBB_20200807T084559_TCI_10m.jp2
# Processing 45 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MZT_A017865_20200807T090515//IMG_DATA/R10m/processed_2_T33MZT_20200807T084559_TCI_10m.jp2
# Processing 46 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A017865_20200807T090515//IMG_DATA/R10m/processed_2_T34MBC_20200807T084559_TCI_10m.jp2
# Processing 47 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEF_A017865_20200807T090515//IMG_DATA/R10m/processed_2_T34NEF_20200807T084559_TCI_10m.jp2
# Processing 48 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MZT_A026745_20200805T091544//IMG_DATA/R10m/processed_2_T33MZT_20200805T085601_TCI_10m.jp2
# Processing 49 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A026745_20200805T091544//IMG_DATA/R10m/processed_2_T34MBC_20200805T085601_TCI_10m.jp2
# Processing 50 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MWV_A026745_20200805T091544//IMG_DATA/R10m/processed_2_T33MWV_20200805T085601_TCI_10m.jp2
# Processing 51 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MZT_A017765_20200731T091349//IMG_DATA/R10m/processed_2_T33MZT_20200731T085559_TCI_10m.jp2
# Processing 52 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A017765_20200731T091349//IMG_DATA/R10m/processed_2_T34MBC_20200731T085559_TCI_10m.jp2
# Processing 53 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MWV_A017765_20200731T091349//IMG_DATA/R10m/processed_2_T33MWV_20200731T085559_TCI_10m.jp2
# Processing 54 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NCH_A017765_20200731T091349//IMG_DATA/R10m/processed_2_T34NCH_20200731T085559_TCI_10m.jp2
# Processing 55 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NZD_A017765_20200731T091349//IMG_DATA/R10m/processed_2_T33NZD_20200731T085559_TCI_10m.jp2
# Processing 56 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYE_A017765_20200731T091349//IMG_DATA/R10m/processed_2_T33NYE_20200731T085559_TCI_10m.jp2
# Processing 57 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBB_A017722_20200728T085918//IMG_DATA/R10m/processed_2_T34MBB_20200728T084559_TCI_10m.jp2
# Processing 58 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MCB_A017722_20200728T085918//IMG_DATA/R10m/processed_2_T34MCB_20200728T084559_TCI_10m.jp2
# Processing 59 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MZT_A017722_20200728T085918//IMG_DATA/R10m/processed_2_T33MZT_20200728T084559_TCI_10m.jp2
# Processing 60 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A017722_20200728T085918//IMG_DATA/R10m/processed_2_T34MBC_20200728T084559_TCI_10m.jp2
# Processing 61 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NCH_A017722_20200728T085918//IMG_DATA/R10m/processed_2_T34NCH_20200728T084559_TCI_10m.jp2
# Processing 62 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MWV_A017665_20200724T092637//IMG_DATA/R10m/processed_2_T33MWV_20200724T090559_TCI_10m.jp2
# Processing 63 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWA_A017665_20200724T092637//IMG_DATA/R10m/processed_2_T33NWA_20200724T090559_TCI_10m.jp2
# Processing 64 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBB_A026559_20200723T090956//IMG_DATA/R10m/processed_2_T34MBB_20200723T084601_TCI_10m.jp2
# Processing 65 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MWV_A017622_20200721T091544//IMG_DATA/R10m/processed_2_T33MWV_20200721T085559_TCI_10m.jp2
# Processing 66 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXC_A017622_20200721T091544//IMG_DATA/R10m/processed_2_T33NXC_20200721T085559_TCI_10m.jp2
# Processing 67 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NZD_A017622_20200721T091544//IMG_DATA/R10m/processed_2_T33NZD_20200721T085559_TCI_10m.jp2
# Processing 68 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBB_A017436_20200708T090330//IMG_DATA/R10m/processed_2_T34MBB_20200708T084559_TCI_10m.jp2
# Processing 69 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NDG_A017436_20200708T090330//IMG_DATA/R10m/processed_2_T34NDG_20200708T084559_TCI_10m.jp2
# Processing 70 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MZT_A026273_20200703T090351//IMG_DATA/R10m/processed_2_T33MZT_20200703T084601_TCI_10m.jp2
# Processing 71 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A026273_20200703T090351//IMG_DATA/R10m/processed_2_T34MBC_20200703T084601_TCI_10m.jp2
# Processing 72 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEF_A026273_20200703T090351//IMG_DATA/R10m/processed_2_T34NEF_20200703T084601_TCI_10m.jp2
# Processing 73 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUF_A026259_20200702T093112//IMG_DATA/R10m/processed_2_T33NUF_20200702T092031_TCI_10m.jp2
# Processing 74 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUG_A026259_20200702T093112//IMG_DATA/R10m/processed_2_T33NUG_20200702T092031_TCI_10m.jp2
# Processing 75 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MZT_A017293_20200628T085951//IMG_DATA/R10m/processed_2_T33MZT_20200628T084559_TCI_10m.jp2
# Processing 76 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MZT_A026173_20200626T092029//IMG_DATA/R10m/processed_2_T33MZT_20200626T085601_TCI_10m.jp2
# Processing 77 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYC_A017236_20200624T092728//IMG_DATA/R10m/processed_2_T33NYC_20200624T090559_TCI_10m.jp2
# Processing 78 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MWV_A017193_20200621T091552//IMG_DATA/R10m/processed_2_T33MWV_20200621T085559_TCI_10m.jp2
# Processing 79 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NCH_A017150_20200618T090240//IMG_DATA/R10m/processed_2_T34NCH_20200618T084559_TCI_10m.jp2
# Processing 80 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTF_A026016_20200615T094404//IMG_DATA/R10m/processed_2_T33NTF_20200615T093041_TCI_10m.jp2
# Processing 81 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVF_A017093_20200614T092409//IMG_DATA/R10m/processed_2_T33NVF_20200614T090559_TCI_10m.jp2
# Processing 82 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBB_A025987_20200613T090356//IMG_DATA/R10m/processed_2_T34MBB_20200613T084611_TCI_10m.jp2
# Processing 83 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MCB_A025987_20200613T090356//IMG_DATA/R10m/processed_2_T34MCB_20200613T084611_TCI_10m.jp2
# Processing 84 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NCH_A025987_20200613T090356//IMG_DATA/R10m/processed_2_T34NCH_20200613T084611_TCI_10m.jp2
# Processing 85 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYC_A025930_20200609T092746//IMG_DATA/R10m/processed_2_T33NYC_20200609T090601_TCI_10m.jp2
# Processing 86 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTG_A016993_20200607T093134//IMG_DATA/R10m/processed_2_T33NTG_20200607T092029_TCI_10m.jp2
# Processing 87 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MWV_A016950_20200604T092923//IMG_DATA/R10m/processed_2_T33MWV_20200604T090559_TCI_10m.jp2
# Processing 88 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NGG_A016821_20200526T085642//IMG_DATA/R10m/processed_2_T34NGG_20200526T083559_TCI_10m.jp2
# Processing 89 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXB_A016807_20200525T092642//IMG_DATA/R10m/processed_2_T33NXB_20200525T090559_TCI_10m.jp2
# Processing 90 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWC_A016807_20200525T092642//IMG_DATA/R10m/processed_2_T33NWC_20200525T090559_TCI_10m.jp2
# Processing 91 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXC_A016807_20200525T092642//IMG_DATA/R10m/processed_2_T33NXC_20200525T090559_TCI_10m.jp2
# Processing 92 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVD_A016807_20200525T092642//IMG_DATA/R10m/processed_2_T33NVD_20200525T090559_TCI_10m.jp2
# Processing 93 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYC_A016807_20200525T092642//IMG_DATA/R10m/processed_2_T33NYC_20200525T090559_TCI_10m.jp2
# Processing 94 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWD_A016807_20200525T092642//IMG_DATA/R10m/processed_2_T33NWD_20200525T090559_TCI_10m.jp2
# Processing 95 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXD_A016807_20200525T092642//IMG_DATA/R10m/processed_2_T33NXD_20200525T090559_TCI_10m.jp2
# Processing 96 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYD_A016807_20200525T092642//IMG_DATA/R10m/processed_2_T33NYD_20200525T090559_TCI_10m.jp2
# Processing 97 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWE_A016807_20200525T092642//IMG_DATA/R10m/processed_2_T33NWE_20200525T090559_TCI_10m.jp2
# Processing 98 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXE_A016807_20200525T092642//IMG_DATA/R10m/processed_2_T33NXE_20200525T090559_TCI_10m.jp2
# Processing 99 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYE_A016807_20200525T092642//IMG_DATA/R10m/processed_2_T33NYE_20200525T090559_TCI_10m.jp2
# Processing 100 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWA_A025644_20200520T092926//IMG_DATA/R10m/processed_2_T33NWA_20200520T090601_TCI_10m.jp2
# Processing 101 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWB_A025644_20200520T092926//IMG_DATA/R10m/processed_2_T33NWB_20200520T090601_TCI_10m.jp2
# Processing 102 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXB_A025644_20200520T092926//IMG_DATA/R10m/processed_2_T33NXB_20200520T090601_TCI_10m.jp2
# Processing 103 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXC_A025644_20200520T092926//IMG_DATA/R10m/processed_2_T33NXC_20200520T090601_TCI_10m.jp2
# Processing 104 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYC_A025644_20200520T092926//IMG_DATA/R10m/processed_2_T33NYC_20200520T090601_TCI_10m.jp2
# Processing 105 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXB_A025601_20200517T091331//IMG_DATA/R10m/processed_2_T33NXB_20200517T085601_TCI_10m.jp2
# Processing 106 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXC_A025601_20200517T091331//IMG_DATA/R10m/processed_2_T33NXC_20200517T085601_TCI_10m.jp2
# Processing 107 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXD_A025601_20200517T091331//IMG_DATA/R10m/processed_2_T33NXD_20200517T085601_TCI_10m.jp2
# Processing 108 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NCH_A025601_20200517T091331//IMG_DATA/R10m/processed_2_T34NCH_20200517T085601_TCI_10m.jp2
# Processing 109 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYD_A025601_20200517T091331//IMG_DATA/R10m/processed_2_T33NYD_20200517T085601_TCI_10m.jp2
# Processing 110 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NZD_A025601_20200517T091331//IMG_DATA/R10m/processed_2_T33NZD_20200517T085601_TCI_10m.jp2
# Processing 111 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTF_A025587_20200516T093756//IMG_DATA/R10m/processed_2_T33NTF_20200516T093041_TCI_10m.jp2
# Processing 112 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NCH_A016621_20200512T091939//IMG_DATA/R10m/processed_2_T34NCH_20200512T085559_TCI_10m.jp2
# Processing 113 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYC_A025501_20200510T092755//IMG_DATA/R10m/processed_2_T33NYC_20200510T090601_TCI_10m.jp2
# Processing 114 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NFG_A016535_20200506T085121//IMG_DATA/R10m/processed_2_T34NFG_20200506T083559_TCI_10m.jp2
# Processing 115 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NGG_A016535_20200506T085121//IMG_DATA/R10m/processed_2_T34NGG_20200506T083559_TCI_10m.jp2
# Processing 116 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEH_A016535_20200506T085121//IMG_DATA/R10m/processed_2_T34NEH_20200506T083559_TCI_10m.jp2
# Processing 117 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVE_A016521_20200505T092849//IMG_DATA/R10m/processed_2_T33NVE_20200505T090549_TCI_10m.jp2
# Processing 118 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVF_A016521_20200505T092849//IMG_DATA/R10m/processed_2_T33NVF_20200505T090549_TCI_10m.jp2
# Processing 119 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBB_A025415_20200504T090346//IMG_DATA/R10m/processed_2_T34MBB_20200504T084601_TCI_10m.jp2
# Processing 120 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MCB_A025415_20200504T090346//IMG_DATA/R10m/processed_2_T34MCB_20200504T084601_TCI_10m.jp2
# Processing 121 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MVV_A025358_20200430T091954//IMG_DATA/R10m/processed_2_T33MVV_20200430T090601_TCI_10m.jp2
# Processing 122 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MWV_A025358_20200430T091954//IMG_DATA/R10m/processed_2_T33MWV_20200430T090601_TCI_10m.jp2
# Processing 123 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWA_A025358_20200430T091954//IMG_DATA/R10m/processed_2_T33NWA_20200430T090601_TCI_10m.jp2
# Processing 124 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MCB_A016435_20200429T085926//IMG_DATA/R10m/processed_2_T34MCB_20200429T084559_TCI_10m.jp2
# Processing 125 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWA_A016378_20200425T092712//IMG_DATA/R10m/processed_2_T33NWA_20200425T090549_TCI_10m.jp2
# Processing 126 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWB_A016378_20200425T092712//IMG_DATA/R10m/processed_2_T33NWB_20200425T090549_TCI_10m.jp2
# Processing 127 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWC_A016378_20200425T092712//IMG_DATA/R10m/processed_2_T33NWC_20200425T090549_TCI_10m.jp2
# Processing 128 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXC_A016378_20200425T092712//IMG_DATA/R10m/processed_2_T33NXC_20200425T090549_TCI_10m.jp2
# Processing 129 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVD_A016378_20200425T092712//IMG_DATA/R10m/processed_2_T33NVD_20200425T090549_TCI_10m.jp2
# Processing 130 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWD_A016378_20200425T092712//IMG_DATA/R10m/processed_2_T33NWD_20200425T090549_TCI_10m.jp2
# Processing 131 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXD_A016378_20200425T092712//IMG_DATA/R10m/processed_2_T33NXD_20200425T090549_TCI_10m.jp2
# Processing 132 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYD_A016378_20200425T092712//IMG_DATA/R10m/processed_2_T33NYD_20200425T090549_TCI_10m.jp2
# Processing 133 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVE_A016378_20200425T092712//IMG_DATA/R10m/processed_2_T33NVE_20200425T090549_TCI_10m.jp2
# Processing 134 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXE_A016378_20200425T092712//IMG_DATA/R10m/processed_2_T33NXE_20200425T090549_TCI_10m.jp2
# Processing 135 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYE_A016378_20200425T092712//IMG_DATA/R10m/processed_2_T33NYE_20200425T090549_TCI_10m.jp2
# Processing 136 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVF_A016378_20200425T092712//IMG_DATA/R10m/processed_2_T33NVF_20200425T090549_TCI_10m.jp2
# Processing 137 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBB_A025272_20200424T091025//IMG_DATA/R10m/processed_2_T34MBB_20200424T084601_TCI_10m.jp2
# Processing 138 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MCB_A025272_20200424T091025//IMG_DATA/R10m/processed_2_T34MCB_20200424T084601_TCI_10m.jp2
# Processing 139 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTF_A016321_20200421T094617//IMG_DATA/R10m/processed_2_T33NTF_20200421T093029_TCI_10m.jp2
# Processing 140 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTG_A016321_20200421T094617//IMG_DATA/R10m/processed_2_T33NTG_20200421T093029_TCI_10m.jp2
# Processing 141 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NQG_A016278_20200418T093728//IMG_DATA/R10m/processed_2_T32NQG_20200418T092029_TCI_10m.jp2
# Processing 142 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NDF_A025129_20200414T090349//IMG_DATA/R10m/processed_2_T34NDF_20200414T084601_TCI_10m.jp2
# Processing 143 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEF_A025129_20200414T090349//IMG_DATA/R10m/processed_2_T34NEF_20200414T084601_TCI_10m.jp2
# Processing 144 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NDG_A025129_20200414T090349//IMG_DATA/R10m/processed_2_T34NDG_20200414T084601_TCI_10m.jp2
# Processing 145 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NDH_A025129_20200414T090349//IMG_DATA/R10m/processed_2_T34NDH_20200414T084601_TCI_10m.jp2
# Processing 146 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEH_A025129_20200414T090349//IMG_DATA/R10m/processed_2_T34NEH_20200414T084601_TCI_10m.jp2
# Processing 147 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXB_A025072_20200410T092731//IMG_DATA/R10m/processed_2_T33NXB_20200410T090551_TCI_10m.jp2
# Processing 148 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXC_A025072_20200410T092731//IMG_DATA/R10m/processed_2_T33NXC_20200410T090551_TCI_10m.jp2
# Processing 149 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYC_A025072_20200410T092731//IMG_DATA/R10m/processed_2_T33NYC_20200410T090551_TCI_10m.jp2
# Processing 150 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXD_A025072_20200410T092731//IMG_DATA/R10m/processed_2_T33NXD_20200410T090551_TCI_10m.jp2
# Processing 151 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MWV_A025029_20200407T091315//IMG_DATA/R10m/processed_2_T33MWV_20200407T085551_TCI_10m.jp2
# Processing 152 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXB_A025029_20200407T091315//IMG_DATA/R10m/processed_2_T33NXB_20200407T085551_TCI_10m.jp2
# Processing 153 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYB_A025029_20200407T091315//IMG_DATA/R10m/processed_2_T33NYB_20200407T085551_TCI_10m.jp2
# Processing 154 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXC_A025029_20200407T091315//IMG_DATA/R10m/processed_2_T33NXC_20200407T085551_TCI_10m.jp2
# Processing 155 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYC_A025029_20200407T091315//IMG_DATA/R10m/processed_2_T33NYC_20200407T085551_TCI_10m.jp2
# Processing 156 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYD_A025029_20200407T091315//IMG_DATA/R10m/processed_2_T33NYD_20200407T085551_TCI_10m.jp2
# Processing 157 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NZD_A025029_20200407T091315//IMG_DATA/R10m/processed_2_T33NZD_20200407T085551_TCI_10m.jp2
# Processing 158 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXB_A024886_20200328T091806//IMG_DATA/R10m/processed_2_T33NXB_20200328T085551_TCI_10m.jp2
# Processing 159 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXC_A024886_20200328T091806//IMG_DATA/R10m/processed_2_T33NXC_20200328T085551_TCI_10m.jp2
# Processing 160 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NFG_A015963_20200327T085848//IMG_DATA/R10m/processed_2_T34NFG_20200327T083559_TCI_10m.jp2
# Processing 161 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYD_A015906_20200323T091341//IMG_DATA/R10m/processed_2_T33NYD_20200323T085619_TCI_10m.jp2
# Processing 162 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NZD_A015906_20200323T091341//IMG_DATA/R10m/processed_2_T33NZD_20200323T085619_TCI_10m.jp2
# Processing 163 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYE_A015906_20200323T091341//IMG_DATA/R10m/processed_2_T33NYE_20200323T085619_TCI_10m.jp2
# Processing 164 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVE_A015806_20200316T091815//IMG_DATA/R10m/processed_2_T33NVE_20200316T090659_TCI_10m.jp2
# Processing 165 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWE_A015806_20200316T091815//IMG_DATA/R10m/processed_2_T33NWE_20200316T090659_TCI_10m.jp2
# Processing 166 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXE_A015806_20200316T091815//IMG_DATA/R10m/processed_2_T33NXE_20200316T090659_TCI_10m.jp2
# Processing 167 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYE_A015806_20200316T091815//IMG_DATA/R10m/processed_2_T33NYE_20200316T090659_TCI_10m.jp2
# Processing 168 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVF_A015806_20200316T091815//IMG_DATA/R10m/processed_2_T33NVF_20200316T090659_TCI_10m.jp2
# Processing 169 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTE_A024686_20200314T092857//IMG_DATA/R10m/processed_2_T33NTE_20200314T092031_TCI_10m.jp2
# Processing 170 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUE_A024686_20200314T092857//IMG_DATA/R10m/processed_2_T33NUE_20200314T092031_TCI_10m.jp2
# Processing 171 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVE_A024686_20200314T092857//IMG_DATA/R10m/processed_2_T33NVE_20200314T092031_TCI_10m.jp2
# Processing 172 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTF_A024686_20200314T092857//IMG_DATA/R10m/processed_2_T33NTF_20200314T092031_TCI_10m.jp2
# Processing 173 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUF_A024686_20200314T092857//IMG_DATA/R10m/processed_2_T33NUF_20200314T092031_TCI_10m.jp2
# Processing 174 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVF_A024686_20200314T092857//IMG_DATA/R10m/processed_2_T33NVF_20200314T092031_TCI_10m.jp2
# Processing 175 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUG_A024686_20200314T092857//IMG_DATA/R10m/processed_2_T33NUG_20200314T092031_TCI_10m.jp2
# Processing 176 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXD_A015763_20200313T091049//IMG_DATA/R10m/processed_2_T33NXD_20200313T085709_TCI_10m.jp2
# Processing 177 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYD_A015763_20200313T091049//IMG_DATA/R10m/processed_2_T33NYD_20200313T085709_TCI_10m.jp2
# Processing 178 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NZD_A015763_20200313T091049//IMG_DATA/R10m/processed_2_T33NZD_20200313T085709_TCI_10m.jp2
# Processing 179 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYE_A015763_20200313T091049//IMG_DATA/R10m/processed_2_T33NYE_20200313T085709_TCI_10m.jp2
# Processing 180 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NDF_A015720_20200310T090902//IMG_DATA/R10m/processed_2_T34NDF_20200310T084709_TCI_10m.jp2
# Processing 181 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEF_A015720_20200310T090902//IMG_DATA/R10m/processed_2_T34NEF_20200310T084709_TCI_10m.jp2
# Processing 182 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NDG_A015720_20200310T090902//IMG_DATA/R10m/processed_2_T34NDG_20200310T084709_TCI_10m.jp2
# Processing 183 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NDH_A015720_20200310T090902//IMG_DATA/R10m/processed_2_T34NDH_20200310T084709_TCI_10m.jp2
# Processing 184 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEH_A015720_20200310T090902//IMG_DATA/R10m/processed_2_T34NEH_20200310T084709_TCI_10m.jp2
# Processing 185 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTG_A015706_20200309T093654//IMG_DATA/R10m/processed_2_T33NTG_20200309T092029_TCI_10m.jp2
# Processing 186 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEH_A015677_20200307T085545//IMG_DATA/R10m/processed_2_T34NEH_20200307T083719_TCI_10m.jp2
# Processing 187 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXD_A015663_20200306T092559//IMG_DATA/R10m/processed_2_T33NXD_20200306T090729_TCI_10m.jp2
# Processing 188 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYD_A015663_20200306T092559//IMG_DATA/R10m/processed_2_T33NYD_20200306T090729_TCI_10m.jp2
# Processing 189 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVE_A015663_20200306T092559//IMG_DATA/R10m/processed_2_T33NVE_20200306T090729_TCI_10m.jp2
# Processing 190 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWE_A015663_20200306T092559//IMG_DATA/R10m/processed_2_T33NWE_20200306T090729_TCI_10m.jp2
# Processing 191 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXE_A015663_20200306T092559//IMG_DATA/R10m/processed_2_T33NXE_20200306T090729_TCI_10m.jp2
# Processing 192 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYE_A015663_20200306T092559//IMG_DATA/R10m/processed_2_T33NYE_20200306T090729_TCI_10m.jp2
# Processing 193 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEF_A024557_20200305T090842//IMG_DATA/R10m/processed_2_T34NEF_20200305T084831_TCI_10m.jp2
# Processing 194 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NDG_A024557_20200305T090842//IMG_DATA/R10m/processed_2_T34NDG_20200305T084831_TCI_10m.jp2
# Processing 195 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NDH_A024557_20200305T090842//IMG_DATA/R10m/processed_2_T34NDH_20200305T084831_TCI_10m.jp2
# Processing 196 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEH_A024557_20200305T090842//IMG_DATA/R10m/processed_2_T34NEH_20200305T084831_TCI_10m.jp2
# Processing 197 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXD_A015620_20200303T091359//IMG_DATA/R10m/processed_2_T33NXD_20200303T085749_TCI_10m.jp2
# Processing 198 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MCB_A015577_20200229T091048//IMG_DATA/R10m/processed_2_T34MCB_20200229T084809_TCI_10m.jp2
# Processing 199 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NDF_A015577_20200229T085821//IMG_DATA/R10m/processed_2_T34NDF_20200229T084809_TCI_10m.jp2
# Processing 200 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEF_A015577_20200229T085821//IMG_DATA/R10m/processed_2_T34NEF_20200229T084809_TCI_10m.jp2
# Processing 201 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NDG_A015577_20200229T085821//IMG_DATA/R10m/processed_2_T34NDG_20200229T084809_TCI_10m.jp2
# Processing 202 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NNM_A024443_20200226T093800//IMG_DATA/R10m/processed_2_T32NNM_20200226T093031_TCI_10m.jp2
# Processing 203 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVF_A015520_20200225T092628//IMG_DATA/R10m/processed_2_T33NVF_20200225T090849_TCI_10m.jp2
# Processing 204 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NML_A015506_20200224T095355//IMG_DATA/R10m/processed_2_T32NML_20200224T094029_TCI_10m.jp2
# Processing 205 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NMM_A015506_20200224T095355//IMG_DATA/R10m/processed_2_T32NMM_20200224T094029_TCI_10m.jp2
# Processing 206 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NNM_A015506_20200224T095355//IMG_DATA/R10m/processed_2_T32NNM_20200224T094029_TCI_10m.jp2
# Processing 207 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTF_A024400_20200223T093253//IMG_DATA/R10m/processed_2_T33NTF_20200223T092021_TCI_10m.jp2
# Processing 208 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUF_A024400_20200223T093253//IMG_DATA/R10m/processed_2_T33NUF_20200223T092021_TCI_10m.jp2
# Processing 209 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVF_A024400_20200223T093253//IMG_DATA/R10m/processed_2_T33NVF_20200223T092021_TCI_10m.jp2
# Processing 210 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTG_A024400_20200223T093253//IMG_DATA/R10m/processed_2_T33NTG_20200223T092021_TCI_10m.jp2
# Processing 211 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUG_A024400_20200223T093253//IMG_DATA/R10m/processed_2_T33NUG_20200223T092021_TCI_10m.jp2
# ...
# Processing 419 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MVV_A021211_20190715T092745//IMG_DATA/R10m/processed_2_T33MVV_20190715T090601_TCI_10m.jp2
# Processing 420 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWC_A021211_20190715T092745//IMG_DATA/R10m/processed_2_T33NWC_20190715T090601_TCI_10m.jp2
# Processing 421 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVC_A020968_20190628T093625//IMG_DATA/R10m/processed_2_T33NVC_20190628T092031_TCI_10m.jp2
# Processing 422 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MVV_A020925_20190625T091818//IMG_DATA/R10m/processed_2_T33MVV_20190625T090601_TCI_10m.jp2
# Processing 423 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVA_A020925_20190625T091818//IMG_DATA/R10m/processed_2_T33NVA_20190625T090601_TCI_10m.jp2
# Processing 424 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUB_A020925_20190625T091818//IMG_DATA/R10m/processed_2_T33NUB_20190625T090601_TCI_10m.jp2
# Processing 425 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NRH_A020439_20190522T094011//IMG_DATA/R10m/processed_2_T32NRH_20190522T093041_TCI_10m.jp2
# Processing 426 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NRH_A020296_20190512T094620//IMG_DATA/R10m/processed_2_T32NRH_20190512T093041_TCI_10m.jp2
# Processing 427 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NFH_A011244_20190502T084913//IMG_DATA/R10m/processed_2_T34NFH_20190502T083609_TCI_10m.jp2
# Processing 428 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NQG_A011030_20190417T094727//IMG_DATA/R10m/processed_2_T32NQG_20190417T093039_TCI_10m.jp2
# Processing 429 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NRK_A011030_20190417T094727//IMG_DATA/R10m/processed_2_T32NRK_20190417T093039_TCI_10m.jp2
# Processing 430 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NRK_A019867_20190412T094618//IMG_DATA/R10m/processed_2_T32NRK_20190412T093041_TCI_10m.jp2
# Processing 431 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NQG_A019867_20190412T094618//IMG_DATA/R10m/processed_2_T32NQG_20190412T093041_TCI_10m.jp2
# Processing 432 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NRH_A019867_20190412T094618//IMG_DATA/R10m/processed_2_T32NRH_20190412T093041_TCI_10m.jp2
# Processing 433 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NRH_A019824_20190409T093304//IMG_DATA/R10m/processed_2_T32NRH_20190409T092031_TCI_10m.jp2
# Processing 434 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUB_A010844_20190404T093457//IMG_DATA/R10m/processed_2_T33NUB_20190404T092029_TCI_10m.jp2
# Processing 435 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUE_A010844_20190404T093457//IMG_DATA/R10m/processed_2_T33NUE_20190404T092029_TCI_10m.jp2
# Processing 436 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUC_A010844_20190404T093457//IMG_DATA/R10m/processed_2_T33NUC_20190404T092029_TCI_10m.jp2
# Processing 437 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVD_A010844_20190404T093457//IMG_DATA/R10m/processed_2_T33NVD_20190404T092029_TCI_10m.jp2
# Processing 438 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVC_A010844_20190404T093457//IMG_DATA/R10m/processed_2_T33NVC_20190404T092029_TCI_10m.jp2
# Processing 439 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUD_A010844_20190404T093457//IMG_DATA/R10m/processed_2_T33NUD_20190404T092029_TCI_10m.jp2
# Processing 440 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWB_A010801_20190401T092807//IMG_DATA/R10m/processed_2_T33NWB_20190401T090559_TCI_10m.jp2
# Processing 441 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWC_A010801_20190401T092807//IMG_DATA/R10m/processed_2_T33NWC_20190401T090559_TCI_10m.jp2
# Processing 442 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVD_A010801_20190401T092807//IMG_DATA/R10m/processed_2_T33NVD_20190401T090559_TCI_10m.jp2
# Processing 443 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVD_A019538_20190320T093112//IMG_DATA/R10m/processed_2_T33NVD_20190320T092031_TCI_10m.jp2
# Processing 444 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NRH_A010415_20190305T093720//IMG_DATA/R10m/processed_2_T32NRH_20190305T092029_TCI_10m.jp2
# Processing 445 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NRK_A010415_20190305T093720//IMG_DATA/R10m/processed_2_T32NRK_20190305T092029_TCI_10m.jp2
# Processing 446 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTE_A010415_20190305T093720//IMG_DATA/R10m/processed_2_T33NTE_20190305T092029_TCI_10m.jp2
# Processing 447 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NFH_A010243_20190221T084958//IMG_DATA/R10m/processed_2_T34NFH_20190221T083959_TCI_10m.jp2
# Processing 448 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVA_A019066_20190215T092143//IMG_DATA/R10m/processed_2_T33NVA_20190215T091051_TCI_10m.jp2
# Processing 449 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWB_A019066_20190215T092143//IMG_DATA/R10m/processed_2_T33NWB_20190215T091051_TCI_10m.jp2
# Processing 450 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXE_A019066_20190215T092143//IMG_DATA/R10m/processed_2_T33NXE_20190215T091051_TCI_10m.jp2
# Processing 451 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NRH_A019009_20190211T094444//IMG_DATA/R10m/processed_2_T32NRH_20190211T093121_TCI_10m.jp2
# Processing 452 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NFH_A010100_20190211T085817//IMG_DATA/R10m/processed_2_T34NFH_20190211T084059_TCI_10m.jp2
# Processing 453 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NQG_A018680_20190119T093439//IMG_DATA/R10m/processed_2_T32NQG_20190119T092311_TCI_10m.jp2
# Processing 454 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NRH_A018680_20190119T093439//IMG_DATA/R10m/processed_2_T32NRH_20190119T092311_TCI_10m.jp2
# Processing 455 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NFH_A009671_20190112T085828//IMG_DATA/R10m/processed_2_T34NFH_20190112T084319_TCI_10m.jp2
# Processing 456 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWC_A009657_20190111T091856//IMG_DATA/R10m/processed_2_T33NWC_20190111T091339_TCI_10m.jp2
# Processing 457 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVD_A009657_20190111T091856//IMG_DATA/R10m/processed_2_T33NVD_20190111T091339_TCI_10m.jp2
# Processing 458 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWD_A009657_20190111T091856//IMG_DATA/R10m/processed_2_T33NWD_20190111T091339_TCI_10m.jp2
# Processing 459 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXE_A009657_20190111T091856//IMG_DATA/R10m/processed_2_T33NXE_20190111T091339_TCI_10m.jp2
# Processing 460 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NML_A009643_20190110T095700//IMG_DATA/R10m/processed_2_T32NML_20190110T094359_TCI_10m.jp2
# Processing 461 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUE_A018537_20190109T093637//IMG_DATA/R10m/processed_2_T33NUE_20190109T092351_TCI_10m.jp2
# Processing 462 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NMK_A018480_20190105T095815//IMG_DATA/R10m/processed_2_T32NMK_20190105T094401_TCI_10m.jp2
# Processing 463 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NQH_A014891_20200112T094228//IMG_DATA/R10m/processed_2_T32NQH_20200112T093249_TCI_10m.jp2
# Processing 464 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NQH_A016278_20200418T093728//IMG_DATA/R10m/processed_2_T32NQH_20200418T092029_TCI_10m.jp2
# Processing 465 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NQH_A018680_20190119T093439//IMG_DATA/R10m/processed_2_T32NQH_20190119T092311_TCI_10m.jp2
# Processing 466 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NQH_A019824_20190409T093304//IMG_DATA/R10m/processed_2_T32NQH_20190409T092031_TCI_10m.jp2
# Processing 467 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NQH_A019867_20190412T094618//IMG_DATA/R10m/processed_2_T32NQH_20190412T093041_TCI_10m.jp2
# Processing 468 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NQH_A023685_20200104T093437//IMG_DATA/R10m/processed_2_T32NQH_20200104T092401_TCI_10m.jp2
# Processing 469 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MCE_A015577_20200229T085821//IMG_DATA/R10m/processed_2_T34MCE_20200229T084809_TCI_10m.jp2
# Processing 470 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MCE_A016435_20200429T085926//IMG_DATA/R10m/processed_2_T34MCE_20200429T084559_TCI_10m.jp2
# Processing 471 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MCE_A017150_20200618T090240//IMG_DATA/R10m/processed_2_T34MCE_20200618T084559_TCI_10m.jp2
# Processing 472 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MCE_A017436_20200708T090330//IMG_DATA/R10m/processed_2_T34MCE_20200708T084559_TCI_10m.jp2
# Processing 473 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MCE_A025129_20200414T090349//IMG_DATA/R10m/processed_2_T34MCE_20200414T084601_TCI_10m.jp2
# Processing 474 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MCE_A025272_20200424T090055//IMG_DATA/R10m/processed_2_T34MCE_20200424T084601_TCI_10m.jp2
# Processing 475 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MCE_A025272_20200424T091025//IMG_DATA/R10m/processed_2_T34MCE_20200424T084601_TCI_10m.jp2
# Processing 476 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MCE_A025415_20200504T090346//IMG_DATA/R10m/processed_2_T34MCE_20200504T084601_TCI_10m.jp2
# Processing 477 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MCE_A025844_20200603T090013//IMG_DATA/R10m/processed_2_T34MCE_20200603T084611_TCI_10m.jp2
# Processing 478 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MCE_A025987_20200613T090356//IMG_DATA/R10m/processed_2_T34MCE_20200613T084611_TCI_10m.jp2
# Processing 479 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T35NLB_A009628_20190109T083800//IMG_DATA/R10m/processed_2_T35NLB_20190109T083329_TCI_10m.jp2
# Processing 480 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T35NLB_A010200_20190218T084507//IMG_DATA/R10m/processed_2_T35NLB_20190218T083009_TCI_10m.jp2
# Processing 481 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T35NLB_A014347_20191205T083849//IMG_DATA/R10m/processed_2_T35NLB_20191205T083229_TCI_10m.jp2
# Processing 482 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T35NLB_A014919_20200114T084628//IMG_DATA/R10m/processed_2_T35NLB_20200114T083219_TCI_10m.jp2
# Processing 483 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T35NLB_A015205_20200203T084711//IMG_DATA/R10m/processed_2_T35NLB_20200203T083049_TCI_10m.jp2
# Processing 484 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T35NLB_A016921_20200602T084159//IMG_DATA/R10m/processed_2_T35NLB_20200602T082609_TCI_10m.jp2
# Processing 485 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T35NLB_A019037_20190213T084055//IMG_DATA/R10m/processed_2_T35NLB_20190213T083041_TCI_10m.jp2
# Processing 486 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T35NLB_A023613_20191230T084321//IMG_DATA/R10m/processed_2_T35NLB_20191230T083341_TCI_10m.jp2
# Processing 487 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T35NLB_A024185_20200208T084355//IMG_DATA/R10m/processed_2_T35NLB_20200208T083111_TCI_10m.jp2
# Processing 488 of 488
# creating /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T35NLB_A025758_20200528T084055//IMG_DATA/R10m/processed_2_T35NLB_20200528T082611_TCI_10m.jp2
# Applied masks to 488 products

# %%
# Generate array of processed directories if error during masking code
processed = []
with open("./data/processed.txt","r") as f:
    for lin in f:
        processed.append(lin.split("\n")[0])

# %%
def generate_product_detail_df(input_dir):
    
    '''
    Generate product details dataframe used as input for ordering products by Cloudy Pixel Percentage, No Data Pixel Percentage, or Unclassified Percentage
    
    '''
    input_dir = add_trailing_slash(input_dir)
    
    dirs = os.listdir(input_dir)

    meta_data = []
    for folder in dirs:
        xml_loc = glob(input_dir + "/" + folder + "/*.xml")[0]
        tree = ET.parse(xml_loc)
        directory = [elem.text for elem in tree.iter() if "MASK_FILENAME" in elem.tag][0].split("/")[1]
        tile_id = directory.split("_")[1]
        filepath_partial = input_dir + "/" + directory + "/IMG_DATA" + "/R10m"
        filepath = glob(filepath_partial + "/processed*.jp2")[0]
        filename = filepath.split("/")[-1]
        cloud_cover,no_data,unclassified = [elem.text for elem in tree.iter() if "CLOUDY_PIXEL_PERCENTAGE" in elem.tag 
                 or "NODATA_PIXEL_PERCENTAGE" in elem.tag or "UNCLASSIFIED_PERCENTAGE" in elem.tag]
        meta_data.append([directory,tile_id,cloud_cover,no_data,unclassified,filename,filepath])
    df = pd.DataFrame(meta_data,columns=["Directory","Tile_Id","Cloud Cover","No Data Percentage","Unclassified Percentage","Filename","Filepath"])
    df2 = df.sort_values(by=["Tile_Id","Cloud Cover","Unclassified Percentage"],ignore_index=True)
    return df2

# %%
input_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw"

df = generate_product_detail_df(input_dir)

# %%
df
# Out:
#                               Directory Tile_Id Cloud Cover  \
# 0    L2A_T32NMK_A024343_20200219T095439  T32NMK   10.375307
# 1    L2A_T32NMK_A018480_20190105T095815  T32NMK   12.898219
# 2    L2A_T32NMK_A014505_20191216T095042  T32NMK   14.797034
# 3    L2A_T32NMK_A015077_20200125T095047  T32NMK    3.746630
# 4    L2A_T32NMK_A014791_20200105T095703  T32NMK    9.728458
# ..                                  ...     ...         ...
# 483  L2A_T35NLB_A019037_20190213T084055  T35NLB    3.899672
# 484  L2A_T35NLB_A009628_20190109T083800  T35NLB   30.178366
# 485  L2A_T35NLB_A023613_20191230T084321  T35NLB    4.121645
# 486  L2A_T35NLB_A014347_20191205T083849  T35NLB    5.536621
# 487  L2A_T35NLB_A015205_20200203T084711  T35NLB    6.972405
#
#     No Data Percentage Unclassified Percentage  \
# 0             0.000000                7.602649
# 1             0.000000                4.594089
# 2             0.000000                1.208974
# 3             0.000000                1.804589
# 4             0.000000                2.432975
# ..                 ...                     ...
# 483           0.000000                0.273543
# 484          36.006102               29.398388
# 485           0.000000                0.004230
# 486           0.000000                5.679570
# 487           0.000000                3.153487
#
#                                          Filename  \
# 0    processed_T32NMK_20200219T094031_TCI_10m.jp2
# 1    processed_T32NMK_20190105T094401_TCI_10m.jp2
# 2    processed_T32NMK_20191216T094319_TCI_10m.jp2
# 3    processed_T32NMK_20200125T094159_TCI_10m.jp2
# 4    processed_T32NMK_20200105T094309_TCI_10m.jp2
# ..                                            ...
# 483  processed_T35NLB_20190213T083041_TCI_10m.jp2
# 484  processed_T35NLB_20190109T083329_TCI_10m.jp2
# 485  processed_T35NLB_20191230T083341_TCI_10m.jp2
# 486  processed_T35NLB_20191205T083229_TCI_10m.jp2
# 487  processed_T35NLB_20200203T083049_TCI_10m.jp2
#
#                                               Filepath
# 0    /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
# 1    /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
# 2    /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
# 3    /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
# 4    /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
# ..                                                 ...
# 483  /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
# 484  /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
# 485  /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
# 486  /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
# 487  /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
#
# [488 rows x 7 columns]

# %%
def order_masked_tiles(df,output_dir):
    
    '''
    
    df input is the products detail pre-sorted dataframe to be used for sorting products 
    
    '''
    
    output_dir = add_trailing_slash(output_dir)
    create_dir(output_dir)
    

    layer = 1
    for index,row in df.iterrows(): 
        destination_dir = output_dir + str(layer)
        output_file = destination_dir + "/" + row["Filename"]

        # Check if directory exists
        if not os.path.isdir(destination_dir):
            os.mkdir(destination_dir)

        # Copy file to existing or new directory
        copyfile(row["Filepath"],output_file)

        # Check if Tile_Id already exists in the directory - only necessary up until the last tile
        if len(df) > index + 1:
            if df.loc[index,"Tile_Id"] == df.loc[index + 1,"Tile_Id"]:
                layer += 1
            else:
                layer = 1

# %%
order_masked_tiles(df,"/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/")

# %%
def convert_rasters(src_dir, dest_dir, epsg_format='EPSG:4326', windows=False):
    """Converts the rasters in the src_dir into a different EPSG format,
    keeping the same folder structure and saving them in the dest_dir."""

    src_dir = add_trailing_slash(src_dir)
    dest_dir = add_trailing_slash(dest_dir)
    
    # If the output folder doesn't exist, create it
    create_dir(dest_dir)

    input_files = glob(src_dir + '*/*.jp2')
    # Keep track of how many files were converted
    n = 1
    total = len(input_files)
    
    for f in input_files:
        print(f'processing file {n} of {total}')
        n += 1
        
        # The way we've set it up, we save each product into a numbered folder,
        # depending on which layer it's in. To keep this structure, we need to
        # pull out the folder number from the file path.
        # How exactly to do this depends on if you're using Windows or not,
        # since the path conventions are different.
        if windows:
            folder_num = f.split('\\')[-2]
            filename = f.split('\\')[-1]
        else:
            folder_num = f.split('/')[-2]
            filename = f.split('/')[-1]
        output_folder = dest_dir + folder_num + '/'
        
        
        # If the respective grouping folders are not available 
        create_dir(output_folder)
        
        output_filepath = output_folder + filename
        
        print(output_filepath)
        print(f)

        # Finally, we convert
        converted = gdal.Warp(output_filepath, [f],format='GTiff',
                              dstSRS=epsg_format, resampleAlg='near')
        converted = None
        
    print('Finished')

# %%
src_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2"
dest_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2"

convert_rasters(src_dir, dest_dir)
# Out:
# processing file 1 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/1/processed_T32NQH_20200112T093249_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/1/processed_T32NQH_20200112T093249_TCI_10m.jp2
# processing file 2 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/1/processed_T34MCE_20200429T084559_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/1/processed_T34MCE_20200429T084559_TCI_10m.jp2
# processing file 3 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/1/processed_T35NLB_20200528T082611_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/1/processed_T35NLB_20200528T082611_TCI_10m.jp2
# processing file 4 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/2/processed_T32NQH_20190119T092311_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/2/processed_T32NQH_20190119T092311_TCI_10m.jp2
# processing file 5 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/2/processed_T34MCE_20200424T084601_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/2/processed_T34MCE_20200424T084601_TCI_10m.jp2
# processing file 6 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/2/processed_T35NLB_20190218T083009_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/2/processed_T35NLB_20190218T083009_TCI_10m.jp2
# processing file 7 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/3/processed_T32NQH_20200418T092029_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/3/processed_T32NQH_20200418T092029_TCI_10m.jp2
# processing file 8 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/3/processed_T34MCE_20200414T084601_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/3/processed_T34MCE_20200414T084601_TCI_10m.jp2
# processing file 9 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/3/processed_T35NLB_20200602T082609_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/3/processed_T35NLB_20200602T082609_TCI_10m.jp2
# processing file 10 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/4/processed_T32NQH_20190412T093041_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/4/processed_T32NQH_20190412T093041_TCI_10m.jp2
# processing file 11 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/4/processed_T34MCE_20200618T084559_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/4/processed_T34MCE_20200618T084559_TCI_10m.jp2
# processing file 12 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/4/processed_T35NLB_20200114T083219_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/4/processed_T35NLB_20200114T083219_TCI_10m.jp2
# processing file 13 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/5/processed_T32NQH_20200104T092401_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/5/processed_T32NQH_20200104T092401_TCI_10m.jp2
# processing file 14 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/5/processed_T34MCE_20200613T084611_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/5/processed_T34MCE_20200613T084611_TCI_10m.jp2
# processing file 15 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/5/processed_T35NLB_20200208T083111_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/5/processed_T35NLB_20200208T083111_TCI_10m.jp2
# processing file 16 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/6/processed_T32NQH_20190409T092031_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/6/processed_T32NQH_20190409T092031_TCI_10m.jp2
# processing file 17 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/6/processed_T34MCE_20200229T084809_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/6/processed_T34MCE_20200229T084809_TCI_10m.jp2
# processing file 18 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/6/processed_T35NLB_20190213T083041_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/6/processed_T35NLB_20190213T083041_TCI_10m.jp2
# processing file 19 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/7/processed_T34MCE_20200708T084559_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/7/processed_T34MCE_20200708T084559_TCI_10m.jp2
# processing file 20 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/7/processed_T35NLB_20190109T083329_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/7/processed_T35NLB_20190109T083329_TCI_10m.jp2
# processing file 21 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/8/processed_T34MCE_20200424T084601_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/8/processed_T34MCE_20200424T084601_TCI_10m.jp2
# processing file 22 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/8/processed_T35NLB_20191230T083341_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/8/processed_T35NLB_20191230T083341_TCI_10m.jp2
# processing file 23 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/9/processed_T34MCE_20200504T084601_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/9/processed_T34MCE_20200504T084601_TCI_10m.jp2
# processing file 24 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/9/processed_T35NLB_20191205T083229_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/9/processed_T35NLB_20191205T083229_TCI_10m.jp2
# processing file 25 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/10/processed_T34MCE_20200603T084611_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/10/processed_T34MCE_20200603T084611_TCI_10m.jp2
# processing file 26 of 26
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped_v2/10/processed_T35NLB_20200203T083049_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_v2/10/processed_T35NLB_20200203T083049_TCI_10m.jp2
# Finished

# %%
def make_full_virtual_raster(src_dir, dest_dir, num_layers=10):
    """Combines the rasters in the src_dir into a single virtual raster
    with proper prioritization. This is saved into the dest_dir.
    Make sure the num_layers variable is the same as the number of tile layers
    in your src_dir."""
    
    src_dir = add_trailing_slash(src_dir)
    dest_dir = add_trailing_slash(dest_dir)
    
    # If the output folder doesn't exist, create it
    create_dir(dest_dir)
    
    
    
    for layer in range(1, num_layers+1):
        print('Making Layer', layer)
        
        # Get the filenames from the layer in question
        filenames = glob(src_dir + f'{layer}/*.jp2', recursive=True)
        
        output_file = dest_dir + f'Layer{layer}.vrt'
    
        vrt = gdal.BuildVRT(output_file, filenames, resolution='average', resampleAlg='nearest', srcNodata=0)
    
        vrt.FlushCache()
    
    print('Making full raster')

    # To make the full raster, we combine every layer. Do it in reverse order because (I believe)
    # the last items in the list are prioritized.

    input_files = [dest_dir + f'Layer{i}.vrt' for i in reversed(range(1, num_layers+1))]
    
    output_file = dest_dir + 'full_v2.vrt'

    vrt = gdal.BuildVRT(output_file, input_files, resolution='average', resampleAlg='nearest', srcNodata=0)

    vrt.FlushCache()

    print('Finished')

# %%
src_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_ordered_warped"
dest_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_master_raster_v2"

make_full_virtual_raster(src_dir, dest_dir)
# Out:
# Making Layer 1
# Making Layer 2
# Making Layer 3
# Making Layer 4
# Making Layer 5
# Making Layer 6
# Making Layer 7
# Making Layer 8
# Making Layer 9
# Making Layer 10
# Making full raster
# Finished

# %%
def vrt_to_tif(output_file,src_file):

    translate = gdal.Translate(output_file, src_file,
                               format='GTiff')
    translate.FlushCache()

# %%
src_file = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_master_raster_v2/full_v2.vrt"
output_file = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_master_raster_v2/full_tif_v2.tif"

vrt_to_tif(output_file,src_file)

# %%
def csv_to_gdf(csv_loc):
    '''
    import manually created areas of interest csv
    
    output is an in-memory geo dataframe with one polygon AOI per row to be utilized for cropping master raster
    
    '''
    df = pd.read_csv(csv_loc)
    df_labels = df[["polygon","Labels combined"]]

    #create geometry column for polygons
    polygons = []
    for polygon in df_labels["polygon"]:
        polygon_temp = []
        for coordinates in json.loads(polygon)["coordinates"]:
            for coordinate in coordinates:
                polygon_temp.append(tuple(coordinate))
            polygons.append(Polygon(polygon_temp))

    gdf_series = gpd.GeoSeries(polygons)
    gdf = gpd.GeoDataFrame(gdf_series,geometry=0)
    gdf["geometry"] = gdf[0]
    gdf = gdf.drop(columns=[0])
    
    # add Labels column 
    gdf["Labels"] = [s.strip().split(", ") for s in df_labels["Labels combined"]]
    
    return gdf

# %%
csv_loc = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/Polygon_List/polygons_100820.csv"

gdf = csv_to_gdf(csv_loc)

# %%
gdf
# Out:
#                                               geometry  \
# 0    POLYGON ((9.08878 5.75315, 9.17925 5.70311, 9....
# 1    POLYGON ((8.89189 5.80456, 8.93188 5.80302, 8....
# 2    POLYGON ((13.14840 5.59719, 13.19990 5.62265, ...
# 3    POLYGON ((14.34763 5.34181, 14.35965 5.35079, ...
# 4    POLYGON ((13.02927 5.42701, 13.10274 5.42769, ...
# ..                                                 ...
# 96   POLYGON ((18.06616 -2.71119, 18.06624 -2.70772...
# 97   POLYGON ((19.17355 -2.85123, 19.20582 -2.83863...
# 98   POLYGON ((19.27242 -3.13435, 19.15277 -3.13572...
# 99   POLYGON ((19.24650 -3.12663, 19.24650 -3.08275...
# 100  POLYGON ((18.62080 -3.18491, 18.96566 -3.18114...
#
#                                                 Labels
# 0                                    [ISL, Rainforest]
# 1                                    [ISL, Rainforest]
# 2                                    [ISL, Rainforest]
# 3                [Rainforest, Mining, Savannah, Roads]
# 4                                    [ISL, Rainforest]
# ..                                                 ...
# 96                        [Fire, Shifting cultivation]
# 97                                    [Fire, Savannah]
# 98                                   [ISL, Rainforest]
# 99                                   [ISL, Rainforest]
# 100  [Rainforest, River, Habitation, Shifting culti...
#
# [101 rows x 2 columns]

# %%
def export_aoi_polygon_rasters(gdf,master_raster_path,output_dir):
    
    output_parent_dir = add_trailing_slash(output_dir) 
    
    # create parent output directory if it doesn't exist
    create_dir(output_dir)

    src_raster_file = rio.open(master_raster_path)
    
    for index in range(gdf.shape[0]):
        
        crop_extent = gdf.loc[[index],"geometry"]
        

        try:
            raster_crop, raster_meta = es.crop_image(src_raster_file, crop_extent)
#             print(f"succesfully cropped image {index} ")
            
        except Exception:
            
            print(f"polygon on row {index} does not overlap with master raster, continuing")
            traceback.print_exc()
            
        

        # Update the metadata to have the new shape (x and y and affine information)
        raster_meta.update({"driver": "GTiff",
                         "height": raster_crop.shape[1],
                         "width": raster_crop.shape[2],
                         "transform": raster_meta["transform"]})

#         mask the nodata values
        raster_crop_ma = np.ma.masked_equal(raster_crop, 0) 
        
        
        for labels in gdf.loc[[index],"Labels"]:
            for label in labels:
                
                # output directory per label
                output_label_dir = output_parent_dir + label
                output_label_dir = add_trailing_slash(output_label_dir) 
                
                # create output directory if it doesn't exist
                create_dir(output_label_dir)
                

                # output file path
                outpath = output_label_dir + str(index+1) + '.tif'
                print(outpath)

                # Export cloud-masked TCI file
                print(f'Cropping Polygon {index + 1} for Label "{label}"')
                
                with rio.open(outpath, 'w', **raster_meta) as outf:
                    outf.write(raster_crop_ma)

# %%
master_raster_path = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_master_raster_v2/full_tif_v2.tif"
output_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/"

export_aoi_polygon_rasters(gdf,master_raster_path,output_dir)
# Out:
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/1.tif
# Cropping Polygon 0 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/1.tif
# Cropping Polygon 0 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/2.tif
# Cropping Polygon 1 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/2.tif
# Cropping Polygon 1 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/3.tif
# Cropping Polygon 2 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/3.tif
# Cropping Polygon 2 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/4.tif
# Cropping Polygon 3 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Mining/4.tif
# Cropping Polygon 3 for Label Mining
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Savannah/4.tif
# Cropping Polygon 3 for Label Savannah
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/4.tif
# Cropping Polygon 3 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/5.tif
# Cropping Polygon 4 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/5.tif
# Cropping Polygon 4 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/6.tif
# Cropping Polygon 5 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/6.tif
# Cropping Polygon 5 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/6.tif
# Cropping Polygon 5 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Habitation/6.tif
# Cropping Polygon 5 for Label Habitation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Industrial agriculture/6.tif
# Cropping Polygon 5 for Label Industrial agriculture
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/7.tif
# Cropping Polygon 6 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/7.tif
# Cropping Polygon 6 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Savannah/7.tif
# Cropping Polygon 6 for Label Savannah
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/8.tif
# Cropping Polygon 7 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Mining/8.tif
# Cropping Polygon 7 for Label Mining
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Savannah/8.tif
# Cropping Polygon 7 for Label Savannah
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Savannah/9.tif
# Cropping Polygon 8 for Label Savannah
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Industrial agriculture/9.tif
# Cropping Polygon 8 for Label Industrial agriculture
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/9.tif
# Cropping Polygon 8 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/9.tif
# Cropping Polygon 8 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Habitation/9.tif
# Cropping Polygon 8 for Label Habitation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/10.tif
# Cropping Polygon 9 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/10.tif
# Cropping Polygon 9 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Industrial agriculture/10.tif
# Cropping Polygon 9 for Label Industrial agriculture
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/10.tif
# Cropping Polygon 9 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/11.tif
# Cropping Polygon 10 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/11.tif
# Cropping Polygon 10 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Water/12.tif
# Cropping Polygon 11 for Label Water
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/13.tif
# Cropping Polygon 12 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/13.tif
# Cropping Polygon 12 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/13.tif
# Cropping Polygon 12 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/13.tif
# Cropping Polygon 12 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Habitation/13.tif
# Cropping Polygon 12 for Label Habitation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/14.tif
# Cropping Polygon 13 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Habitation/14.tif
# Cropping Polygon 13 for Label Habitation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/14.tif
# Cropping Polygon 13 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/14.tif
# Cropping Polygon 13 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Savannah/14.tif
# Cropping Polygon 13 for Label Savannah
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/15.tif
# Cropping Polygon 14 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/15.tif
# Cropping Polygon 14 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Savannah/15.tif
# Cropping Polygon 14 for Label Savannah
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/16.tif
# Cropping Polygon 15 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/16.tif
# Cropping Polygon 15 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Savannah/16.tif
# Cropping Polygon 15 for Label Savannah
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/17.tif
# Cropping Polygon 16 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/17.tif
# Cropping Polygon 16 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/17.tif
# Cropping Polygon 16 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/17.tif
# Cropping Polygon 16 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/18.tif
# Cropping Polygon 17 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Savannah/18.tif
# Cropping Polygon 17 for Label Savannah
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/18.tif
# Cropping Polygon 17 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/19.tif
# Cropping Polygon 18 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/19.tif
# Cropping Polygon 18 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Habitation/19.tif
# Cropping Polygon 18 for Label Habitation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/19.tif
# Cropping Polygon 18 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/19.tif
# Cropping Polygon 18 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/20.tif
# Cropping Polygon 19 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/20.tif
# Cropping Polygon 19 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/20.tif
# Cropping Polygon 19 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/21.tif
# Cropping Polygon 20 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/21.tif
# Cropping Polygon 20 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/22.tif
# Cropping Polygon 21 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/22.tif
# Cropping Polygon 21 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/23.tif
# Cropping Polygon 22 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Savannah/23.tif
# Cropping Polygon 22 for Label Savannah
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/24.tif
# Cropping Polygon 23 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/24.tif
# Cropping Polygon 23 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/25.tif
# Cropping Polygon 24 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/25.tif
# Cropping Polygon 24 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/26.tif
# Cropping Polygon 25 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/26.tif
# Cropping Polygon 25 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/26.tif
# Cropping Polygon 25 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/27.tif
# Cropping Polygon 26 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/27.tif
# Cropping Polygon 26 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/27.tif
# Cropping Polygon 26 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Habitation/27.tif
# Cropping Polygon 26 for Label Habitation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Industrial agriculture/27.tif
# Cropping Polygon 26 for Label Industrial agriculture
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/28.tif
# Cropping Polygon 27 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/29.tif
# Cropping Polygon 28 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/29.tif
# Cropping Polygon 28 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/29.tif
# Cropping Polygon 28 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/30.tif
# Cropping Polygon 29 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/30.tif
# Cropping Polygon 29 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/30.tif
# Cropping Polygon 29 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Habitation/30.tif
# Cropping Polygon 29 for Label Habitation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Industrial agriculture/30.tif
# Cropping Polygon 29 for Label Industrial agriculture
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/31.tif
# Cropping Polygon 30 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/31.tif
# Cropping Polygon 30 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/31.tif
# Cropping Polygon 30 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Habitation/31.tif
# Cropping Polygon 30 for Label Habitation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Industrial agriculture/31.tif
# Cropping Polygon 30 for Label Industrial agriculture
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/32.tif
# Cropping Polygon 31 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/32.tif
# Cropping Polygon 31 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/33.tif
# Cropping Polygon 32 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/33.tif
# Cropping Polygon 32 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/34.tif
# Cropping Polygon 33 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/34.tif
# Cropping Polygon 33 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/34.tif
# Cropping Polygon 33 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/35.tif
# Cropping Polygon 34 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/35.tif
# Cropping Polygon 34 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/36.tif
# Cropping Polygon 35 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/36.tif
# Cropping Polygon 35 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/36.tif
# Cropping Polygon 35 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/37.tif
# Cropping Polygon 36 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/37.tif
# Cropping Polygon 36 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/37.tif
# Cropping Polygon 36 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/38.tif
# Cropping Polygon 37 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/38.tif
# Cropping Polygon 37 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/39.tif
# Cropping Polygon 38 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/39.tif
# Cropping Polygon 38 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/40.tif
# Cropping Polygon 39 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/40.tif
# Cropping Polygon 39 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/41.tif
# Cropping Polygon 40 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/41.tif
# Cropping Polygon 40 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/42.tif
# Cropping Polygon 41 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/42.tif
# Cropping Polygon 41 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/43.tif
# Cropping Polygon 42 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/43.tif
# Cropping Polygon 42 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/44.tif
# Cropping Polygon 43 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/44.tif
# Cropping Polygon 43 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Habitation/45.tif
# Cropping Polygon 44 for Label Habitation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/45.tif
# Cropping Polygon 44 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/45.tif
# Cropping Polygon 44 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/45.tif
# Cropping Polygon 44 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/46.tif
# Cropping Polygon 45 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/46.tif
# Cropping Polygon 45 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/47.tif
# Cropping Polygon 46 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/47.tif
# Cropping Polygon 46 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/48.tif
# Cropping Polygon 47 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/48.tif
# Cropping Polygon 47 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Habitation/49.tif
# Cropping Polygon 48 for Label Habitation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/49.tif
# Cropping Polygon 48 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Industrial agriculture/49.tif
# Cropping Polygon 48 for Label Industrial agriculture
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/49.tif
# Cropping Polygon 48 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/49.tif
# Cropping Polygon 48 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/50.tif
# Cropping Polygon 49 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/50.tif
# Cropping Polygon 49 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/51.tif
# Cropping Polygon 50 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Habitation/51.tif
# Cropping Polygon 50 for Label Habitation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Habitation/52.tif
# Cropping Polygon 51 for Label Habitation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/52.tif
# Cropping Polygon 51 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Industrial agriculture/52.tif
# Cropping Polygon 51 for Label Industrial agriculture
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/52.tif
# Cropping Polygon 51 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/53.tif
# Cropping Polygon 52 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/53.tif
# Cropping Polygon 52 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/54.tif
# Cropping Polygon 53 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/54.tif
# Cropping Polygon 53 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/55.tif
# Cropping Polygon 54 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/55.tif
# Cropping Polygon 54 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/55.tif
# Cropping Polygon 54 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/56.tif
# Cropping Polygon 55 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/56.tif
# Cropping Polygon 55 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/57.tif
# Cropping Polygon 56 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/57.tif
# Cropping Polygon 56 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/58.tif
# Cropping Polygon 57 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Savannah/58.tif
# Cropping Polygon 57 for Label Savannah
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Industrial agriculture/58.tif
# Cropping Polygon 57 for Label Industrial agriculture
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/58.tif
# Cropping Polygon 57 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/59.tif
# Cropping Polygon 58 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/59.tif
# Cropping Polygon 58 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/59.tif
# Cropping Polygon 58 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/60.tif
# Cropping Polygon 59 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/60.tif
# Cropping Polygon 59 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/61.tif
# Cropping Polygon 60 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Mining/61.tif
# Cropping Polygon 60 for Label Mining
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/62.tif
# Cropping Polygon 61 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/62.tif
# Cropping Polygon 61 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/63.tif
# Cropping Polygon 62 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Mining/63.tif
# Cropping Polygon 62 for Label Mining
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/64.tif
# Cropping Polygon 63 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/64.tif
# Cropping Polygon 63 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Mining/64.tif
# Cropping Polygon 63 for Label Mining
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/65.tif
# Cropping Polygon 64 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/65.tif
# Cropping Polygon 64 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/66.tif
# Cropping Polygon 65 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Habitation/66.tif
# Cropping Polygon 65 for Label Habitation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/66.tif
# Cropping Polygon 65 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/66.tif
# Cropping Polygon 65 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/66.tif
# Cropping Polygon 65 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/67.tif
# Cropping Polygon 66 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/68.tif
# Cropping Polygon 67 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/68.tif
# Cropping Polygon 67 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/68.tif
# Cropping Polygon 67 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/69.tif
# Cropping Polygon 68 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Mining/69.tif
# Cropping Polygon 68 for Label Mining
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/69.tif
# Cropping Polygon 68 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/70.tif
# Cropping Polygon 69 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/70.tif
# Cropping Polygon 69 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/71.tif
# Cropping Polygon 70 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Water/71.tif
# Cropping Polygon 70 for Label Water
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/72.tif
# Cropping Polygon 71 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/72.tif
# Cropping Polygon 71 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/72.tif
# Cropping Polygon 71 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/73.tif
# Cropping Polygon 72 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/73.tif
# Cropping Polygon 72 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/74.tif
# Cropping Polygon 73 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/74.tif
# Cropping Polygon 73 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/74.tif
# Cropping Polygon 73 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/75.tif
# Cropping Polygon 74 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/75.tif
# Cropping Polygon 74 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/76.tif
# Cropping Polygon 75 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/76.tif
# Cropping Polygon 75 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/76.tif
# Cropping Polygon 75 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/77.tif
# Cropping Polygon 76 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/77.tif
# Cropping Polygon 76 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/78.tif
# Cropping Polygon 77 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/79.tif
# Cropping Polygon 78 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/79.tif
# Cropping Polygon 78 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/80.tif
# Cropping Polygon 79 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/80.tif
# Cropping Polygon 79 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/81.tif
# Cropping Polygon 80 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/81.tif
# Cropping Polygon 80 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Habitation/81.tif
# Cropping Polygon 80 for Label Habitation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/81.tif
# Cropping Polygon 80 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/82.tif
# Cropping Polygon 81 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/82.tif
# Cropping Polygon 81 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/83.tif
# Cropping Polygon 82 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/83.tif
# Cropping Polygon 82 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/83.tif
# Cropping Polygon 82 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/84.tif
# Cropping Polygon 83 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/84.tif
# Cropping Polygon 83 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/84.tif
# Cropping Polygon 83 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Mining/84.tif
# Cropping Polygon 83 for Label Mining
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/85.tif
# Cropping Polygon 84 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/85.tif
# Cropping Polygon 84 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/85.tif
# Cropping Polygon 84 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Savannah/85.tif
# Cropping Polygon 84 for Label Savannah
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/86.tif
# Cropping Polygon 85 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Mining/86.tif
# Cropping Polygon 85 for Label Mining
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/87.tif
# Cropping Polygon 86 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/87.tif
# Cropping Polygon 86 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Industrial agriculture/87.tif
# Cropping Polygon 86 for Label Industrial agriculture
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/87.tif
# Cropping Polygon 86 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/88.tif
# Cropping Polygon 87 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/88.tif
# Cropping Polygon 87 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/89.tif
# Cropping Polygon 88 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/89.tif
# Cropping Polygon 88 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/89.tif
# Cropping Polygon 88 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/90.tif
# Cropping Polygon 89 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/90.tif
# Cropping Polygon 89 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/91.tif
# Cropping Polygon 90 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/91.tif
# Cropping Polygon 90 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/91.tif
# Cropping Polygon 90 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/92.tif
# Cropping Polygon 91 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/92.tif
# Cropping Polygon 91 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/92.tif
# Cropping Polygon 91 for Label Roads
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Water/92.tif
# Cropping Polygon 91 for Label Water
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Habitation/92.tif
# Cropping Polygon 91 for Label Habitation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/93.tif
# Cropping Polygon 92 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/93.tif
# Cropping Polygon 92 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/93.tif
# Cropping Polygon 92 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/94.tif
# Cropping Polygon 93 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/94.tif
# Cropping Polygon 93 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Fire/95.tif
# Cropping Polygon 94 for Label Fire
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Fire/96.tif
# Cropping Polygon 95 for Label Fire
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Fire/97.tif
# Cropping Polygon 96 for Label Fire
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/97.tif
# Cropping Polygon 96 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Fire/98.tif
# Cropping Polygon 97 for Label Fire
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Savannah/98.tif
# Cropping Polygon 97 for Label Savannah
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/99.tif
# Cropping Polygon 98 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/99.tif
# Cropping Polygon 98 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/ISL/100.tif
# Cropping Polygon 99 for Label ISL
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/100.tif
# Cropping Polygon 99 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Rainforest/101.tif
# Cropping Polygon 100 for Label Rainforest
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/River/101.tif
# Cropping Polygon 100 for Label River
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Habitation/101.tif
# Cropping Polygon 100 for Label Habitation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Shifting cultivation/101.tif
# Cropping Polygon 100 for Label Shifting cultivation
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/Roads/101.tif
# Cropping Polygon 100 for Label Roads

# %%
def tif_to_jpg(in_dir,out_dir):
    
    
    
    in_dir_base = add_trailing_slash(in_dir)
    
    out_dir_base = add_trailing_slash(out_dir)
    
    # If the output parent folder doesn't exist, create it
    
    create_dir(out_dir)
    
    # List containing respective label directories
    
    in_dir_list = glob(in_dir_base + "*/")
    
    for in_dir_child in in_dir_list:
        
        label = in_dir_child.split("/")[-2]
        
        # If output child folder doesn't exist, create
        
        out_dir_child = out_dir_base + label
        
        out_dir_child = add_trailing_slash(out_dir_child)
        
        create_dir(out_dir_child)
    

        # Export Polygons from TIF to  JPEG

        tif_list = glob(in_dir_child + "*.tif",recursive=True)

        for tif_path in tif_list:
            base_filename = tif_path.split("/")[-1].split(".")[0]
            im = Image.open(tif_path)
            im.thumbnail(im.size)
            im.save(out_dir_child + base_filename + ".jpg", "JPEG", quality=100)

# %%
in_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/LabelBox/TIF"
out_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/AOI_Crops/LabelBox/JPG"

tif_to_jpg(in_dir,out_dir)

# %% [markdown]
# # AWS S3 Sandbox

# %%
import boto3

s3 = boto3.client("s3")

# %%
s3.create_bucket(Bucket="canopy-staging-download")
# Out:
# {'ResponseMetadata': {'RequestId': 'B9983BB7A06108AD',
#   'HostId': '093iFDxG/xMV+xL5hnGk6FmVqsBlEJ9Av/f+LyOqDtwRs7vup5/FzX3ajWvM7sAR6FTDFDlFy1Q=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': '093iFDxG/xMV+xL5hnGk6FmVqsBlEJ9Av/f+LyOqDtwRs7vup5/FzX3ajWvM7sAR6FTDFDlFy1Q=',
#    'x-amz-request-id': 'B9983BB7A06108AD',
#    'date': 'Tue, 13 Oct 2020 01:42:18 GMT',
#    'location': '/canopy-staging-download',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'Location': '/canopy-staging-download'}

# %%
response = s3.list_buckets()
buckets = [bucket["Name"] for bucket in response["Buckets"]]

# %%
# !aws s3
# Out:
# usage: aws [options] <command> <subcommand> [parameters]
# aws: error: too few arguments

# %%
# !aws get-current-user
# Out:
# usage: aws [options] <command> <subcommand> [<subcommand> ...] [parameters]
# To see help text, you can run:
#
#   aws help
#   aws <command> help
#   aws <command> <subcommand> help
# aws: error: argument command: Invalid choice, valid choices are:
#
# accessanalyzer                           | acm
# acm-pca                                  | alexaforbusiness
# amplify                                  | apigateway
# apigatewaymanagementapi                  | apigatewayv2
# appconfig                                | application-autoscaling
# application-insights                     | appmesh
# appstream                                | appsync
# athena                                   | autoscaling
# autoscaling-plans                        | backup
# batch                                    | budgets
# ce                                       | chime
# cloud9                                   | clouddirectory
# cloudformation                           | cloudfront
# cloudhsm                                 | cloudhsmv2
# cloudsearch                              | cloudsearchdomain
# cloudtrail                               | cloudwatch
# codebuild                                | codecommit
# codeguru-reviewer                        | codeguruprofiler
# codepipeline                             | codestar
# codestar-connections                     | codestar-notifications
# cognito-identity                         | cognito-idp
# cognito-sync                             | comprehend
# comprehendmedical                        | compute-optimizer
# connect                                  | connectparticipant
# cur                                      | dataexchange
# datapipeline                             | datasync
# dax                                      | detective
# devicefarm                               | directconnect
# discovery                                | dlm
# dms                                      | docdb
# ds                                       | dynamodb
# dynamodbstreams                          | ebs
# ec2                                      | ec2-instance-connect
# ecr                                      | ecs
# efs                                      | eks
# elastic-inference                        | elasticache
# elasticbeanstalk                         | elastictranscoder
# elb                                      | elbv2
# emr                                      | es
# events                                   | firehose
# fms                                      | forecast
# forecastquery                            | frauddetector
# fsx                                      | gamelift
# glacier                                  | globalaccelerator
# glue                                     | greengrass
# groundstation                            | guardduty
# health                                   | iam
# imagebuilder                             | importexport
# inspector                                | iot
# iot-data                                 | iot-jobs-data
# iot1click-devices                        | iot1click-projects
# iotanalytics                             | iotevents
# iotevents-data                           | iotsecuretunneling
# iotsitewise                              | iotthingsgraph
# kafka                                    | kendra
# kinesis                                  | kinesis-video-archived-media
# kinesis-video-media                      | kinesis-video-signaling
# kinesisanalytics                         | kinesisanalyticsv2
# kinesisvideo                             | kms
# lakeformation                            | lambda
# lex-models                               | lex-runtime
# license-manager                          | lightsail
# logs                                     | machinelearning
# macie                                    | managedblockchain
# marketplace-catalog                      | marketplace-entitlement
# marketplacecommerceanalytics             | mediaconnect
# mediaconvert                             | medialive
# mediapackage                             | mediapackage-vod
# mediastore                               | mediastore-data
# mediatailor                              | meteringmarketplace
# mgh                                      | migrationhub-config
# mobile                                   | mq
# mturk                                    | neptune
# networkmanager                           | opsworks
# opsworkscm                               | organizations
# outposts                                 | personalize
# personalize-events                       | personalize-runtime
# pi                                       | pinpoint
# pinpoint-email                           | pinpoint-sms-voice
# polly                                    | pricing
# qldb                                     | qldb-session
# quicksight                               | ram
# rds                                      | rds-data
# redshift                                 | rekognition
# resource-groups                          | resourcegroupstaggingapi
# robomaker                                | route53
# route53domains                           | route53resolver
# s3control                                | sagemaker
# sagemaker-a2i-runtime                    | sagemaker-runtime
# savingsplans                             | schemas
# sdb                                      | secretsmanager
# securityhub                              | serverlessrepo
# service-quotas                           | servicecatalog
# servicediscovery                         | ses
# sesv2                                    | shield
# signer                                   | sms
# sms-voice                                | snowball
# sns                                      | sqs
# ssm                                      | sso
# sso-oidc                                 | stepfunctions
# storagegateway                           | sts
# support                                  | swf
# synthetics                               | textract
# transcribe                               | transfer
# translate                                | waf
# waf-regional                             | wafv2
# workdocs                                 | worklink
# workmail                                 | workmailmessageflow
# workspaces                               | xray
# s3api                                    | s3
# configure                                | deploy
# configservice                            | opsworks-cm
# runtime.sagemaker                        | history
# help

# %% [markdown]
# # Testing Cloud Masking Code

# %%
def cloud_mask_tci(prod_dir):
    
    '''
    
    prod refers product directory 
    
    '''
    
    prod_dir = add_trailing_slash(prod_dir)
    
    msk_file_path = glob(prod_dir + "*/MSK_CLDPRB_20m.jp2")[0]
    print(msk_file_path)
    tci_file_path = glob(prod_dir + "IMG_DATA/R10m/*.jp2")[0]
    print(tci_file_path)
    tci_filename = tci_file_path.split("/")[-1]
    output_tci_file_path = prod_dir + "/IMG_DATA/R10m/" + "processed_2_" + tci_filename 

    nodatavalue = int(0)

    with rio.open(tci_file_path) as sen_TCI_src:
        sen_TCI = sen_TCI_src.read(masked=True)
        sen_TCI_meta = sen_TCI_src.meta

    with rio.open(msk_file_path) as sen_mask_src:
        sen_mask_pre = sen_mask_src.read(1)
        sen_mask = np.repeat(np.repeat(sen_mask_pre,2,axis=0),2,axis=1)

    # All pixels above 0 probability will be classified as True

    sen_mask_qa = sen_mask > 0


    # Apply mask to source TCI file
#     if np.count_nonzero(sen_mask_qa) > 0:
    sen_TCI_cl_free_nan = em.mask_pixels(sen_TCI, sen_mask_qa)
    sen_TCI_cl_free_processed = np.ma.filled(sen_TCI_cl_free_nan, fill_value=nodatavalue)
        
#     else:
#         sen_TCI_cl_free_processed = sen_mask_qa
    
#     # If file shape only has one band (dimension), generate correct shape for export
    
#     if len(sen_TCI_cl_free_processed.shape) < 3:
#         sen_TCI_cl_free_processed = np.array((sen_TCI_cl_free_processed,sen_TCI_cl_free_processed,sen_TCI_cl_free_processed))
#         sen_TCI_cl_free_processed = sen_TCI_cl_free_processed.astype(np.uint8)

    # Export cloud-masked TCI file
    with rio.open(output_tci_file_path, 'w',**sen_TCI_meta) as outf:
        outf.write(sen_TCI_cl_free_processed)

# %%
cloud_mask_tci("/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A017722_20200728T085918")
# Out:
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A017722_20200728T085918/QI_DATA/MSK_CLDPRB_20m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A017722_20200728T085918/IMG_DATA/R10m/T34MBC_20200728T084559_TCI_10m.jp2

# %% [markdown]
# # Testing Metadata Dataframe Creation

# %%
def generate_product_detail_df(input_dir):
    
    '''
    Generate product details dataframe used as input for ordering products by Cloudy Pixel Percentage, No Data Pixel Percentage, or Unclassified Percentage
    
    '''
    input_dir = add_trailing_slash(input_dir)
    
    dirs = os.listdir(input_dir)

    meta_data = []
    for folder in dirs:
        xml_loc = glob(input_dir + "/" + folder + "/*.xml")[0]
        tree = ET.parse(xml_loc)
        directory = [elem.text for elem in tree.iter() if "MASK_FILENAME" in elem.tag][0].split("/")[1]
        tile_id = directory.split("_")[1]
        filepath_partial = input_dir + "/" + directory + "/IMG_DATA" + "/R10m"
        filepath = glob(filepath_partial + "/processed*.jp2")[0]
        filename = filepath.split("/")[-1]
        cloud_cover,no_data,unclassified = [float(elem.text) for elem in tree.iter() if "CLOUDY_PIXEL_PERCENTAGE" in elem.tag 
                 or "NODATA_PIXEL_PERCENTAGE" in elem.tag or "UNCLASSIFIED_PERCENTAGE" in elem.tag]
        meta_data.append([directory,tile_id,cloud_cover,no_data,unclassified,filename,filepath])
    df = pd.DataFrame(meta_data,columns=["Directory","Tile_Id","Cloud Cover","No Data Percentage","Unclassified Percentage","Filename","Filepath"])
    df2 = df.sort_values(by=["Tile_Id","Cloud Cover","Unclassified Percentage"],ignore_index=True)
    return df2

# %%
df = generate_product_detail_df(input_dir)

# %%
df
# Out:
#                               Directory Tile_Id  Cloud Cover  \
# 0    L2A_T32NMK_A015077_20200125T095047  T32NMK     3.746630
# 1    L2A_T32NMK_A014791_20200105T095703  T32NMK     9.728458
# 2    L2A_T32NMK_A024343_20200219T095439  T32NMK    10.375307
# 3    L2A_T32NMK_A018480_20190105T095815  T32NMK    12.898219
# 4    L2A_T32NMK_A014505_20191216T095042  T32NMK    14.797034
# ..                                  ...     ...          ...
# 483  L2A_T35NLB_A019037_20190213T084055  T35NLB     3.899672
# 484  L2A_T35NLB_A023613_20191230T084321  T35NLB     4.121645
# 485  L2A_T35NLB_A014347_20191205T083849  T35NLB     5.536621
# 486  L2A_T35NLB_A015205_20200203T084711  T35NLB     6.972405
# 487  L2A_T35NLB_A009628_20190109T083800  T35NLB    30.178366
#
#      No Data Percentage  Unclassified Percentage  \
# 0              0.000000                 1.804589
# 1              0.000000                 2.432975
# 2              0.000000                 7.602649
# 3              0.000000                 4.594089
# 4              0.000000                 1.208974
# ..                  ...                      ...
# 483            0.000000                 0.273543
# 484            0.000000                 0.004230
# 485            0.000000                 5.679570
# 486            0.000000                 3.153487
# 487           36.006102                29.398388
#
#                                          Filename  \
# 0    processed_T32NMK_20200125T094159_TCI_10m.jp2
# 1    processed_T32NMK_20200105T094309_TCI_10m.jp2
# 2    processed_T32NMK_20200219T094031_TCI_10m.jp2
# 3    processed_T32NMK_20190105T094401_TCI_10m.jp2
# 4    processed_T32NMK_20191216T094319_TCI_10m.jp2
# ..                                            ...
# 483  processed_T35NLB_20190213T083041_TCI_10m.jp2
# 484  processed_T35NLB_20191230T083341_TCI_10m.jp2
# 485  processed_T35NLB_20191205T083229_TCI_10m.jp2
# 486  processed_T35NLB_20200203T083049_TCI_10m.jp2
# 487  processed_T35NLB_20190109T083329_TCI_10m.jp2
#
#                                               Filepath
# 0    /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
# 1    /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
# 2    /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
# 3    /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
# 4    /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
# ..                                                 ...
# 483  /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
# 484  /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
# 485  /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
# 486  /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
# 487  /Volumes/Lacie/zhenyadata/Project_Canopy_Data/...
#
# [488 rows x 7 columns]

# %%
def import_aois(csv_loc):    

    df_labels = pd.read_csv(csv_loc)
    df_labels = df_labels[["center-lat","center-long","polygon","Labels combined"]]

    polygons = []
    for polygon in df_labels["polygon"]:
        polygons.append(json.loads(polygon)["coordinates"])


    tiles = []
    tiles_dic = {}
    polygon_id = 0 
    coordinates = []
    for items in polygons:
        polygon_id += 1 
        for item in items:
            for lon_lat in item:
                coordinates.append(lon_lat)
                tile = encode(LLtoUTM(lon_lat[1],lon_lat[0]),1)[:-2]
                

                if polygon_id in tiles_dic:

                    tiles_dic[polygon_id].append(tile)

                else:

                    tiles_dic[polygon_id] = [tile]

                tiles.append(tile)

            tiles_dic[polygon_id] = list(set(tiles_dic[polygon_id]))

    tiles = list(set(tiles))

    df_labels["tiles"] = tiles_dic.values()

    #bounding box

    min_lon = min([i[0] for i in coordinates])
    min_lat = min([i[1] for i in coordinates])
    max_lon = max([i[0] for i in coordinates])
    max_lat = max([i[1] for i in coordinates])

    bounding_box = min_lon,min_lat,max_lon,max_lat
    
    return df_labels,bounding_box,tiles

# %%
import_aois(csv_loc)
# Out:
# (     center-lat  center-long  \
#  0       5.77459      9.16861
#  1       5.75499      8.92339
#  2       5.59555     13.18814
#  3       5.35518     14.33673
#  4       5.33908     13.10411
#  ..          ...          ...
#  96     -2.70602     18.07841
#  97     -2.85049     19.19509
#  98     -3.08219     19.18118
#  99     -3.08245     19.16616
#  100    -3.27737     18.82696
#
#                                                 polygon  \
#  0    {"type":"Polygon","coordinates":[[[9.088783,5....
#  1    {"type":"Polygon","coordinates":[[[8.891888,5....
#  2    {"type":"Polygon","coordinates":[[[13.148403,5...
#  3    {"type":"Polygon","coordinates":[[[14.34763,5....
#  4    {"type":"Polygon","coordinates":[[[13.02927,5....
#  ..                                                 ...
#  96   {"type":"Polygon","coordinates":[[[18.066158,-...
#  97   {"type":"Polygon","coordinates":[[[19.173546,-...
#  98   {"type":"Polygon","coordinates":[[[19.272423,-...
#  99   {"type":"Polygon","coordinates":[[[19.246502,-...
#  100  {"type":"Polygon","coordinates":[[[18.620796,-...
#
#                                         Labels combined           tiles
#  0                                      ISL, Rainforest         [32NNM]
#  1                                      ISL, Rainforest         [32NMM]
#  2                                      ISL, Rainforest  [33NTG, 33NUG]
#  3                  Rainforest, Mining, Savannah, Roads         [33NVF]
#  4                                      ISL, Rainforest  [33NTG, 33NTF]
#  ..                                                 ...             ...
#  96                          Fire, Shifting cultivation  [34MAC, 34MAB]
#  97                                      Fire, Savannah  [34MCB, 34MBB]
#  98                                     ISL, Rainforest  [34MCB, 34MBB]
#  99                                     ISL, Rainforest  [34MCB, 34MBB]
#  100  Rainforest, River, Habitation, Shifting cultiv...         [34MBB]
#
#  [101 rows x 5 columns],
#  (8.42823, -3.373256, 25.688438, 5.845887),
#  ['33MVV',
#   '33NTE',
#   '33NWE',
#   '32NRK',
#   '33NUB',
#   '32NPG',
#   '33NUC',
#   '33NUG',
#   '32NMK',
#   '33NZD',
#   '33NVE',
#   '33NXD',
#   '33NVD',
#   '33NTG',
#   '34NDF',
#   '34MCE',
#   '35NLB',
#   '33NXE',
#   '34MBC',
#   '34MAC',
#   '33NTC',
#   '33NVF',
#   '34MCB',
#   '34NCH',
#   '32NMM',
#   '34NEH',
#   '33MWV',
#   '34NDG',
#   '33NTB',
#   '34NEF',
#   '33NUD',
#   '34NAJ',
#   '33NWC',
#   '34MAB',
#   '34MBB',
#   '32NQH',
#   '33NYC',
#   '33NWA',
#   '33NUF',
#   '34NDH',
#   '33NWD',
#   '33NUE',
#   '33NWB',
#   '33NVC',
#   '33NYB',
#   '33NTD',
#   '34NFH',
#   '32NNM',
#   '32NRH',
#   '33NXB',
#   '33NYD',
#   '33NVA',
#   '33NSE',
#   '33NSD',
#   '34NFG',
#   '34NGG',
#   '33MZT',
#   '32NQG',
#   '33NSF',
#   '33NXC',
#   '33NYE',
#   '33NTF',
#   '32NML'])
