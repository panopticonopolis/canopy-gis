# %%
# Sentinel Hub Config

from env_vars import sentinel_hub_instance_id
from sentinelhub import SHConfig

# Import Area of Interest List

import pandas as pd
import json
from scripts.mgrs import encode,LLtoUTM


# Sentinel Hub Tile Look Up / Download

from sentinelhub import WebFeatureService, BBox, CRS, DataSource, AwsTileRequest


# Cloud Masking

import rasterio as rio
import numpy as np
import earthpy.mask as em

# Generate Product Detail DataFrame

import os
from glob import glob
import xml.etree.ElementTree as ET


# Sort / Organize Tiles by Individual Folders

from shutil import copyfile

# Reproject Masked Files 

import gdal
from glob import glob

# Create Master Raster


# Extract Polygon crops from products

import pandas as pd
from shapely.geometry import Polygon
import geopandas as gpd
from geopandas import GeoDataFrame
import earthpy.spatial as es

# TIF to JPG

from PIL import Image

# %%
gdal.UseExceptions()

# %%
def add_trailing_slash(path):
    if path[-1] != '/':
        path += '/'
    return path

# %%
def create_dir(output_dir):
    # If the output folder doesn't exist, create it
    if not os.path.isdir(output_dir):
        os.mkdir(output_dir)

# %%
def shub_connect(sentinel_hub_instance_id):

    INSTANCE_ID = sentinel_hub_instance_id  

    if INSTANCE_ID:
        config = SHConfig()
        config.instance_id = INSTANCE_ID
    else:
        config = None
        
    return config

# %%
config = shub_connect(sentinel_hub_instance_id)

# %%
df_labels = pd.read_csv("/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/Polygon_List/polygons_100620.csv")
df_labels = df_labels[["center-lat","center-long","polygon","Labels (combined)"]]

polygons = []
for polygon in df_labels["polygon"]:
    polygons.append(json.loads(polygon)["coordinates"])


tiles = []
tiles_dic = {}
polygon_id = 0 
for items in polygons:
    polygon_id += 1 
    for item in items:
        for lon_lat in item:
            
            tile = encode(LLtoUTM(lon_lat[1],lon_lat[0]),1)[:-2]
            
            if polygon_id in tiles_dic:
                
                tiles_dic[polygon_id].append(tile)
                
            else:
                
                tiles_dic[polygon_id] = [tile]
                
            tiles.append(tile)
            
        tiles_dic[polygon_id] = list(set(tiles_dic[polygon_id]))
            
tiles = list(set(tiles))

df_labels["tiles"] = tiles_dic.values()

#bounding box

min_lon = min([i[0] for i in coordinates])
min_lat = min([i[1] for i in coordinates])
max_lon = max([i[0] for i in coordinates])
max_lat = max([i[1] for i in coordinates])

bounding_box = min_lon,min_lat,max_lon,max_lat
# Out:
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
def import_aois(csv_loc):    

    df_labels = pd.read_csv(csv_loc)
    df_labels = df_labels[["center-lat","center-long","polygon","Labels combined"]]

    polygons = []
    for polygon in df_labels["polygon"]:
        polygons.append(json.loads(polygon)["coordinates"])


    tiles = []
    tiles_dic = {}
    polygon_id = 0 
    for items in polygons:
        polygon_id += 1 
        for item in items:
            for lon_lat in item:

                tile = encode(LLtoUTM(lon_lat[1],lon_lat[0]),1)[:-2]

                if polygon_id in tiles_dic:

                    tiles_dic[polygon_id].append(tile)

                else:

                    tiles_dic[polygon_id] = [tile]

                tiles.append(tile)

            tiles_dic[polygon_id] = list(set(tiles_dic[polygon_id]))

    tiles = list(set(tiles))

    df_labels["tiles"] = tiles_dic.values()

    #bounding box

    min_lon = min([i[0] for i in coordinates])
    min_lat = min([i[1] for i in coordinates])
    max_lon = max([i[0] for i in coordinates])
    max_lat = max([i[1] for i in coordinates])

    bounding_box = min_lon,min_lat,max_lon,max_lat
    
    return df_labels,bounding_box,tile_list

# %%
df,bounding_box,tile_list = import_aois("/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/Polygon_List/polygons_100720.csv")

# %%
def shub_lookup_tiles(bounding_box,tile_list,search_time_interval = ('2019-01-01T00:00:00', '2020-12-31T23:59:59'),
                   product_type = DataSource.SENTINEL2_L2A):
    
    #Misha's Tiles of Interest
    search_bbox = BBox(bbox=bounding_box, crs=CRS.WGS84)

    search_time_interval = ('2019-01-01T00:00:00', '2020-12-31T23:59:59')
    wfs_iterator = WebFeatureService(
        search_bbox,
        search_time_interval,
        data_source=product_type,
        maxcc=.05,
        config=config
    )
    results = wfs_iterator.get_tiles()
    df = pd.DataFrame(results, columns=['Tilename','Date','AmazonID'])
    df_tiles_of_interest = df[df["Tilename"].isin(tile_list)]
    df2 = df_tiles_of_interest.groupby('Tilename').head(10)
    output2 = list(df2.itertuples(index=False,name=None))
    return output2

# %%
results_list = shub_lookup_tiles(bounding_box,tile_list,search_time_interval = ('2019-01-01T00:00:00', '2020-12-31T23:59:59'),
                   product_type = DataSource.SENTINEL2_L2A)

# %%
def shub_download_tiles(results_list,output_dir,bands=["R10m/TCI"],product_type = DataSource.SENTINEL2_L2A):
    
    #Additional Params
    bands = bands
    
    output_dir = add_trailing_slash(output_dir)
    create_dir(output_dir)
    
    
    for tile in results_list:
        tile_name, time, aws_index = tile

        #Download SAFE Files
        request = AwsTileRequest(
            tile=tile_name,
            time=time,
            bands = bands, 
            aws_index=aws_index,
            data_folder=output_dir,
            data_source=product_type,
            safe_format = True
        )

        request.save_data(redownload=True)

# %%
output_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw"

shub_download_tiles(results_list,output_dir,bands=["R10m/TCI"],product_type = DataSource.SENTINEL2_L2A)
# Out:
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.14 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# ...
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.13 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.12 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.12 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.12 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.12 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.12 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)
# /Users/purgatorid/opt/anaconda3/envs/pc_staging/lib/python3.8/site-packages/sentinelhub/aws.py:164: SHUserWarning: Products with baseline 02.12 are not officially supported in sentinelhub-py. If you notice any errors in naming structure of downloaded data please report an issue at https://github.com/sentinel-hub/sentinelhub-py/issues. Pull requests are also very appreciated
#   warnings.warn(message, category=SHUserWarning)

# %%
glob("/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXB_A027603_20201004T091931/" + "IMG_DATA/R10m/*.jp2")[0]
# Out:
# '/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXB_A027603_20201004T091931/IMG_DATA/R10m/T33NXB_20201004T085831_TCI_10m.jp2'

# %%
def cloud_mask_tci(prod_dir):
    
    '''
    
    prod refers product directory 
    
    '''
    
    prod_dir = add_trailing_slash(prod_dir)
    
    msk_file_path = glob(prod_dir + "*/MSK_CLDPRB_20m.jp2")[0]
    tci_file_path = glob(prod_dir + "IMG_DATA/R10m/*.jp2")[0]
    tci_filename = tci_file_path.split("/")[-1]
    output_tci_file_path = prod_dir + "/IMG_DATA/R10m/" + "processed_" + tci_filename 

    nodatavalue = int(0)

    with rio.open(tci_file_path) as sen_TCI_src:
        sen_TCI = sen_TCI_src.read(masked=True)
        sen_TCI_meta = sen_TCI_src.meta

    with rio.open(msk_file_path) as sen_mask_src:
        sen_mask_pre = sen_mask_src.read(1)
        sen_mask = np.repeat(np.repeat(sen_mask_pre,2,axis=0),2,axis=1)

    # All pixels above 0 probability will be classified as True

    sen_mask_qa = sen_mask > 0


    # Apply mask to source TCI file
    if np.count_nonzero(sen_mask_qa) > 0:
        sen_TCI_cl_free_nan = em.mask_pixels(sen_TCI, sen_mask_qa)
        sen_TCI_cl_free_processed = np.ma.filled(sen_TCI_cl_free_nan, fill_value=nodatavalue)
        
    else:
        sen_TCI_cl_free_processed = sen_mask_qa
    
    # If file shape only has one band (dimension), generate correct shape for export
    
    if len(sen_TCI_cl_free_processed.shape) < 3:
        sen_TCI_cl_free_processed = np.array((sen_TCI_cl_free_processed,sen_TCI_cl_free_processed,sen_TCI_cl_free_processed))
        sen_TCI_cl_free_processed = sen_TCI_cl_free_processed.astype(np.uint8)

    # Export cloud-masked TCI file
    with rio.open(output_tci_file_path, 'w',**sen_TCI_meta) as outf:
        outf.write(sen_TCI_cl_free_processed)

# %%
def apply_mask_tci_safe_list(products_dir):
    '''
    
    products_dir refers to parent directory containing multiple products
    
    
    '''
    
    products_dir = add_trailing_slash(products_dir)
    
    dir_list = glob(products_dir + "/*/" )
    
    
    for directory in dir_list:
        print(f'Processing {dir_list.index(directory) + 1} of {len(dir_list)}')
        if directory in processed:
            print(f'Already processed {directory}')
            continue
        else:
            print(f'Applying mask on {directory}')
            cloud_mask_tci(directory)
        
    print(f"Applied masks to {len(dir_list)} products")

# %%
tci_folder_list = output_dir
apply_mask_tci_safe_list(tci_folder_list)
# Out:
# Processing 1 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXB_A027603_20201004T091931/
# Processing 2 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYB_A027603_20201004T091931/
# Processing 3 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NCH_A027603_20201004T091931/
# Processing 4 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NZD_A027603_20201004T091931/
# Processing 5 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NZD_A027603_20201004T090335/
# Processing 6 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MVV_A018666_20201002T092142/
# Processing 7 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWC_A018666_20201002T092142/
# Processing 8 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NDH_A027560_20201001T085947/
# Processing 9 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYC_A027503_20200927T092758/
# Processing 10 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBB_A018580_20200926T090258/
# Processing 11 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NCH_A018580_20200926T090258/
# Processing 12 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYC_A018523_20200922T091949/
# Processing 13 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWE_A018523_20200922T091949/
# Processing 14 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVF_A018523_20200922T091949/
# Processing 15 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYB_A018337_20200909T091030/
# Processing 16 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MZT_A018294_20200906T090201/
# Processing 17 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEF_A018294_20200906T090201/
# Processing 18 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MZT_A027174_20200904T090335/
# Processing 19 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A027174_20200904T090335/
# Processing 20 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXB_A027174_20200904T090335/
# Processing 21 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYB_A027174_20200904T090335/
# Processing 22 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXC_A027174_20200904T090335/
# Processing 23 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYC_A027174_20200904T090335/
# Processing 24 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NCH_A027174_20200904T090335/
# Processing 25 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEH_A018251_20200903T085912/
# Processing 26 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A018194_20200830T091400/
# Processing 27 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A027031_20200825T092011/
# Processing 28 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEF_A026945_20200819T084315/
# Processing 29 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NCH_A018008_20200817T090516/
# Processing 30 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEF_A017965_20200814T085123/
# Processing 31 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBB_A026845_20200812T090428/
# Processing 32 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MCB_A026845_20200812T090428/
# Processing 33 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MZT_A026845_20200812T090428/
# Processing 34 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A026845_20200812T090428/
# Processing 35 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A017908_20200810T091451/
# Processing 36 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXB_A017908_20200810T091451/
# Processing 37 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MVV_A026788_20200808T093036/
# Processing 38 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MWV_A026788_20200808T093036/
# Processing 39 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVA_A026788_20200808T093036/
# Processing 40 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWA_A026788_20200808T093036/
# Processing 41 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MWV_A026788_20200808T091204/
# Processing 42 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVA_A026788_20200808T091204/
# Processing 43 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWA_A026788_20200808T091204/
# Processing 44 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBB_A017865_20200807T090515/
# Processing 45 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MZT_A017865_20200807T090515/
# Processing 46 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A017865_20200807T090515/
# Processing 47 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEF_A017865_20200807T090515/
# Processing 48 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MZT_A026745_20200805T091544/
# Processing 49 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A026745_20200805T091544/
# Processing 50 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MWV_A026745_20200805T091544/
# Processing 51 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MZT_A017765_20200731T091349/
# Processing 52 of 462
# Already processed /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34MBC_A
of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTG_A024400_20200223T093253/
# Processing 211 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUG_A024400_20200223T093253/
# Processing 212 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NNM_A015463_20200221T094825/
# Processing 213 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTF_A015463_20200221T094825/
# Processing 214 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTG_A015463_20200221T094825/
# Processing 215 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MVV_A024357_20200220T091348/
# Processing 216 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVA_A024357_20200220T091348/
# Processing 217 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWA_A024357_20200220T091348/
# Processing 218 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUB_A024357_20200220T091348/
# Processing 219 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWB_A024357_20200220T091348/
# Processing 220 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXB_A024357_20200220T091348/
# Processing 221 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYD_A024357_20200220T091348/
# Processing 222 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYE_A024357_20200220T091348/
# Processing 223 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NMK_A024343_20200219T095439/
# Processing 224 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NMM_A024343_20200219T095439/
# Processing 225 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NNM_A024343_20200219T095439/
# Processing 226 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTE_A015420_20200218T093533/
# Processing 227 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUF_A015420_20200218T093533/
# Processing 228 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVF_A015420_20200218T093533/
# Processing 229 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTG_A015420_20200218T093533/
# Processing 230 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUG_A015420_20200218T093533/
# Processing 231 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NRK_A024300_20200216T093801/
# Processing 232 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NNM_A024300_20200216T093801/
# Processing 233 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTF_A024300_20200216T093801/
# Processing 234 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTG_A024300_20200216T093801/
# Processing 235 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33MVV_A015377_20200215T092112/
# Processing 236 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVA_A015377_20200215T092112/
# Processing 237 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWA_A015377_20200215T092112/
# Processing 238 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUB_A015377_20200215T092112/
# Processing 239 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWB_A015377_20200215T092112/
# Processing 240 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWC_A015377_20200215T092112/
# Processing 241 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXC_A015377_20200215T092112/
# Processing 242 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWD_A015377_20200215T092112/
# Processing 243 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXD_A015377_20200215T092112/
# Processing 244 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYD_A015377_20200215T092112/
# Processing 245 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVE_A015377_20200215T092112/
# Processing 246 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NWE_A015377_20200215T092112/
# Processing 247 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NXE_A015377_20200215T092112/
# Processing 248 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NYE_A015377_20200215T092112/
# Processing 249 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVF_A015377_20200215T092112/
# Processing 250 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NMK_A015363_20200214T095912/
# Processing 251 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NML_A015363_20200214T095912/
# Processing 252 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NML_A015363_20200214T094641/
# Processing 253 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NMM_A015363_20200214T094641/
# Processing 254 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NNM_A015363_20200214T094641/
# Processing 255 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NDF_A024271_20200214T090049/
# Processing 256 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEF_A024271_20200214T090049/
# Processing 257 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NDG_A024271_20200214T090049/
# Processing 258 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NDH_A024271_20200214T090049/
# Processing 259 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NEH_A024271_20200214T090049/
# Processing 260 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTD_A024257_20200213T093321/
# Processing 261 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUD_A024257_20200213T093321/
# Processing 262 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVD_A024257_20200213T093321/
# Processing 263 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NRK_A024257_20200213T093321/
# Processing 264 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTE_A024257_20200213T093321/
# Processing 265 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUE_A024257_20200213T093321/
# Processing 266 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NVE_A024257_20200213T093321/
# Processing 267 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTF_A024257_20200213T093321/
# Processing 268 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUF_A024257_20200213T093321/
# Processing 269 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTG_A024257_20200213T093321/
# Processing 270 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NUG_A024257_20200213T093321/
# Processing 271 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NQG_A015320_20200211T094701/
# Processing 272 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NRK_A015320_20200211T094701/
# Processing 273 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T32NNM_A015320_20200211T094701/
# Processing 274 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTF_A015320_20200211T094701/
# Processing 275 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T33NTG_A015320_20200211T094701/
# Processing 276 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NFG_A024228_20200211T085547/
# Processing 277 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NGG_A024228_20200211T085547/
# Processing 278 of 462
# Applying mask on /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/SAFE_true_raw/L2A_T34NFH_A024228_20200211T085547/

# %%
# Generate array of processed directories if error during masking code
processed = []
with open("./data/processed.txt","r") as f:
    for lin in f:
        processed.append(lin.split("\n")[0])

# %%
def generate_product_detail_df(input_dir):
    
    '''
    Generate product details dataframe used as input for ordering products by Cloudy Pixel Percentage, No Data Pixel Percentage, or Unclassified Percentage
    
    '''
    input_dir = add_trailing_slash(input_dir)
    
    dirs = os.listdir(input_dir)

    meta_data = []
    for folder in dirs:
        xml_loc = glob(input_dir + "/" + folder + "/*.xml")[0]
        tree = ET.parse(xml_loc)
        directory = [elem.text for elem in tree.iter() if "MASK_FILENAME" in elem.tag][0].split("/")[1]
        tile_id = directory.split("_")[1]
        filepath_partial = input_dir + "/" + directory + "/IMG_DATA" + "/R10m"
        filepath = glob(filepath_partial + "/processed*.jp2")[0]
        filename = filepath.split("/")[-1]
        cloud_cover,no_data,unclassified = [elem.text for elem in tree.iter() if "CLOUDY_PIXEL_PERCENTAGE" in elem.tag 
                 or "NODATA_PIXEL_PERCENTAGE" in elem.tag or "UNCLASSIFIED_PERCENTAGE" in elem.tag]
        meta_data.append([directory,tile_id,cloud_cover,no_data,unclassified,filename,filepath])
    df = pd.DataFrame(meta_data,columns=["Directory","Tile_Id","Cloud Cover","No Data Percentage","Unclassified Percentage","Filename","Filepath"])
    df2 = df.sort_values(by=["Tile_Id","Cloud Cover","Unclassified Percentage"],ignore_index=True)
    return df2

# %%
input_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/test_raw"

df = generate_product_detail_df(input_dir)

# %%
def order_masked_tiles(df,output_dir):
    
    '''
    
    df input is the products detail pre-sorted dataframe to be used for sorting products 
    
    '''
    
    output_dir = add_trailing_slash(output_dir)

    layer = 1
    for index,row in df.iterrows(): 
        destination_dir = output_dir + str(layer)
        output_file = destination_dir + "/" + row["Filename"]

        # Check if directory exists
        if not os.path.isdir(destination_dir):
            os.mkdir(destination_dir)

        # Copy file to existing or new directory
        copyfile(row["Filepath"],output_file)

        # Check if Tile_Id already exists in the directory - only necessary up until the last tile
        if len(df) > index + 1:
            if df.loc[index,"Tile_Id"] == df.loc[index + 1,"Tile_Id"]:
                layer += 1
            else:
                layer = 1

# %%
order_masked_tiles(df,"/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/test_ordered/")

# %%
def csv_to_gdf(csv_loc):
    '''
    import manually created areas of interest csv
    
    output is an in-memory geo dataframe with one polygon AOI per row to be utilized for cropping master raster
    
    '''
    df = pd.read_csv(csv_loc)
    df_labels = df[["center-lat","center-long","polygon"]][0:33]


    polygons = []
    for polygon in df_labels["polygon"]:
        polygon_temp = []
        for coordinates in json.loads(polygon)["coordinates"]:
            for coordinate in coordinates:
                polygon_temp.append(tuple(coordinate))
            polygons.append(Polygon(polygon_temp))

    gdf_series = gpd.GeoSeries(polygons)
    gdf = gpd.GeoDataFrame(gdf_series,geometry=0)
    gdf["geometry"] = gdf[0]
    gdf = gdf.drop(columns=[0])
    return gdf

# %%
csv_loc = "/Users/purgatorid/Documents/GitHub/canopy-gis/data_collection/data/labelled/labels_Misha_v2.csv"

gdf = csv_to_gdf(csv_loc)

# %%
def convert_rasters(src_dir, dest_dir, epsg_format='EPSG:4326', windows=False):
    """Converts the rasters in the src_dir into a different EPSG format,
    keeping the same folder structure and saving them in the dest_dir."""

    src_dir = add_trailing_slash(src_dir)
    dest_dir = add_trailing_slash(dest_dir)
    
    # If the output folder doesn't exist, create it
    create_dir(dest_dir)

    input_files = glob(src_dir + '*/*.jp2')
    # Keep track of how many files were converted
    n = 1
    total = len(input_files)
    
    for f in input_files:
        print(f'processing file {n} of {total}')
        n += 1
        
        # The way we've set it up, we save each product into a numbered folder,
        # depending on which layer it's in. To keep this structure, we need to
        # pull out the folder number from the file path.
        # How exactly to do this depends on if you're using Windows or not,
        # since the path conventions are different.
        if windows:
            folder_num = f.split('\\')[-2]
            filename = f.split('\\')[-1]
        else:
            folder_num = f.split('/')[-2]
            filename = f.split('/')[-1]
        output_folder = dest_dir + folder_num + '/'
        
        
        # If the respective grouping folders are not available 
        create_dir(output_folder)
        
        output_filepath = output_folder + filename
        
        print(output_filepath)
        print(f)

        # Finally, we convert
        converted = gdal.Warp(output_filepath, [f],format='GTiff',
                              dstSRS=epsg_format, resampleAlg='near')
        converted = None
        
    print('Finished')

# %%
src_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/test_ordered"
dest_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/test_ordered_warped"

convert_rasters(src_dir, dest_dir)
# Out:
# processing file 1 of 4
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/test_ordered_warped/1/processed_T33NYC_20200927T090731_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/test_ordered/1/processed_T33NYC_20200927T090731_TCI_10m.jp2
# processing file 2 of 4
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/test_ordered_warped/1/processed_T34MBB_20200926T084719_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/test_ordered/1/processed_T34MBB_20200926T084719_TCI_10m.jp2
# processing file 3 of 4
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/test_ordered_warped/1/processed_T34NEF_20200906T084559_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/test_ordered/1/processed_T34NEF_20200906T084559_TCI_10m.jp2
# processing file 4 of 4
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/test_ordered_warped/2/processed_T33NYC_20200922T090659_TCI_10m.jp2
# /Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/test_ordered/2/processed_T33NYC_20200922T090659_TCI_10m.jp2
# Finished

# %%
def make_full_virtual_raster(src_dir, dest_dir, num_layers=2):
    """Combines the rasters in the src_dir into a single virtual raster
    with proper prioritization. This is saved into the dest_dir.
    Make sure the num_layers variable is the same as the number of tile layers
    in your src_dir."""
    
    src_dir = add_trailing_slash(src_dir)
    dest_dir = add_trailing_slash(dest_dir)
    
    # If the output folder doesn't exist, create it
    create_dir(dest_dir)
    
    
    
    for layer in range(1, num_layers+1):
        print('Making Layer', layer)
        
        # Get the filenames from the layer in question
        filenames = glob(src_dir + f'{layer}/*.jp2', recursive=True)
        
        output_file = dest_dir + f'Layer{layer}.vrt'
    
        vrt = gdal.BuildVRT(output_file, filenames, resolution='average', resampleAlg='nearest', srcNodata=0)
    
        vrt.FlushCache()
    
    print('Making full raster')

    # To make the full raster, we combine every layer. Do it in reverse order because (I believe)
    # the last items in the list are prioritized.

    input_files = [dest_dir + f'Layer{i}.vrt' for i in reversed(range(1, num_layers+1))]
    
    output_file = dest_dir + 'full.vrt'

    vrt = gdal.BuildVRT(output_file, input_files, resolution='average', resampleAlg='nearest', srcNodata=0)

    vrt.FlushCache()

    print('Finished')

# %%
src_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/test_ordered_warped"
dest_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/test_master_raster"

make_full_virtual_raster(src_dir, dest_dir)
# Out:
# Making Layer 1
# Making Layer 2
# Making full raster
# Finished

# %%
def vrt_to_tif(output_file,src_file):

    translate = gdal.Translate("/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/test_master_raster/full_tif.tif", "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/test_master_raster/full.vrt",
                               format='GTiff')
    translate.FlushCache()

# %%
def export_aoi_polygon_rasters(gdf,master_raster_path,output_dir):
    
    output_dir = add_trailing_slash(output_dir) 

    src_raster_file = rio.open(master_raster_path)
    
    for index in range(gdf.shape[0]):
        crop_extent = gdf.loc[[index],"geometry"]


        raster_crop, raster_meta = es.crop_image(src_raster_file, crop_extent)

        # Update the metadata to have the new shape (x and y and affine information)
        raster_meta.update({"driver": "GTiff",
                         "height": raster_crop.shape[1],
                         "width": raster_crop.shape[2],
                         "transform": raster_meta["transform"]})

        # generate an extent for the newly cropped object for plotting
        cr_ext = rio.transform.array_bounds(raster_meta['height'], 
                                                    raster_meta['width'], 
                                                    raster_meta['transform'])
        
        

        bound_order = [0,2,1,3]
        cr_extent = [cr_ext[b] for b in bound_order]

        # mask the nodata
        raster_crop_ma = np.ma.masked_equal(raster_crop, 0) 


        # output_path
        outpath = out_base_path + str(index+1) + '.tif'

        # Check if directory exists
        if not os.path.isdir(out_base_path):
            os.mkdir(out_base_path)


        # Export cloud-masked TCI file
        with rio.open(outpath, 'w', **raster_meta) as outf:
            outf.write(raster_crop_ma)

# %%
master_raster_path = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/Master_Rasters/msk_geotiff_full.tif"
output_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/Polygon_Crops_Test/"

export_aoi_polygon_rasters(gdf,master_raster_path,output_dir)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-b712d91838e1> in <module>
#       2 output_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/Polygon_Crops_Test/"
#       3
# ----> 4 export_aoi_polygon_rasters(gdf,master_raster_path,output_dir)
#       5
#
# <ipython-input-16-43e5cf1db1df> in export_aoi_polygon_rasters(gdf, master_raster_path, output_dir)
#       7
#       8
# ----> 9         raster_crop, raster_meta = es.crop_image(src_raster_file, crop_extent)
#      10
#      11         # Update the metadata to have the new shape (x and y and affine information)
#
# ~/.local/share/virtualenvs/data_collection-Bxb0R3Gi/lib/python3.7/site-packages/earthpy/spatial.py in crop_image(raster, geoms, all_touched)
#     382         clip_extent = geoms
#     383     out_image, out_transform = mask(
# --> 384         raster, clip_extent, crop=True, all_touched=all_touched
#     385     )
#     386     out_meta = raster.meta.copy()
#
# ~/.local/share/virtualenvs/data_collection-Bxb0R3Gi/lib/python3.7/site-packages/rasterio/mask.py in mask(dataset, shapes, all_touched, invert, nodata, filled, crop, pad, pad_width, indexes)
#     192
#     193     out_image = dataset.read(
# --> 194         window=window, out_shape=out_shape, masked=True, indexes=indexes)
#     195
#     196     out_image.mask = out_image.mask | shape_mask
#
# rasterio/_io.pyx in rasterio._io.DatasetReaderBase.read()
#
# rasterio/_io.pyx in rasterio._io.DatasetReaderBase._read()
#
# /usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/logging/__init__.py in debug(self, msg, *args, **kwargs)
#    1354         self.manager._clear_cache()
#    1355
# -> 1356     def debug(self, msg, *args, **kwargs):
#    1357         """
#    1358         Log 'msg % args' with severity 'DEBUG'.
#
# KeyboardInterrupt:

# %%
def tif_to_jpg(in_dir,out_dir):
    
    
    
    in_dir = add_trailing_slash(in_dir)
    
    out_dir = add_trailing_slash(out_dir)
    
    # If the output folder doesn't exist, create it
    
    create_dir(out_dir)
    

    # Export Polygons from TIF to  JPEG

    tif_list = glob(in_dir + "*.tif",recursive=True)
    
    for tif_path in tif_list:
        base_filename = tif_path.split("/")[-1].split(".")[0]
        im = Image.open(tif_path)
        im.thumbnail(im.size)
        im.save(out_dir + base_filename + ".jpg", "JPEG", quality=100)

# %%
in_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/Polygon_Crops/MSK/Individual_Polygons/TIF/"
out_dir = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v2_Misha/Polygon_Crops/MSK/Individual_Polygons/JPG_2"

tif_to_jpg(in_dir,out_dir)
