# %%
import ee

ee.Initialize()

# %%
Full_Basin = [[[5.493164,8.276727],[5.449219,-5.703448],[31.376953,-4.959615],[31.157227,8.711359],[5.493164,8.276727]]]
AOI_full_basin = ee.Geometry.Polygon(Full_Basin)
START_DATE = '2020-10-01'
END_DATE = '2020-11-30'
CLOUD_FILTER = 5

def make_s2_sr_col(aoi=AOI_full_basin,start_date = START_DATE, end_date=END_DATE, CLOUD_FILTER=CLOUD_FILTER):
    s2_sr_col = (ee.ImageCollection('COPERNICUS/S2_SR')
        .filterBounds(aoi)
        .filterDate(start_date, end_date)
        .filter(ee.Filter.lte('CLOUDY_PIXEL_PERCENTAGE', CLOUD_FILTER)))
    return s2_sr_col

# %%
help(ee.Filter)
# Out:
# Help on class Filter in module ee.filter:
#
# class Filter(ee.computedobject.ComputedObject)
#  |  Filter(*args, **kwargs)
#  |
#  |  An object to represent collection filters.
#  |
#  |  Method resolution order:
#  |      Filter
#  |      ee.computedobject.ComputedObject
#  |      ee.encodable.Encodable
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  Not(self)
#  |      Returns the opposite of this filter.
#  |
#  |      Returns:
#  |        The negated filter, which will match iff this filter doesn't.
#  |
#  |  __init__(self, opt_filter=None)
#  |      Construct a filter.
#  |
#  |      This constructor accepts the following args:
#  |        1) Another filter.
#  |        2) An array of filters (which are implicitly ANDed together).
#  |        3) A ComputedObject returning a filter. Users shouldn't be making these;
#  |           they're produced by the generator functions below.
#  |
#  |      Args:
#  |        opt_filter: Optional filter to add.
#  |
#  |  predicateCount(self)
#  |      Return the number of predicates that have been added to this filter.
#  |
#  |      Returns:
#  |        The number of predicates that have been added to this filter.
#  |        This does not count nested predicates.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  initialize() from ee.computedobject.ComputedObjectMetaclass
#  |      Imports API functions to this class.
#  |
#  |  reset() from ee.computedobject.ComputedObjectMetaclass
#  |      Removes imported API functions from this class.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  And(*args)
#  |      Combine two or more filters using boolean AND.
#  |
#  |  Or(*args)
#  |      Combine two or more filters using boolean OR.
#  |
#  |  always = Filter.always(*args, **kwargs)
#  |      Simple filter ALWAYS.
#  |
#  |  calendarRange = Filter.calendarRange(*args, **kwargs)
#  |      Returns a filter that passes if the object's timestamp falls within the
#  |      given range of a calendar field.  The month, day_of_year, day_of_month, and
#  |      day_of_week are 1-based.  Times are assumed to be in UTC.  Weeks are
#  |      assumed to begin on Monday as day 1.   If end < start then this tests for
#  |      value >= start OR value <= end, to allow for wrapping.
#  |
#  |      Args:
#  |        start: The start of the desired calendar field, inclusive.
#  |        end: The end of the desired calendar field, inclusive. Defaults to
#  |            the same value as start.
#  |        field: The calendar field to filter over. Options are: 'year',
#  |            'month', 'hour', 'minute', 'day_of_year', 'day_of_month',
#  |            and 'day_of_week'.
#  |
#  |  contains = Filter.contains(*args, **kwargs)
#  |      Creates a unary or binary filter that passes if the left geometry contains
#  |      the right geometry (empty geometries are not contained in anything).
#  |
#  |      Args:
#  |        leftField: A selector for the left operand. Should not be
#  |            specified if leftValue is specified.
#  |        rightValue: The value of the right operand. Should not be
#  |            specified if rightField is specified.
#  |        rightField: A selector for the right operand. Should not be
#  |            specified if rightValue is specified.
#  |        leftValue: The value of the left operand. Should not be
#  |            specified if leftField is specified.
#  |        maxError: The maximum reprojection error allowed during
#  |            filter application.
#  |
#  |  date(start, opt_end=None)
#  |      Filter images by date.
#  |
#  |      The start and end may be a Date, numbers (interpreted as milliseconds since
#  |      1970-01-01T00:00:00Z), or strings (such as '1996-01-01T08:00'). Based on
#  |      'system:time_start'.
#  |
#  |      Args:
#  |        start: The inclusive start date.
#  |        opt_end: The optional exclusive end date, If not specified, a
#  |                 1-millisecond range starting at 'start' is created.
#  |
#  |      Returns:
#  |        The modified filter.
#  |
#  |  dateRangeContains = Filter.dateRangeContains(*args, **kwargs)
#  |      Creates a unary or binary filter that passes if the left operand, a date
#  |      range, contains the right operand, a date.
#  |
#  |      Args:
#  |        leftField: A selector for the left operand. Should not be
#  |            specified if leftValue is specified.
#  |        rightValue: The value of the right operand. Should not be
#  |            specified if rightField is specified.
#  |        rightField: A selector for the right operand. Should not be
#  |            specified if rightValue is specified.
#  |        leftValue: The value of the left operand. Should not be
#  |            specified if leftField is specified.
#  |
#  |  dayOfYear = Filter.dayOfYear(*args, **kwargs)
#  |      Returns a filter that passes if the object's timestamp falls within the
#  |      given day-of-year range.
#  |
#  |      Args:
#  |        start: The start of the desired day range, inclusive.
#  |        end: The end of the desired day range, inclusive.
#  |
#  |  disjoint = Filter.disjoint(*args, **kwargs)
#  |      Creates a unary or binary filter that passes unless the left geometry
#  |      intersects the right geometry.
#  |
#  |      Args:
#  |        leftField: A selector for the left operand. Should not be
#  |            specified if leftValue is specified.
#  |        rightValue: The value of the right operand. Should not be
#  |            specified if rightField is specified.
#  |        rightField: A selector for the right operand. Should not be
#  |            specified if rightValue is specified.
#  |        leftValue: The value of the left operand. Should not be
#  |            specified if leftField is specified.
#  |        maxError: The maximum reprojection error allowed during
#  |            filter application.
#  |
#  |  eq(name, value)
#  |      Filter to metadata equal to the given value.
#  |
#  |  equals = Filter.equals(*args, **kwargs)
#  |      Creates a unary or binary filter that passes if the two operands are
#  |      equals.
#  |
#  |      Args:
#  |        leftField: A selector for the left operand. Should not be
#  |            specified if leftValue is specified.
#  |        rightValue: The value of the right operand. Should not be
#  |            specified if rightField is specified.
#  |        rightField: A selector for the right operand. Should not be
#  |            specified if rightValue is specified.
#  |        leftValue: The value of the left operand. Should not be
#  |            specified if leftField is specified.
#  |
#  |  expression = Filter.expression(*args, **kwargs)
#  |      Constructs a filter tree from a string.
#  |
#  |      Args:
#  |        expression: A string to be parsed into a Filter object
#  |            (e.g.: "property > value"). Supported operators
#  |            include: >, >=, <, <=, ==, !=, (), !, && and ||.
#  |
#  |  geometry(geometry, opt_errorMargin=None)
#  |      Filter on intersection with geometry.
#  |
#  |      Items in the collection with a footprint that fails to intersect
#  |      the given geometry will be excluded.
#  |
#  |      Args:
#  |        geometry: The geometry to filter to either as a GeoJSON geometry,
#  |            or a FeatureCollection, from which a geometry will be extracted.
#  |        opt_errorMargin: An optional error margin. If a number, interpreted as
#  |            sphere surface meters.
#  |
#  |      Returns:
#  |        The constructed filter.
#  |
#  |  greaterThan = Filter.greaterThan(*args, **kwargs)
#  |      Creates a unary or binary filter that passes if the left operand is greater
#  |      than the right operand.
#  |
#  |      Args:
#  |        leftField: A selector for the left operand. Should not be
#  |            specified if leftValue is specified.
#  |        rightValue: The value of the right operand. Should not be
#  |            specified if rightField is specified.
#  |        rightField: A selector for the right operand. Should not be
#  |            specified if rightValue is specified.
#  |        leftValue: The value of the left operand. Should not be
#  |            specified if leftField is specified.
#  |
#  |  greaterThanOrEquals = Filter.greaterThanOrEquals(*args, **kwargs)
#  |      Creates a unary or binary filter that passes unless the left operand is
#  |      less than the right operand.
#  |
#  |      Args:
#  |        leftField: A selector for the left operand. Should not be
#  |            specified if leftValue is specified.
#  |        rightValue: The value of the right operand. Should not be
#  |            specified if rightField is specified.
#  |        rightField: A selector for the right operand. Should not be
#  |            specified if rightValue is specified.
#  |        leftValue: The value of the left operand. Should not be
#  |            specified if leftField is specified.
#  |
#  |  gt(name, value)
#  |      Filter on metadata greater than the given value.
#  |
#  |  gte(name, value)
#  |      Filter on metadata greater than or equal to the given value.
#  |
#  |  hasGeometry = Filter.hasGeometry(*args, **kwargs)
#  |      Simple filter HAS_GEOMETRY.
#  |
#  |  inList(opt_leftField=None, opt_rightValue=None, opt_rightField=None, opt_leftValue=None)
#  |      Filter on metadata contained in a list.
#  |
#  |      Args:
#  |        opt_leftField: A selector for the left operand.
#  |            Should not be specified if leftValue is specified.
#  |        opt_rightValue: The value of the right operand.
#  |            Should not be specified if rightField is specified.
#  |        opt_rightField: A selector for the right operand.
#  |            Should not be specified if rightValue is specified.
#  |        opt_leftValue: The value of the left operand.
#  |            Should not be specified if leftField is specified.
#  |
#  |      Returns:
#  |        The constructed filter.
#  |
#  |  intersects = Filter.intersects(*args, **kwargs)
#  |      Creates a unary or binary filter that passes if the left geometry
#  |      intersects the right geometry.
#  |
#  |      Args:
#  |        leftField: A selector for the left operand. Should not be
#  |            specified if leftValue is specified.
#  |        rightValue: The value of the right operand. Should not be
#  |            specified if rightField is specified.
#  |        rightField: A selector for the right operand. Should not be
#  |            specified if rightValue is specified.
#  |        leftValue: The value of the left operand. Should not be
#  |            specified if leftField is specified.
#  |        maxError: The maximum reprojection error allowed during
#  |            filter application.
#  |
#  |  isContained = Filter.isContained(*args, **kwargs)
#  |      Creates a unary or binary filter that passes if the right geometry contains
#  |      the left geometry (empty geometries are not contained in anything).
#  |
#  |      Args:
#  |        leftField: A selector for the left operand. Should not be
#  |            specified if leftValue is specified.
#  |        rightValue: The value of the right operand. Should not be
#  |            specified if rightField is specified.
#  |        rightField: A selector for the right operand. Should not be
#  |            specified if rightValue is specified.
#  |        leftValue: The value of the left operand. Should not be
#  |            specified if leftField is specified.
#  |        maxError: The maximum reprojection error allowed during
#  |            filter application.
#  |
#  |  lessThan = Filter.lessThan(*args, **kwargs)
#  |      Creates a unary or binary filter that passes if the left operand is less
#  |      than the right operand.
#  |
#  |      Args:
#  |        leftField: A selector for the left operand. Should not be
#  |            specified if leftValue is specified.
#  |        rightValue: The value of the right operand. Should not be
#  |            specified if rightField is specified.
#  |        rightField: A selector for the right operand. Should not be
#  |            specified if rightValue is specified.
#  |        leftValue: The value of the left operand. Should not be
#  |            specified if leftField is specified.
#  |
#  |  lessThanOrEquals = Filter.lessThanOrEquals(*args, **kwargs)
#  |      Creates a unary or binary filter that passes unless the left operand is
#  |      greater than the right operand.
#  |
#  |      Args:
#  |        leftField: A selector for the left operand. Should not be
#  |            specified if leftValue is specified.
#  |        rightValue: The value of the right operand. Should not be
#  |            specified if rightField is specified.
#  |        rightField: A selector for the right operand. Should not be
#  |            specified if rightValue is specified.
#  |        leftValue: The value of the left operand. Should not be
#  |            specified if leftField is specified.
#  |
#  |  listContains = Filter.listContains(*args, **kwargs)
#  |      Creates a unary or binary filter that passes if the left operand, a list,
#  |      contains the right operand.
#  |
#  |      Args:
#  |        leftField: A selector for the left operand. Should not be
#  |            specified if leftValue is specified.
#  |        rightValue: The value of the right operand. Should not be
#  |            specified if rightField is specified.
#  |        rightField: A selector for the right operand. Should not be
#  |            specified if rightValue is specified.
#  |        leftValue: The value of the left operand. Should not be
#  |            specified if leftField is specified.
#  |
#  |  lt(name, value)
#  |      Filter to metadata less than the given value.
#  |
#  |  lte(name, value)
#  |      Filter on metadata less than or equal to the given value.
#  |
#  |  maxDifference = Filter.maxDifference(*args, **kwargs)
#  |      Creates a unary or binary filter that passes if the left and right
#  |      operands, both numbers, are within a given maximum difference. If used as a
#  |      join condition, this numeric difference is used as a join measure.
#  |
#  |      Args:
#  |        difference: The maximum difference for which the filter
#  |            will return true.
#  |        leftField: A selector for the left operand. Should not be
#  |            specified if leftValue is specified.
#  |        rightValue: The value of the right operand. Should not be
#  |            specified if rightField is specified.
#  |        rightField: A selector for the right operand. Should not be
#  |            specified if rightValue is specified.
#  |        leftValue: The value of the left operand. Should not be
#  |            specified if leftField is specified.
#  |
#  |  metadata_(name, operator, value)
#  |      Filter on metadata. This is deprecated.
#  |
#  |      Args:
#  |        name: The property name to filter on.
#  |        operator: The type of comparison. One of:
#  |            "equals", "less_than", "greater_than", "contains", "begins_with",
#  |            "ends_with", or any of these prefixed with "not_".
#  |        value: The value to compare against.
#  |
#  |      Returns:
#  |        The new filter.
#  |
#  |      Deprecated.  Use ee.Filter.eq(), ee.Filter.gte(), etc.'
#  |
#  |  name()
#  |      Returns the name of the object, used in __str__().
#  |
#  |  neq(name, value)
#  |      Filter to metadata not equal to the given value.
#  |
#  |  never = Filter.never(*args, **kwargs)
#  |      Simple filter NEVER.
#  |
#  |  notEquals = Filter.notEquals(*args, **kwargs)
#  |      Creates a unary or binary filter that passes unless the two operands are
#  |      equals.
#  |
#  |      Args:
#  |        leftField: A selector for the left operand. Should not be
#  |            specified if leftValue is specified.
#  |        rightValue: The value of the right operand. Should not be
#  |            specified if rightField is specified.
#  |        rightField: A selector for the right operand. Should not be
#  |            specified if rightValue is specified.
#  |        leftValue: The value of the left operand. Should not be
#  |            specified if leftField is specified.
#  |
#  |  notNull = Filter.notNull(*args, **kwargs)
#  |      Returns a filter that passes if all the named properties are not null.
#  |
#  |      Args:
#  |        properties:
#  |
#  |  rangeContains = Filter.rangeContains(*args, **kwargs)
#  |      Returns a filter that passes if the value of the selected field is in the
#  |      specified range (inclusive).
#  |
#  |      Args:
#  |        field: A selector for the property being tested.
#  |        minValue: The lower bound of the range.
#  |        maxValue: The upper bound of the range.
#  |
#  |  stringContains = Filter.stringContains(*args, **kwargs)
#  |      Creates a unary or binary filter that passes if the left operand, a string,
#  |      contains the right operand, also a string.
#  |
#  |      Args:
#  |        leftField: A selector for the left operand. Should not be
#  |            specified if leftValue is specified.
#  |        rightValue: The value of the right operand. Should not be
#  |            specified if rightField is specified.
#  |        rightField: A selector for the right operand. Should not be
#  |            specified if rightValue is specified.
#  |        leftValue: The value of the left operand. Should not be
#  |            specified if leftField is specified.
#  |
#  |  stringEndsWith = Filter.stringEndsWith(*args, **kwargs)
#  |      Creates a unary or binary filter that passes if the left operand, a string,
#  |      ends with the right operand, also a string.
#  |
#  |      Args:
#  |        leftField: A selector for the left operand. Should not be
#  |            specified if leftValue is specified.
#  |        rightValue: The value of the right operand. Should not be
#  |            specified if rightField is specified.
#  |        rightField: A selector for the right operand. Should not be
#  |            specified if rightValue is specified.
#  |        leftValue: The value of the left operand. Should not be
#  |            specified if leftField is specified.
#  |
#  |  stringStartsWith = Filter.stringStartsWith(*args, **kwargs)
#  |      Creates a unary or binary filter that passes if the left operand, a string,
#  |      starts with the right operand, also a string.
#  |
#  |      Args:
#  |        leftField: A selector for the left operand. Should not be
#  |            specified if leftValue is specified.
#  |        rightValue: The value of the right operand. Should not be
#  |            specified if rightField is specified.
#  |        rightField: A selector for the right operand. Should not be
#  |            specified if rightValue is specified.
#  |        leftValue: The value of the left operand. Should not be
#  |            specified if leftField is specified.
#  |
#  |  withinDistance = Filter.withinDistance(*args, **kwargs)
#  |      Creates a unary or binary filter that passes if the left geometry is within
#  |      a specified distance of the right geometry. If used as a join condition,
#  |      this distance is used as a join measure.
#  |
#  |      Args:
#  |        distance: The maximum distance for which the filter will
#  |            return true.
#  |        leftField: A selector for the left operand. Should not be
#  |            specified if leftValue is specified.
#  |        rightValue: The value of the right operand. Should not be
#  |            specified if rightField is specified.
#  |        rightField: A selector for the right operand. Should not be
#  |            specified if rightValue is specified.
#  |        leftValue: The value of the left operand. Should not be
#  |            specified if leftField is specified.
#  |        maxError: The maximum reprojection error allowed during
#  |            filter application.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from ee.computedobject.ComputedObject:
#  |
#  |  __eq__(self, other)
#  |      Return self==value.
#  |
#  |  __hash__(self)
#  |      Return hash(self).
#  |
#  |  __ne__(self, other)
#  |      Return self!=value.
#  |
#  |  __str__(self)
#  |      Writes out the object in a human-readable form.
#  |
#  |  aside(self, func, *var_args)
#  |      Calls a function passing this object as the first argument.
#  |
#  |      Returns the object itself for chaining. Convenient e.g. when debugging:
#  |
#  |      c = (ee.ImageCollection('foo').aside(logging.info)
#  |               .filterDate('2001-01-01', '2002-01-01').aside(logging.info)
#  |               .filterBounds(geom).aside(logging.info)
#  |               .aside(addToMap, {'min': 0, 'max': 142})
#  |               .select('a', 'b'))
#  |
#  |      Args:
#  |        func: The function to call.
#  |        *var_args: Any extra arguments to pass to the function.
#  |
#  |      Returns:
#  |        The same object, for chaining.
#  |
#  |  encode(self, encoder)
#  |      Encodes the object in a format compatible with Serializer.
#  |
#  |  encode_cloud_value(self, encoder)
#  |      Encodes the object as a ValueNode.
#  |
#  |      Args:
#  |        encoder: A function that can be called to encode the components of
#  |            an object.
#  |
#  |      Returns:
#  |        The encoded form of the object.
#  |
#  |  getInfo(self)
#  |      Fetch and return information about this object.
#  |
#  |      Returns:
#  |        The object can evaluate to anything.
#  |
#  |  isVariable(self)
#  |      Returns whether this computed object is a variable reference.
#  |
#  |  serialize(self, opt_pretty=False, for_cloud_api=True)
#  |      Serialize this object into a JSON string.
#  |
#  |      Args:
#  |        opt_pretty: A flag indicating whether to pretty-print the JSON.
#  |        for_cloud_api: Whether the encoding should be done for the Cloud API
#  |          or the legacy API.
#  |
#  |      Returns:
#  |        The serialized representation of this object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from ee.computedobject.ComputedObject:
#  |
#  |  freeze(obj)
#  |      Freeze a list or dict so it can be hashed.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from ee.encodable.Encodable:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
help(ee.Algorithms.If)
# Out:
# Help on function <lambda> in module ee:
#
# <lambda> lambda *args, **kwargs
#     Selects one of its inputs based on a condition, similar to an if-then-else
#     construct.
#
#     Args:
#       condition: The condition that determines which result is
#           returned. If this is not a boolean, it is interpreted as
#           a boolean by the following rules:   - Numbers that are
#           equal to 0 or a NaN are false.   - Empty strings, lists
#           and dictionaries are false.   - Null is false.   -
#           Everything else is true.
#       trueCase: The result to return if the condition is true.
#       falseCase: The result to return if the condition is false.

# %%
help(ee.Algorithms.__gt__)
# Out:
# Help on method-wrapper object:
#
# __gt__ = class method-wrapper(object)
#  |  Methods defined here:
#  |
#  |  __call__(self, /, *args, **kwargs)
#  |      Call self as a function.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __reduce__(...)
#  |      Helper for pickle.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __objclass__
#  |
#  |  __self__
#  |
#  |  __text_signature__

# %%
flag = ee.Algorithms.IsEqual(1, 5)
print(flag)
# Out:
# ee.ComputedObject({
#   "functionInvocationValue": {
#     "functionName": "IsEqual",
#     "arguments": {
#       "left": {
#         "constantValue": 1
#       },
#       "right": {
#         "constantValue": 5
#       }
#     }
#   }
# })

# %%
s = ee.Algorithms.If(flag, "this is true", "this is false")

print(s)
# Out:
# ee.ComputedObject({
#   "functionInvocationValue": {
#     "functionName": "If",
#     "arguments": {
#       "condition": {
#         "functionInvocationValue": {
#           "functionName": "IsEqual",
#           "arguments": {
#             "left": {
#               "constantValue": 1
#             },
#             "right": {
#               "constantValue": 5
#             }
#           }
#         }
#       },
#       "falseCase": {
#         "constantValue": "this is false"
#       },
#       "trueCase": {
#         "constantValue": "this is true"
#       }
#     }
#   }
# })

# %%
s.getInfo()
# Out:
# 'this is false'

# %%
# %%time
collection.size().getInfo()
# Out:
# Wall time: 595 ms
# 14

# %%
# %%time

flag = ee.Algorithms.gt(collection.size(), 30)

s = ee.Algorithms.If(flag, True, False)

print(s)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Anaconda3\envs\google_api\lib\site-packages\ee\__init__.py in __getattr__(self, name)
#      59     try:
# ---> 60       return self[name]
#      61     except KeyError:
#
# KeyError: 'gt'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>
#
# C:\Anaconda3\envs\google_api\lib\site-packages\ee\__init__.py in __getattr__(self, name)
#      60       return self[name]
#      61     except KeyError:
# ---> 62       raise AttributeError
#      63
#      64   def __setattr__(self, name, value):
#
# AttributeError:

# %%
type(collection.size())
# Out:
# ee.ee_number.Number

# %%
help(ee.ee_number.Number)
# Out:
# Help on class Number in module ee.ee_number:
#
# class Number(ee.computedobject.ComputedObject)
#  |  Number(*args, **kwargs)
#  |
#  |  An object to represent numbers.
#  |
#  |  Method resolution order:
#  |      Number
#  |      ee.computedobject.ComputedObject
#  |      ee.encodable.Encodable
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  And = Number.and(*args, **kwargs)
#  |      Returns 1 iff both values are non-zero.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  Not = Number.not(*args, **kwargs)
#  |      Returns 0 if the input is non-zero, and 1 otherwise.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  Or = Number.or(*args, **kwargs)
#  |      Returns 1 iff either input value is non-zero.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  __init__(self, number)
#  |      Construct a number wrapper.
#  |
#  |      This constructor accepts the following args:
#  |        1) A bare number.
#  |        2) A ComputedObject returning a number.
#  |
#  |      Args:
#  |        number: The number to wrap.
#  |
#  |  abs = Number.abs(*args, **kwargs)
#  |      Computes the absolute value of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  acos = Number.acos(*args, **kwargs)
#  |      Computes the arc cosine in radians of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  add = Number.add(*args, **kwargs)
#  |      Adds the first value to the second.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  asin = Number.asin(*args, **kwargs)
#  |      Computes the arc sine in radians of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  atan = Number.atan(*args, **kwargs)
#  |      Computes the arc tangent in radians of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  atan2 = Number.atan2(*args, **kwargs)
#  |      Calculates the angle formed by the 2D vector [x, y].
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  bitCount = Number.bitCount(*args, **kwargs)
#  |      Calculates the number of one-bits in the 64-bit two's complement binary
#  |      representation of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  bitwiseAnd = Number.bitwiseAnd(*args, **kwargs)
#  |      Calculates the bitwise AND of the input values.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  bitwiseNot = Number.bitwiseNot(*args, **kwargs)
#  |      Calculates the bitwise NOT of the input, in the smallest signed integer
#  |      type that can hold the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  bitwiseOr = Number.bitwiseOr(*args, **kwargs)
#  |      Calculates the bitwise OR of the input values.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  bitwiseXor = Number.bitwiseXor(*args, **kwargs)
#  |      Calculates the bitwise XOR of the input values.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  bitwise_and = Number.bitwise_and(*args, **kwargs)
#  |      Calculates the bitwise AND of the input values.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  bitwise_not = Number.bitwise_not(*args, **kwargs)
#  |      Calculates the bitwise NOT of the input, in the smallest signed integer
#  |      type that can hold the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  bitwise_or = Number.bitwise_or(*args, **kwargs)
#  |      Calculates the bitwise OR of the input values.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  bitwise_xor = Number.bitwise_xor(*args, **kwargs)
#  |      Calculates the bitwise XOR of the input values.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  byte = Number.byte(*args, **kwargs)
#  |      Casts the input value to an unsigned 8-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  cbrt = Number.cbrt(*args, **kwargs)
#  |      Computes the cubic root of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  ceil = Number.ceil(*args, **kwargs)
#  |      Computes the smallest integer greater than or equal to the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  cos = Number.cos(*args, **kwargs)
#  |      Computes the cosine of the input in radians.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  cosh = Number.cosh(*args, **kwargs)
#  |      Computes the hyperbolic cosine of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  digamma = Number.digamma(*args, **kwargs)
#  |      Computes the digamma function of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  divide = Number.divide(*args, **kwargs)
#  |      Divides the first value by the second, returning 0 for division by 0.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  double = Number.double(*args, **kwargs)
#  |      Casts the input value to a 64-bit float.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  encode(self, opt_encoder=None)
#  |      Encodes the object in a format compatible with Serializer.
#  |
#  |  encode_cloud_value(self, opt_encoder=None)
#  |      Encodes the object as a ValueNode.
#  |
#  |      Args:
#  |        encoder: A function that can be called to encode the components of
#  |            an object.
#  |
#  |      Returns:
#  |        The encoded form of the object.
#  |
#  |  eq = Number.eq(*args, **kwargs)
#  |      Returns 1 iff the first value is equal to the second.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  erf = Number.erf(*args, **kwargs)
#  |      Computes the error function of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  erfInv = Number.erfInv(*args, **kwargs)
#  |      Computes the inverse error function of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  erfc = Number.erfc(*args, **kwargs)
#  |      Computes the complementary error function of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  erfcInv = Number.erfcInv(*args, **kwargs)
#  |      Computes the inverse complementary error function of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  exp = Number.exp(*args, **kwargs)
#  |      Computes the Euler's number e raised to the power of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  first = Number.first(*args, **kwargs)
#  |      Selects the value of the first value.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  firstNonZero = Number.firstNonZero(*args, **kwargs)
#  |      Selects the first value if it is non-zero, and the second value otherwise.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  first_nonzero = Number.first_nonzero(*args, **kwargs)
#  |      Selects the first value if it is non-zero, and the second value otherwise.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  float = Number.float(*args, **kwargs)
#  |      Casts the input value to a 32-bit float.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  floor = Number.floor(*args, **kwargs)
#  |      Computes the largest integer less than or equal to the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  format = Number.format(*args, **kwargs)
#  |      Convert a number to a string using printf-style formatting.
#  |
#  |      Args:
#  |        number: The number to convert to a string.
#  |        pattern: A printf-style format string. For example, '%.2f'
#  |            produces numbers formatted like '3.14', and '%05d'
#  |            produces numbers formatted like '00042'. The format string
#  |            must satisfy the following criteria: 1. Zero or more
#  |            prefix characters. 2. Exactly one '%'. 3. Zero or more
#  |            modifier characters in the set [#-+ 0,(.\d]. 4. Exactly
#  |            one conversion character in the set [sdoxXeEfgGaA]. 5.
#  |            Zero or more suffix characters.   For more about format
#  |            strings, see https://docs.oracle.com/javase/7/docs/api/jav
#  |            a/util/Formatter.html
#  |
#  |  gamma = Number.gamma(*args, **kwargs)
#  |      Computes the gamma function of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  gammainc = Number.gammainc(*args, **kwargs)
#  |      Calculates the regularized lower incomplete Gamma function γ(x,a).
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  gt = Number.gt(*args, **kwargs)
#  |      Returns 1 iff the first value is greater than the second.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  gte = Number.gte(*args, **kwargs)
#  |      Returns 1 iff the first value is greater than or equal to the second.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  hypot = Number.hypot(*args, **kwargs)
#  |      Calculates the magnitude of the 2D vector [x, y].
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  int = Number.int(*args, **kwargs)
#  |      Casts the input value to a signed 32-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  int16 = Number.int16(*args, **kwargs)
#  |      Casts the input value to a signed 16-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  int32 = Number.int32(*args, **kwargs)
#  |      Casts the input value to a signed 32-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  int64 = Number.int64(*args, **kwargs)
#  |      Casts the input value to a signed 64-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  int8 = Number.int8(*args, **kwargs)
#  |      Casts the input value to a signed 8-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  lanczos = Number.lanczos(*args, **kwargs)
#  |      Computes the Lanczos approximation of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  leftShift = Number.leftShift(*args, **kwargs)
#  |      Calculates the left shift of v1 by v2 bits.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  left_shift = Number.left_shift(*args, **kwargs)
#  |      Calculates the left shift of v1 by v2 bits.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  log = Number.log(*args, **kwargs)
#  |      Computes the natural logarithm of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  log10 = Number.log10(*args, **kwargs)
#  |      Computes the base-10 logarithm of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  long = Number.long(*args, **kwargs)
#  |      Casts the input value to a signed 64-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  lt = Number.lt(*args, **kwargs)
#  |      Returns 1 iff the first value is less than the second.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  lte = Number.lte(*args, **kwargs)
#  |      Returns 1 iff the first value is less than or equal to the second.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  max = Number.max(*args, **kwargs)
#  |      Selects the maximum of the first and second values.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  min = Number.min(*args, **kwargs)
#  |      Selects the minimum of the first and second values.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  mod = Number.mod(*args, **kwargs)
#  |      Calculates the remainder of the first value divided by the second.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  multiply = Number.multiply(*args, **kwargs)
#  |      Multiplies the first value by the second.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  neq = Number.neq(*args, **kwargs)
#  |      Returns 1 iff the first value is not equal to the second.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  pow = Number.pow(*args, **kwargs)
#  |      Raises the first value to the power of the second.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  rightShift = Number.rightShift(*args, **kwargs)
#  |      Calculates the signed right shift of v1 by v2 bits.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  right_shift = Number.right_shift(*args, **kwargs)
#  |      Calculates the signed right shift of v1 by v2 bits.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  round = Number.round(*args, **kwargs)
#  |      Computes the integer nearest to the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  short = Number.short(*args, **kwargs)
#  |      Casts the input value to a signed 16-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  sin = Number.sin(*args, **kwargs)
#  |      Computes the sine of the input in radians.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  sinh = Number.sinh(*args, **kwargs)
#  |      Computes the hyperbolic sine of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  sqrt = Number.sqrt(*args, **kwargs)
#  |      Computes the square root of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  subtract = Number.subtract(*args, **kwargs)
#  |      Subtracts the second value from the first.
#  |
#  |      Args:
#  |        left: The left-hand value.
#  |        right: The right-hand value.
#  |
#  |  tan = Number.tan(*args, **kwargs)
#  |      Computes the tangent of the input in radians.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  tanh = Number.tanh(*args, **kwargs)
#  |      Computes the hyperbolic tangent of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  toByte = Number.toByte(*args, **kwargs)
#  |      Casts the input value to an unsigned 8-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  toDouble = Number.toDouble(*args, **kwargs)
#  |      Casts the input value to a 64-bit float.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  toFloat = Number.toFloat(*args, **kwargs)
#  |      Casts the input value to a 32-bit float.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  toInt = Number.toInt(*args, **kwargs)
#  |      Casts the input value to a signed 32-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  toInt16 = Number.toInt16(*args, **kwargs)
#  |      Casts the input value to a signed 16-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  toInt32 = Number.toInt32(*args, **kwargs)
#  |      Casts the input value to a signed 32-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  toInt64 = Number.toInt64(*args, **kwargs)
#  |      Casts the input value to a signed 64-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  toInt8 = Number.toInt8(*args, **kwargs)
#  |      Casts the input value to a signed 8-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  toLong = Number.toLong(*args, **kwargs)
#  |      Casts the input value to a signed 64-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  toShort = Number.toShort(*args, **kwargs)
#  |      Casts the input value to a signed 16-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  toUint16 = Number.toUint16(*args, **kwargs)
#  |      Casts the input value to an unsigned 16-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  toUint32 = Number.toUint32(*args, **kwargs)
#  |      Casts the input value to an unsigned 32-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  toUint8 = Number.toUint8(*args, **kwargs)
#  |      Casts the input value to an unsigned 8-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  trigamma = Number.trigamma(*args, **kwargs)
#  |      Computes the trigamma function of the input.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  uint16 = Number.uint16(*args, **kwargs)
#  |      Casts the input value to an unsigned 16-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  uint32 = Number.uint32(*args, **kwargs)
#  |      Casts the input value to an unsigned 32-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  uint8 = Number.uint8(*args, **kwargs)
#  |      Casts the input value to an unsigned 8-bit integer.
#  |
#  |      Args:
#  |        input: The input value.
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  initialize() from ee.computedobject.ComputedObjectMetaclass
#  |      Imports API functions to this class.
#  |
#  |  reset() from ee.computedobject.ComputedObjectMetaclass
#  |      Removes imported API functions from this class.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  clamp = Number.clamp(*args, **kwargs)
#  |      Clamps the value to lie within the range of min to max.
#  |
#  |      Args:
#  |        number:
#  |        min:
#  |        max:
#  |
#  |  expression = Number.expression(*args, **kwargs)
#  |      Computes a numeric expression.
#  |
#  |      Args:
#  |        expression: A mathematical expression string to be
#  |            evaluated. In addiiton to the standard arithmetic,
#  |            boolean and relational operators, expressions also
#  |            support any function in Number, the '.' operator to
#  |            extract child elements from the 'vars' dictionary, and
#  |            mathematical constants Math.PI and Math.E
#  |        vars: A dictionary of named values that can be used in the
#  |            expression.
#  |
#  |  name()
#  |      Returns the name of the object, used in __str__().
#  |
#  |  parse = Number.parse(*args, **kwargs)
#  |      Convert a string to a number.
#  |
#  |      Args:
#  |        input: The string to convert to a number.
#  |        radix: An integer representing the base number system from which
#  |            to convert. If input is not an integer, radix must equal 10
#  |            or not be specified.
#  |
#  |  unitScale = Number.unitScale(*args, **kwargs)
#  |      Scales the input so that the range of input values [min, max] becomes [0,
#  |      1]. Values outside the range are NOT clamped.  If min == max, 0 is
#  |      returned.
#  |
#  |      Args:
#  |        number:
#  |        min:
#  |        max:
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from ee.computedobject.ComputedObject:
#  |
#  |  __eq__(self, other)
#  |      Return self==value.
#  |
#  |  __hash__(self)
#  |      Return hash(self).
#  |
#  |  __ne__(self, other)
#  |      Return self!=value.
#  |
#  |  __str__(self)
#  |      Writes out the object in a human-readable form.
#  |
#  |  aside(self, func, *var_args)
#  |      Calls a function passing this object as the first argument.
#  |
#  |      Returns the object itself for chaining. Convenient e.g. when debugging:
#  |
#  |      c = (ee.ImageCollection('foo').aside(logging.info)
#  |               .filterDate('2001-01-01', '2002-01-01').aside(logging.info)
#  |               .filterBounds(geom).aside(logging.info)
#  |               .aside(addToMap, {'min': 0, 'max': 142})
#  |               .select('a', 'b'))
#  |
#  |      Args:
#  |        func: The function to call.
#  |        *var_args: Any extra arguments to pass to the function.
#  |
#  |      Returns:
#  |        The same object, for chaining.
#  |
#  |  getInfo(self)
#  |      Fetch and return information about this object.
#  |
#  |      Returns:
#  |        The object can evaluate to anything.
#  |
#  |  isVariable(self)
#  |      Returns whether this computed object is a variable reference.
#  |
#  |  serialize(self, opt_pretty=False, for_cloud_api=True)
#  |      Serialize this object into a JSON string.
#  |
#  |      Args:
#  |        opt_pretty: A flag indicating whether to pretty-print the JSON.
#  |        for_cloud_api: Whether the encoding should be done for the Cloud API
#  |          or the legacy API.
#  |
#  |      Returns:
#  |        The serialized representation of this object.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from ee.computedobject.ComputedObject:
#  |
#  |  freeze(obj)
#  |      Freeze a list or dict so it can be hashed.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from ee.encodable.Encodable:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# %%time

flag = collection.size().gt(30)

s = ee.Algorithms.If(flag, True, False)

print(s.getInfo())
# Out:
# False
# Wall time: 721 ms

# %%
# %%time
collection.size().getInfo()
# Out:
# Wall time: 1.78 s
# 14

# %%
import time

time.time()
# Out:
# 1605735406.0820196

# %%
print(10 > 30)
# Out:
# False

# %%
client_times = []
server_times = []

for _ in range(10):
    print('Getting size directly')
    start = time.time()
    size = collection.size().getInfo()
    print(size > 30)
    end = time.time()
    print('Time elapsed:', end - start)
    client_times.append(end - start)
    
    print('Using server-size conditional')
    start = time.time()
    flag = collection.size().gt(30)
    s = ee.Algorithms.If(flag, True, False)
    print(s.getInfo())
    end = time.time()
    print('Time elapsed:', end-start)
    server_times.append(end-start)
# Out:
# Getting size directly
# False
# Time elapsed: 0.542189359664917
# Using server-size conditional
# False
# Time elapsed: 0.5403802394866943
# Getting size directly
# False
# Time elapsed: 0.1730637550354004
# Using server-size conditional
# False
# Time elapsed: 0.3010871410369873
# Getting size directly
# False
# Time elapsed: 0.2634923458099365
# Using server-size conditional
# False
# Time elapsed: 0.16972708702087402
# Getting size directly
# False
# Time elapsed: 0.2929832935333252
# Using server-size conditional
# False
# Time elapsed: 0.29103684425354004
# Getting size directly
# False
# Time elapsed: 0.16585588455200195
# Using server-size conditional
# False
# Time elapsed: 0.3103318214416504
# Getting size directly
# False
# Time elapsed: 0.17348790168762207
# Using server-size conditional
# False
# Time elapsed: 0.3032388687133789
# Getting size directly
# False
# Time elapsed: 0.17789053916931152
# Using server-size conditional
# False
# Time elapsed: 0.30017662048339844
# Getting size directly
# False
# Time elapsed: 0.3056068420410156
# Using server-size conditional
# False
# Time elapsed: 0.17850995063781738
# Getting size directly
# False
# Time elapsed: 0.27135181427001953
# Using server-size conditional
# False
# Time elapsed: 0.29972290992736816
# Getting size directly
# False
# Time elapsed: 0.17689156532287598
# Using server-size conditional
# False
# Time elapsed: 0.3018198013305664

# %%
sum(client_times) / 10
# Out:
# 0.25428133010864257

# %%
sum(server_times) / 10
# Out:
# 0.29960312843322756

# %%
client_times = []

for _ in range(100):
    start = time.time()
    size = collection.size().getInfo()
    end = time.time()
    client_times.append(end - start)
    
print(sum(client_times) / 100)
# Out:
# 0.25053317785263063

# %%
server_times = []

for _ in range(100):
    start = time.time()
    flag = collection.size().gt(30)
    s = ee.Algorithms.If(flag, True, False).getInfo()
    end = time.time()
    server_times.append(end-start)
    
print(sum(server_times) / 100)
# Out:
# 0.21635420560836793

# %%
def coll_filter_conditional(coll, filter_by='NODATA_PIXEL_PERCENTAGE',
                            filter_type='less_than', filter_thresh=10,
                            cond_type='gt', cond_thresh=30):
    if filter_by is not None:
        coll = coll.filterMetadata(filter_by, filter_type, filter_thresh)
        
    size = coll.size()
    
    print('Size:', size.getInfo())
    
    flag = getattr(size, cond_type)(cond_thresh)
    
    return ee.Algorithms.If(flag, True, False).getInfo()

# %%
coll_filter_conditional(collection)
# Out:
# False

# %%
def collection_greater_than(coll, threshold):
    return coll_filter_conditional(coll, filter_by=None, cond_thresh=threshold)

# %%
collection_greater_than(collection, 30)
# Out:
# False

# %%
def collection_quality_test_no_filter(coll, best, coll_thresh=30, best_thresh=1):
    best_is_good = collection_greater_than(best, best_thresh)
    if best_is_good:
        return True
    
    return collection_greater_than(coll, coll_thresh)

# %%
best = collection.filterMetadata('CLOUDY_PIXEL_PERCENTAGE', 'less_than', 5)

# %%
best.size().getInfo()
# Out:
# 14

# %%
collection_quality_test_no_filter(collection, best)
# Out:
# True

# %%
def collection_quality_test_filter(coll, best, coll_min=30, best_min=1,
                                   filter_by='NODATA_PIXEL_PERCENTAGE',
                                   filter_type='less_than', filter_thresh=10):

    # Test to see if there's at least one good image with low nodata pixels
    best_is_good = coll_filter_conditional(best, filter_by=filter_by, filter_type=filter_type,
                                           filter_thresh=filter_thresh, cond_thresh=best_min)
    
    # If there is, the collection is fine!
    if best_is_good:
        return True
    
    # If there isn't a sufficient good image, test the size of the collection as a whole
    coll_is_good = collection_greater_than(coll, coll_min)

    return coll_is_good

# %%
coll_filter_conditional(best)
# Out:
# False

# %%
collection_quality_test_filter(collection, best)
# Out:
# False

# %%
collection_quality_test_filter(collection, best, filter_thresh=20)
# Out:
# False

# %%
collection_quality_test_filter(collection, best, filter_thresh=50)
# Out:
# False

# %%
collection_quality_test_filter(collection, best, filter_thresh=80)
# Out:
# False

# %%
collection_quality_test_filter(collection, best, filter_thresh=100)
# Out:
# False

# %%
collection_quality_test_filter(collection, best)
# Out:
# Size: 0
# Size: 14
# False

# %%
collection_quality_test_filter(collection, best, filter_thresh=100)
# Out:
# Size: 0
# Size: 14
# False

# %%
coll = make_s2_sr_col()

best = coll.filterMetadata('CLOUDY_PIXEL_PERCENTAGE', 'less_than', 5)

# %%
collection_quality_test_filter(coll, best)
# Out:
# Size: 197
# True

# %%
coll.size().getInfo()
# Out:
# 481

# %%
import ee
import yaml
import time
import os
import json
import pandas as pd
from utils import exportImageToGDrive,exportImageToGCS
from download_sen12 import *

ee.Initialize()
# Out:
# C:\Anaconda3\envs\cloud_removal\lib\site-packages\gevent\hub.py:158: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
config_dict = load_config('config.yml')
source = config_dict['data_list'][0]
sensor = config_dict['sensors'][0]
# export_folder = config_dict['drive_folder']
export_folder = config_dict['bucket']

print(export_folder)
# Out:
# project-canopy-temp-2
# C:\Users\David\canopy\canopy-gis\google-earth-explore\GEE_DataDownloader\download_sen12.py:205: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   return yaml.load(stream)

# %%
def import_aois(csv_loc):    

    df_labels = pd.read_csv(csv_loc)
    df_labels = df_labels[["center-lat","center-long","polygon","Labels combined"]]

    polygons = []
    for polygon in df_labels["polygon"]:
        polygons.append(json.loads(polygon)["coordinates"])

    return polygons

### CHANGE BELOW PATH ###
zhenya_path = "/Volumes/Lacie/zhenyadata/Project_Canopy_Data/PC_Data/Sentinel_Data/Labelled/Tiles_v3/Polygon_List/polygons_101320.csv"
david_path = 'D:/canopy_data/csvs/polygons_101320.csv'
polygons = import_aois(david_path)

feature_id = 0 
features = []
for poly in polygons:
    # create an roi. first item in Misha's label list
    feature_id += 1 
    
    # create geometry object, create feature object, append to features list for feature collection creation 
    polys = ee.Geometry.Polygon(poly)
    feature = ee.Feature(polys,{"name":feature_id})
    features.append(feature)

fc = ee.FeatureCollection(features)

# %%
results = process_datasource(source, sensor, export_folder, fc)
# Out:
# 101 features have been loaded
# processing  1_pipeline_v2_test_1_Nov_18_15:08:22_2020
# Size of best filtered: 11
# processing  2_pipeline_v2_test_1_Nov_18_15:08:23_2020
# Size of best filtered: 10
# processing  3_pipeline_v2_test_1_Nov_18_15:08:25_2020
# Size of best filtered: 34
# processing  4_pipeline_v2_test_1_Nov_18_15:08:27_2020
# Size of best filtered: 17
# processing  5_pipeline_v2_test_1_Nov_18_15:08:28_2020
# Size of best filtered: 22
# processing  6_pipeline_v2_test_1_Nov_18_15:08:30_2020
# Size of best filtered: 2
# processing  7_pipeline_v2_test_1_Nov_18_15:08:31_2020
# Size of best filtered: 13
# processing  8_pipeline_v2_test_1_Nov_18_15:08:32_2020
# Size of best filtered: 1
# processing  75_pipeline_v2_test_1_Nov_18_15:11:54_2020
# Size of best filtered: 3
# processing  76_pipeline_v2_test_1_Nov_18_15:11:55_2020
# Size of best filtered: 0
# Size of entire coll: 28
# processing  77_pipeline_v2_test_1_Nov_18_15:12:05_2020
# Size of best filtered: 0
# Size of entire coll: 13
# processing  78_pipeline_v2_test_1_Nov_18_15:12:10_2020
# Size of best filtered: 3
# processing  79_pipeline_v2_test_1_Nov_18_15:12:11_2020
# Size of best filtered: 8
# processing  80_pipeline_v2_test_1_Nov_18_15:12:12_2020
# Size of best filtered: 18
# processing  81_pipeline_v2_test_1_Nov_18_15:12:14_2020
# Size of best filtered: 31
# processing  82_pipeline_v2_test_1_Nov_18_15:12:16_2020
# Size of best filtered: 11
# processing  83_pipeline_v2_test_1_Nov_18_15:12:17_2020
# Size of best filtered: 9
# processing  84_pipeline_v2_test_1_Nov_18_15:12:18_2020
# Size of best filtered: 3
# processing  85_pipeline_v2_test_1_Nov_18_15:12:19_2020
# Size of best filtered: 17
# processing  86_pipeline_v2_test_1_Nov_18_15:12:20_2020
# Size of best filtered: 3
# processing  87_pipeline_v2_test_1_Nov_18_15:12:25_2020
# Size of best filtered: 6
# processing  88_pipeline_v2_test_1_Nov_18_15:12:26_2020
# Size of best filtered: 12
# processing  89_pipeline_v2_test_1_Nov_18_15:12:27_2020
# Size of best filtered: 12
# processing  90_pipeline_v2_test_1_Nov_18_15:12:28_2020
# Size of best filtered: 9
# processing  91_pipeline_v2_test_1_Nov_18_15:12:29_2020
# Size of best filtered: 9
# processing  92_pipeline_v2_test_1_Nov_18_15:12:30_2020
# Size of best filtered: 12
# processing  93_pipeline_v2_test_1_Nov_18_15:12:31_2020
# Size of best filtered: 11
# processing  94_pipeline_v2_test_1_Nov_18_15:12:32_2020
# Size of best filtered: 12
# processing  95_pipeline_v2_test_1_Nov_18_15:12:33_2020
# Size of best filtered: 11
# processing  96_pipeline_v2_test_1_Nov_18_15:12:34_2020
# Size of best filtered: 0
# Size of entire coll: 118
# processing  97_pipeline_v2_test_1_Nov_18_15:12:42_2020
# Size of best filtered: 0
# Size of entire coll: 244
# processing  98_pipeline_v2_test_1_Nov_18_15:13:02_2020
# Size of best filtered: 30
# processing  99_pipeline_v2_test_1_Nov_18_15:13:04_2020
# Size of best filtered: 30
# processing  100_pipeline_v2_test_1_Nov_18_15:13:05_2020
# Size of best filtered: 30
# processing  101_pipeline_v2_test_1_Nov_18_15:13:07_2020
# Size of best filtered: 17
# C:\Anaconda3\envs\cloud_removal\lib\site-packages\gevent\hub.py:158: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
sum(results) / 100
# Out:
# 0.97

# %%
source['start_date']
# Out:
# '2019-01-01'

# %%
source['start_date'] = '2019-10-01'
source['end_date'] = '2020-09-30'

# %%
results = process_datasource(source, sensor, export_folder, fc)
# Out:
# 101 features have been loaded
# processing  1_pipeline_v2_test_1_Nov_18_15:21:01_2020
# Size of best filtered: 10
# processing  2_pipeline_v2_test_1_Nov_18_15:21:02_2020
# Size of best filtered: 9
# processing  3_pipeline_v2_test_1_Nov_18_15:21:03_2020
