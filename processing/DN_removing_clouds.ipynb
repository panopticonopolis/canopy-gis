# %%
import os
from glob import glob
import matplotlib.pyplot as plt
from matplotlib import patches as mpatches, colors
from matplotlib.colors import ListedColormap
import seaborn as sns
import numpy as np
import numpy.ma as ma
import pandas as pd
import rasterio as rio
from rasterio.plot import plotting_extent
from rasterio.mask import mask
import geopandas as gpd
from shapely.geometry import mapping
import earthpy as et
import earthpy.spatial as es
import earthpy.plot as ep
import earthpy.mask as em
from shutil import copyfile

# %%
def change_string(s):
    s += '1'
    return s
    
s = 'abc'

print(change_string(s))

print(s)
# Out:
# abc1
# abc

# %%
src_dir = 'D:/canopy_data/pipeline-products/raw_products/SAFE_ordered_cloud_cover/'

glob(src_dir + "*/*TCI_10m.jp2",recursive=True)[0]
# Out:
# 'D:/canopy_data/pipeline-products/raw_products/SAFE_ordered_cloud_cover\\1\\T33NTB_20191110T092119_TCI_10m.jp2'

# %%
mask_dir = 'D:/canopy_data/pipeline-products/raw_products/SCL/'

glob(mask_dir + "*.jp2", recursive=True)[0]
# Out:
# 'D:/canopy_data/pipeline-products/raw_products/SCL\\33NTB_20191110_SCL.jp2'

# %%
mask_dir = 'D:/canopy_data/pipeline-products/raw_products/MSK/'

glob(mask_dir + "*.jp2", recursive=True)[0]
# Out:
# 'D:/canopy_data/pipeline-products/raw_products/MSK\\L2A_T33NTB_A013990_20191110T093408_MSK_CLDPRB_20m.jp2'

# %%
def make_tci_string(TCI_file):
    return TCI_file.split("\\")[-1].split("_")[0] + "_" + TCI_file.split("\\")[-1].split("_")[1][:8]

TCI_string = make_tci_string(glob(src_dir + "*/*TCI_10m.jp2",recursive=True)[0])

TCI_string
# Out:
# 'T33NTB_20191110'

# %%
mask_dir.split('/')
# Out:
# ['D:', 'canopy_data', 'pipeline-products', 'raw_products', 'MSK', '']

# %%
def make_string_match(mask, mask_type):
    if mask_type == 'MSK':
        return mask.split("\\")[-1].split("_")[1] + "_" + mask.split("\\")[-1].split("_")[3][:8]
    elif mask_type == 'SCL':
        return 'T' + mask.split("\\")[-1].split("_")[0] + "_" + mask.split("\\")[-1].split("_")[1]
    else:
        raise ValueError('Mask type must be either MSK or SCL')


def cloud_fill(source_dir, mask_dir, output_dir, start=0):
    if source_dir[-1] != '/':
        source_dir += '/'
    if mask_dir[-1] != '/':
        mask_dir += '/'
    if output_dir[-1] != '/':
        output_dir += '/'
    
    TCI_list = glob(source_dir + "*/*TCI_10m.jp2", recursive=True)
    Mask_list = glob(mask_dir + "*.jp2", recursive=True)[start:]
    mask_type = mask_dir.split('/')[-2]
    nodatavalue = int(0)
    TCI_string_match = {}

    for index,TCI_file in enumerate(TCI_list):
        TCI_string = TCI_file.split("\\")[-1].split("_")[0] + "_" + TCI_file.split("\\")[-1].split("_")[1][:8]
        TCI_string_match.update({TCI_string:index})
        
    num_masks = len(Mask_list)
    for i, mask in enumerate(Mask_list, 1):
        print(f'Mask {i} of {num_masks}')
        string_match = make_string_match(mask, mask_type)
        if string_match in TCI_string_match.keys():
            index = TCI_string_match[string_match]
            TCI_file = TCI_list[index]
            Mask_file = mask
    
            Mask_filename = Mask_file.split("\\")[-1]
            TCI_filename = "processed_" + TCI_file.split("\\")[-1]
        

            print(f"Applying {Mask_filename} to {TCI_filename}")

            with rio.open(TCI_file) as sen_TCI_src:
                sen_TCI = sen_TCI_src.read(masked=True)
                sen_TCI_meta = sen_TCI_src.meta

            with rio.open(Mask_file) as sen_mask_src:
                sen_mask_pre = sen_mask_src.read(1)
                sen_mask = np.repeat(np.repeat(sen_mask_pre,2,axis=0),2,axis=1)

            # All pixels above 0 probability will be classified as True
            if mask_type == 'MSK':
                sen_mask_qa = sen_mask > 0
            elif mask_type == 'SCL':
                sen_mask_qa = sen_mask > 6
            else:
                raise ValueError('Mask type must be either MSK or SCL')


            # Apply mask to source TCI file
            if np.count_nonzero(sen_mask_qa) > 0:
                sen_TCI_cl_free_nan = em.mask_pixels(sen_TCI, sen_mask_qa)
                sen_TCI_cl_free_processed = np.ma.filled(sen_TCI_cl_free_nan, fill_value=nodatavalue)
            else:
                sen_TCI_c1_free_processed = sen_mask_qa
        
            
            folder = TCI_file.split("\\")[-2]
            outpath = output_dir + folder + "/" + TCI_filename
    
            # Check if directory exists
            if not os.path.isdir(output_dir + folder):
                os.mkdir(output_dir + folder)


            # Export cloud-masked TCI file
            with rio.open(outpath, 'w', **sen_TCI_meta) as outf:
                outf.write(sen_TCI_cl_free_processed)
                
        else:
            print(f'Could not find match for {mask_filename}')

# %%
source_dir = 'D:/canopy_data/pipeline-products/raw_products/SAFE_ordered_cloud_cover/'

mask_dir = 'D:/canopy_data/pipeline-products/raw_products/MSK/'

output_dir = 'D:/canopy_data/pipeline-products/cloudless_products/MSK_cloudcover_order/'

cloud_fill(source_dir, mask_dir, output_dir)
# Out:
# Mask 1 of 210
# Applying L2A_T33NTB_A013990_20191110T093408_MSK_CLDPRB_20m.jp2 to processed_T33NTB_20191110T092119_TCI_10m.jp2
# Mask 2 of 210
# Applying L2A_T33NTB_A017851_20200806T093251_MSK_CLDPRB_20m.jp2 to processed_T33NTB_20200806T092029_TCI_10m.jp2
# Mask 3 of 210
# Applying L2A_T33NTC_A023971_20200124T093439_MSK_CLDPRB_20m.jp2 to processed_T33NTC_20200124T092251_TCI_10m.jp2
# Mask 4 of 210
# Applying L2A_T33NUA_A010801_20190401T092807_MSK_CLDPRB_20m.jp2 to processed_T33NUA_20190401T090559_TCI_10m.jp2
# Mask 5 of 210
# Applying L2A_T33NUA_A015091_20200126T091912_MSK_CLDPRB_20m.jp2 to processed_T33NUA_20200126T091139_TCI_10m.jp2
# Mask 6 of 210
# Applying L2A_T33NUA_A015377_20200215T092112_MSK_CLDPRB_20m.jp2 to processed_T33NUA_20200215T091019_TCI_10m.jp2
# Mask 7 of 210
# Applying L2A_T33NUA_A022498_20191013T091824_MSK_CLDPRB_20m.jp2 to processed_T33NUA_20191013T090921_TCI_10m.jp2
# Mask 8 of 210
# Applying L2A_T33NUA_A023785_20200111T092435_MSK_CLDPRB_20m.jp2 to processed_T33NUA_20200111T091341_TCI_10m.jp2
# Mask 9 of 210
# Applying L2A_T33NUA_A024357_20200220T091348_MSK_CLDPRB_20m.jp2 to processed_T33NUA_20200220T091011_TCI_10m.jp2
# Mask 10 of 210
# Applying L2A_T33NUA_A026788_20200808T091204_MSK_CLDPRB_20m.jp2 to processed_T33NUA_20200808T090601_TCI_10m.jp2
# Mask 11 of 210
# Applying L2A_T33NUA_A026788_20200808T093036_MSK_CLDPRB_20m.jp2 to processed_T33NUA_20200808T090601_TCI_10m.jp2
# Mask 12 of 210
# Applying L2A_T33NUB_A010801_20190401T092807_MSK_CLDPRB_20m.jp2 to processed_T33NUB_20190401T090559_TCI_10m.jp2
# Mask 13 of 210
# Applying L2A_T33NUB_A010844_20190404T093457_MSK_CLDPRB_20m.jp2 to processed_T33NUB_20190404T092029_TCI_10m.jp2
# Mask 14 of 210
# Applying L2A_T33NUB_A014705_20191230T093407_MSK_CLDPRB_20m.jp2 to processed_T33NUB_20191230T092309_TCI_10m.jp2
# Mask 15 of 210
# Applying L2A_T33NUB_A015377_20200215T092112_MSK_CLDPRB_20m.jp2 to processed_T33NUB_20200215T091019_TCI_10m.jp2
# Mask 16 of 210
# Applying L2A_T33NUB_A020925_20190625T091818_MSK_CLDPRB_20m.jp2 to processed_T33NUB_20190625T090601_TCI_10m.jp2
# Mask 17 of 210
# Applying L2A_T33NUB_A023785_20200111T092435_MSK_CLDPRB_20m.jp2 to processed_T33NUB_20200111T091341_TCI_10m.jp2
# Mask 18 of 210
# Applying L2A_T33NUB_A024357_20200220T091348_MSK_CLDPRB_20m.jp2 to processed_T33NUB_20200220T091011_TCI_10m.jp2
# Mask 19 of 210
# Applying L2A_T33NUC_A010801_20190401T092807_MSK_CLDPRB_20m.jp2 to processed_T33NUC_20190401T090559_TCI_10m.jp2
# Mask 20 of 210
# Applying L2A_T33NUC_A010844_20190404T093457_MSK_CLDPRB_20m.jp2 to processed_T33NUC_20190404T092029_TCI_10m.jp2
# Mask 21 of 210
# Applying L2A_T33NUC_A014519_20191217T092124_MSK_CLDPRB_20m.jp2 to processed_T33NUC_20191217T091309_TCI_10m.jp2
# Mask 22 of 210
# Applying L2A_T33NUC_A014519_20191217T092950_MSK_CLDPRB_20m.jp2 to processed_T33NUC_20191217T091309_TCI_10m.jp2
# Mask 23 of 210
# Applying L2A_T33NUC_A014705_20191230T093407_MSK_CLDPRB_20m.jp2 to processed_T33NUC_20191230T092309_TCI_10m.jp2
# Mask 24 of 210
# Applying L2A_T33NUC_A017851_20200806T093251_MSK_CLDPRB_20m.jp2 to processed_T33NUC_20200806T092029_TCI_10m.jp2
# Mask 25 of 210
# Applying L2A_T33NUC_A023785_20200111T092435_MSK_CLDPRB_20m.jp2 to processed_T33NUC_20200111T091341_TCI_10m.jp2
# Mask 26 of 210
# Applying L2A_T33NUC_A023828_20200114T093418_MSK_CLDPRB_20m.jp2 to processed_T33NUC_20200114T092331_TCI_10m.jp2
# Mask 27 of 210
# Applying L2A_T33NUC_A023971_20200124T093439_MSK_CLDPRB_20m.jp2 to processed_T33NUC_20200124T092251_TCI_10m.jp2
# Mask 28 of 210
# Applying L2A_T33NUD_A010844_20190404T093457_MSK_CLDPRB_20m.jp2 to processed_T33NUD_20190404T092029_TCI_10m.jp2
# Mask 29 of 210
# Applying L2A_T33NUD_A023828_20200114T093418_MSK_CLDPRB_20m.jp2 to processed_T33NUD_20200114T092331_TCI_10m.jp2
# Mask 30 of 210
# Applying L2A_T33NUD_A024257_20200213T093321_MSK_CLDPRB_20m.jp2 to processed_T33NUD_20200213T092101_TCI_10m.jp2
# Mask 31 of 210
# Applying L2A_T33NUE_A010415_20190305T093720_MSK_CLDPRB_20m.jp2 to processed_T33NUE_20190305T092029_TCI_10m.jp2
# Mask 32 of 210
# Applying L2A_T33NUE_A010844_20190404T093457_MSK_CLDPRB_20m.jp2 to processed_T33NUE_20190404T092029_TCI_10m.jp2
# Mask 33 of 210
# Applying L2A_T33NUE_A014705_20191230T093407_MSK_CLDPRB_20m.jp2 to processed_T33NUE_20191230T092309_TCI_10m.jp2
# Mask 34 of 210
# Applying L2A_T33NUE_A014991_20200119T093508_MSK_CLDPRB_20m.jp2 to processed_T33NUE_20200119T092219_TCI_10m.jp2
# Mask 35 of 210
# Applying L2A_T33NUE_A015420_20200218T093533_MSK_CLDPRB_20m.jp2 to processed_T33NUE_20200218T092029_TCI_10m.jp2
# Mask 36 of 210
# Applying L2A_T33NUE_A023113_20191125T093443_MSK_CLDPRB_20m.jp2 to processed_T33NUE_20191125T092321_TCI_10m.jp2
# Mask 37 of 210
# Applying L2A_T33NUE_A023256_20191205T093444_MSK_CLDPRB_20m.jp2 to processed_T33NUE_20191205T092351_TCI_10m.jp2
# Mask 38 of 210
# Applying L2A_T33NUE_A023828_20200114T093418_MSK_CLDPRB_20m.jp2 to processed_T33NUE_20200114T092331_TCI_10m.jp2
# Mask 39 of 210
# Applying L2A_T33NUE_A024257_20200213T093321_MSK_CLDPRB_20m.jp2 to processed_T33NUE_20200213T092101_TCI_10m.jp2
# Mask 40 of 210
# Applying L2A_T33NUE_A024686_20200314T092857_MSK_CLDPRB_20m.jp2 to processed_T33NUE_20200314T092031_TCI_10m.jp2
# Mask 41 of 210
# Applying L2A_T33NVA_A014805_20200106T092711_MSK_CLDPRB_20m.jp2 to processed_T33NVA_20200106T091249_TCI_10m.jp2
# Mask 42 of 210
# Applying L2A_T33NVA_A015377_20200215T092112_MSK_CLDPRB_20m.jp2 to processed_T33NVA_20200215T091019_TCI_10m.jp2
# Mask 43 of 210
# Applying L2A_T33NVA_A020925_20190625T091818_MSK_CLDPRB_20m.jp2 to processed_T33NVA_20190625T090601_TCI_10m.jp2
# Mask 44 of 210
# Applying L2A_T33NVA_A021211_20190715T092745_MSK_CLDPRB_20m.jp2 to processed_T33NVA_20190715T090601_TCI_10m.jp2
# Mask 45 of 210
# Applying L2A_T33NVA_A022498_20191013T091824_MSK_CLDPRB_20m.jp2 to processed_T33NVA_20191013T090921_TCI_10m.jp2
# Mask 46 of 210
# Applying L2A_T33NVA_A023785_20200111T092435_MSK_CLDPRB_20m.jp2 to processed_T33NVA_20200111T091341_TCI_10m.jp2
# Mask 47 of 210
# Applying L2A_T33NVA_A024214_20200210T092430_MSK_CLDPRB_20m.jp2 to processed_T33NVA_20200210T091121_TCI_10m.jp2
# Mask 48 of 210
# Applying L2A_T33NVA_A024357_20200220T091348_MSK_CLDPRB_20m.jp2 to processed_T33NVA_20200220T091011_TCI_10m.jp2
# Mask 49 of 210
# Applying L2A_T33NVA_A026788_20200808T091204_MSK_CLDPRB_20m.jp2 to processed_T33NVA_20200808T090601_TCI_10m.jp2
# Mask 50 of 210
# Applying L2A_T33NVA_A026788_20200808T093036_MSK_CLDPRB_20m.jp2 to processed_T33NVA_20200808T090601_TCI_10m.jp2
# Mask 51 of 210
# Applying L2A_T33NVC_A010844_20190404T093457_MSK_CLDPRB_20m.jp2 to processed_T33NVC_20190404T092029_TCI_10m.jp2
# Mask 52 of 210
# Applying L2A_T33NVC_A014705_20191230T093407_MSK_CLDPRB_20m.jp2 to processed_T33NVC_20191230T092309_TCI_10m.jp2
# Mask 53 of 210
# Applying L2A_T33NVC_A014848_20200109T093700_MSK_CLDPRB_20m.jp2 to processed_T33NVC_20200109T092249_TCI_10m.jp2
# Mask 54 of 210
# Applying L2A_T33NVC_A015234_20200205T091719_MSK_CLDPRB_20m.jp2 to processed_T33NVC_20200205T091049_TCI_10m.jp2
# Mask 55 of 210
# Applying L2A_T33NVC_A015234_20200205T092942_MSK_CLDPRB_20m.jp2 to processed_T33NVC_20200205T091049_TCI_10m.jp2
# Mask 56 of 210
# Applying L2A_T33NVC_A016378_20200425T092712_MSK_CLDPRB_20m.jp2 to processed_T33NVC_20200425T090549_TCI_10m.jp2
# Mask 57 of 210
# Applying L2A_T33NVC_A020968_20190628T093625_MSK_CLDPRB_20m.jp2 to processed_T33NVC_20190628T092031_TCI_10m.jp2
# Mask 58 of 210
# Applying L2A_T33NVC_A023785_20200111T092435_MSK_CLDPRB_20m.jp2 to processed_T33NVC_20200111T091341_TCI_10m.jp2
# Mask 59 of 210
# Applying L2A_T33NVC_A023828_20200114T093418_MSK_CLDPRB_20m.jp2 to processed_T33NVC_20200114T092331_TCI_10m.jp2
# Mask 60 of 210
# Applying L2A_T33NVC_A023971_20200124T093439_MSK_CLDPRB_20m.jp2 to processed_T33NVC_20200124T092251_TCI_10m.jp2
# Mask 61 of 210
# Applying L2A_T33NVD_A014519_20191217T092124_MSK_CLDPRB_20m.jp2 to processed_T33NVD_20191217T091309_TCI_10m.jp2
# Mask 62 of 210
# Applying L2A_T33NVD_A014705_20191230T093407_MSK_CLDPRB_20m.jp2 to processed_T33NVD_20191230T092309_TCI_10m.jp2
# Mask 63 of 210
# Applying L2A_T33NVD_A015563_20200228T093509_MSK_CLDPRB_20m.jp2 to processed_T33NVD_20200228T092029_TCI_10m.jp2
# Mask 64 of 210
# Applying L2A_T33NVD_A016378_20200425T092712_MSK_CLDPRB_20m.jp2 to processed_T33NVD_20200425T090549_TCI_10m.jp2
# Mask 65 of 210
# Applying L2A_T33NVD_A016807_20200525T092642_MSK_CLDPRB_20m.jp2 to processed_T33NVD_20200525T090559_TCI_10m.jp2
# Mask 66 of 210
# Applying L2A_T33NVD_A017851_20200806T093251_MSK_CLDPRB_20m.jp2 to processed_T33NVD_20200806T092029_TCI_10m.jp2
# Mask 67 of 210
# Applying L2A_T33NVD_A019824_20190409T093304_MSK_CLDPRB_20m.jp2 to processed_T33NVD_20190409T092031_TCI_10m.jp2
# Mask 68 of 210
# Applying L2A_T33NVD_A023828_20200114T093418_MSK_CLDPRB_20m.jp2 to processed_T33NVD_20200114T092331_TCI_10m.jp2
# Mask 69 of 210
# Applying L2A_T33NVD_A024257_20200213T093321_MSK_CLDPRB_20m.jp2 to processed_T33NVD_20200213T092101_TCI_10m.jp2
# Mask 70 of 210
# Applying L2A_T33NVD_A024686_20200314T092857_MSK_CLDPRB_20m.jp2 to processed_T33NVD_20200314T092031_TCI_10m.jp2
# Mask 71 of 210
# Applying L2A_T33NWA_A015377_20200215T092112_MSK_CLDPRB_20m.jp2 to processed_T33NWA_20200215T091019_TCI_10m.jp2
# Mask 72 of 210
# Applying L2A_T33NWA_A016378_20200425T092712_MSK_CLDPRB_20m.jp2 to processed_T33NWA_20200425T090549_TCI_10m.jp2
# Mask 73 of 210
# Applying L2A_T33NWA_A017665_20200724T092637_MSK_CLDPRB_20m.jp2 to processed_T33NWA_20200724T090559_TCI_10m.jp2
# Mask 74 of 210
# Applying L2A_T33NWA_A023785_20200111T092435_MSK_CLDPRB_20m.jp2 to processed_T33NWA_20200111T091341_TCI_10m.jp2
# Mask 75 of 210
# Applying L2A_T33NWA_A024214_20200210T092430_MSK_CLDPRB_20m.jp2 to processed_T33NWA_20200210T091121_TCI_10m.jp2
# Mask 76 of 210
# Applying L2A_T33NWA_A024357_20200220T091348_MSK_CLDPRB_20m.jp2 to processed_T33NWA_20200220T091011_TCI_10m.jp2
# Mask 77 of 210
# Applying L2A_T33NWA_A025358_20200430T091954_MSK_CLDPRB_20m.jp2 to processed_T33NWA_20200430T090601_TCI_10m.jp2
# Mask 78 of 210
# Applying L2A_T33NWA_A025644_20200520T092926_MSK_CLDPRB_20m.jp2 to processed_T33NWA_20200520T090601_TCI_10m.jp2
# Mask 79 of 210
# Applying L2A_T33NWA_A026788_20200808T091204_MSK_CLDPRB_20m.jp2 to processed_T33NWA_20200808T090601_TCI_10m.jp2
# Mask 80 of 210
# Applying L2A_T33NWA_A026788_20200808T093036_MSK_CLDPRB_20m.jp2 to processed_T33NWA_20200808T090601_TCI_10m.jp2
# Mask 81 of 210
# Applying L2A_T33NWB_A010801_20190401T092807_MSK_CLDPRB_20m.jp2 to processed_T33NWB_20190401T090559_TCI_10m.jp2
# Mask 82 of 210
# Applying L2A_T33NWB_A015377_20200215T092112_MSK_CLDPRB_20m.jp2 to processed_T33NWB_20200215T091019_TCI_10m.jp2
# Mask 83 of 210
# Applying L2A_T33NWB_A015663_20200306T092559_MSK_CLDPRB_20m.jp2 to processed_T33NWB_20200306T090729_TCI_10m.jp2
# Mask 84 of 210
# Applying L2A_T33NWB_A016378_20200425T092712_MSK_CLDPRB_20m.jp2 to processed_T33NWB_20200425T090549_TCI_10m.jp2
# Mask 85 of 210
# Applying L2A_T33NWB_A022498_20191013T091824_MSK_CLDPRB_20m.jp2 to processed_T33NWB_20191013T090921_TCI_10m.jp2
# Mask 86 of 210
# Applying L2A_T33NWB_A023785_20200111T092435_MSK_CLDPRB_20m.jp2 to processed_T33NWB_20200111T091341_TCI_10m.jp2
# Mask 87 of 210
# Applying L2A_T33NWB_A024214_20200210T092430_MSK_CLDPRB_20m.jp2 to processed_T33NWB_20200210T091121_TCI_10m.jp2
# Mask 88 of 210
# Applying L2A_T33NWB_A024357_20200220T091348_MSK_CLDPRB_20m.jp2 to processed_T33NWB_20200220T091011_TCI_10m.jp2
# Mask 89 of 210
# Applying L2A_T33NWB_A024643_20200311T092034_MSK_CLDPRB_20m.jp2 to processed_T33NWB_20200311T090751_TCI_10m.jp2
# Mask 90 of 210
# Applying L2A_T33NWB_A025644_20200520T092926_MSK_CLDPRB_20m.jp2 to processed_T33NWB_20200520T090601_TCI_10m.jp2
# Mask 91 of 210
# Applying L2A_T33NXB_A016378_20200425T092712_MSK_CLDPRB_20m.jp2 to processed_T33NXB_20200425T090549_TCI_10m.jp2
# Mask 92 of 210
# Applying L2A_T33NXB_A016764_20200522T091542_MSK_CLDPRB_20m.jp2 to processed_T33NXB_20200522T085559_TCI_10m.jp2
# Mask 93 of 210
# Applying L2A_T33NXB_A016807_20200525T092642_MSK_CLDPRB_20m.jp2 to processed_T33NXB_20200525T090559_TCI_10m.jp2
# Mask 94 of 210
# Applying L2A_T33NXB_A017908_20200810T091451_MSK_CLDPRB_20m.jp2 to processed_T33NXB_20200810T085559_TCI_10m.jp2
# Mask 95 of 210
# Applying L2A_T33NXB_A025029_20200407T091315_MSK_CLDPRB_20m.jp2 to processed_T33NXB_20200407T085551_TCI_10m.jp2
# Mask 96 of 210
# Applying L2A_T33NXB_A025072_20200410T092731_MSK_CLDPRB_20m.jp2 to processed_T33NXB_20200410T090551_TCI_10m.jp2
# Mask 97 of 210
# Applying L2A_T33NXB_A025601_20200517T091331_MSK_CLDPRB_20m.jp2 to processed_T33NXB_20200517T085601_TCI_10m.jp2
# Mask 98 of 210
# Applying L2A_T33NXB_A025644_20200520T092926_MSK_CLDPRB_20m.jp2 to processed_T33NXB_20200520T090601_TCI_10m.jp2
# Mask 99 of 210
# Applying L2A_T33NXB_A025930_20200609T092746_MSK_CLDPRB_20m.jp2 to processed_T33NXB_20200609T090601_TCI_10m.jp2
# Mask 100 of 210
# Applying L2A_T33NXB_A026788_20200808T091204_MSK_CLDPRB_20m.jp2 to processed_T33NXB_20200808T090601_TCI_10m.jp2
# Mask 101 of 210
# Applying L2A_T33NYC_A015663_20200306T092559_MSK_CLDPRB_20m.jp2 to processed_T33NYC_20200306T090729_TCI_10m.jp2
# Mask 102 of 210
# Applying L2A_T33NYC_A016807_20200525T092642_MSK_CLDPRB_20m.jp2 to processed_T33NYC_20200525T090559_TCI_10m.jp2
# Mask 103 of 210
# Applying L2A_T33NYC_A017236_20200624T092728_MSK_CLDPRB_20m.jp2 to processed_T33NYC_20200624T090559_TCI_10m.jp2
# Mask 104 of 210
# Applying L2A_T33NYC_A024929_20200331T092819_MSK_CLDPRB_20m.jp2 to processed_T33NYC_20200331T090551_TCI_10m.jp2
# Mask 105 of 210
# Applying L2A_T33NYC_A025029_20200407T091315_MSK_CLDPRB_20m.jp2 to processed_T33NYC_20200407T085551_TCI_10m.jp2
# Mask 106 of 210
# Applying L2A_T33NYC_A025072_20200410T092731_MSK_CLDPRB_20m.jp2 to processed_T33NYC_20200410T090551_TCI_10m.jp2
# Mask 107 of 210
# Applying L2A_T33NYC_A025501_20200510T092755_MSK_CLDPRB_20m.jp2 to processed_T33NYC_20200510T090601_TCI_10m.jp2
# Mask 108 of 210
# Applying L2A_T33NYC_A025601_20200517T091331_MSK_CLDPRB_20m.jp2 to processed_T33NYC_20200517T085601_TCI_10m.jp2
# Mask 109 of 210
# Applying L2A_T33NYC_A025644_20200520T092926_MSK_CLDPRB_20m.jp2 to processed_T33NYC_20200520T090601_TCI_10m.jp2
# Mask 110 of 210
# Applying L2A_T33NYC_A025930_20200609T092746_MSK_CLDPRB_20m.jp2 to processed_T33NYC_20200609T090601_TCI_10m.jp2
# Mask 111 of 210
# Applying L2A_T33NYD_A015906_20200323T091341_MSK_CLDPRB_20m.jp2 to processed_T33NYD_20200323T085619_TCI_10m.jp2
# Mask 112 of 210
# Applying L2A_T33NYD_A016378_20200425T092712_MSK_CLDPRB_20m.jp2 to processed_T33NYD_20200425T090549_TCI_10m.jp2
# Mask 113 of 210
# Applying L2A_T33NYD_A016807_20200525T092642_MSK_CLDPRB_20m.jp2 to processed_T33NYD_20200525T090559_TCI_10m.jp2
# Mask 114 of 210
# Applying L2A_T33NYD_A017765_20200731T091349_MSK_CLDPRB_20m.jp2 to processed_T33NYD_20200731T085559_TCI_10m.jp2
# Mask 115 of 210
# Applying L2A_T33NYD_A025029_20200407T091315_MSK_CLDPRB_20m.jp2 to processed_T33NYD_20200407T085551_TCI_10m.jp2
# Mask 116 of 210
# Applying L2A_T33NYD_A025072_20200410T092731_MSK_CLDPRB_20m.jp2 to processed_T33NYD_20200410T090551_TCI_10m.jp2
# Mask 117 of 210
# Applying L2A_T33NYD_A025458_20200507T091112_MSK_CLDPRB_20m.jp2 to processed_T33NYD_20200507T085601_TCI_10m.jp2
# Mask 118 of 210
# Applying L2A_T33NYD_A025501_20200510T092755_MSK_CLDPRB_20m.jp2 to processed_T33NYD_20200510T090601_TCI_10m.jp2
# Mask 119 of 210
# Applying L2A_T33NYD_A025601_20200517T091331_MSK_CLDPRB_20m.jp2 to processed_T33NYD_20200517T085601_TCI_10m.jp2
# Mask 120 of 210
# Applying L2A_T33NYD_A025644_20200520T092926_MSK_CLDPRB_20m.jp2 to processed_T33NYD_20200520T090601_TCI_10m.jp2
# Mask 121 of 210
# Applying L2A_T33NZD_A015191_20200202T091751_MSK_CLDPRB_20m.jp2 to processed_T33NZD_20200202T090059_TCI_10m.jp2
# Mask 122 of 210
# Applying L2A_T33NZD_A015334_20200212T091359_MSK_CLDPRB_20m.jp2 to processed_T33NZD_20200212T090019_TCI_10m.jp2
# Mask 123 of 210
# Applying L2A_T33NZD_A015763_20200313T091049_MSK_CLDPRB_20m.jp2 to processed_T33NZD_20200313T085709_TCI_10m.jp2
# Mask 124 of 210
# Applying L2A_T33NZD_A015906_20200323T091341_MSK_CLDPRB_20m.jp2 to processed_T33NZD_20200323T085619_TCI_10m.jp2
# Mask 125 of 210
# Applying L2A_T33NZD_A016621_20200512T090705_MSK_CLDPRB_20m.jp2 to processed_T33NZD_20200512T085559_TCI_10m.jp2
# Mask 126 of 210
# Applying L2A_T33NZD_A017622_20200721T091544_MSK_CLDPRB_20m.jp2 to processed_T33NZD_20200721T085559_TCI_10m.jp2
# Mask 127 of 210
# Applying L2A_T33NZD_A017765_20200731T091349_MSK_CLDPRB_20m.jp2 to processed_T33NZD_20200731T085559_TCI_10m.jp2
# Mask 128 of 210
# Applying L2A_T33NZD_A024171_20200207T091251_MSK_CLDPRB_20m.jp2 to processed_T33NZD_20200207T090131_TCI_10m.jp2
# Mask 129 of 210
# Applying L2A_T33NZD_A025029_20200407T091315_MSK_CLDPRB_20m.jp2 to processed_T33NZD_20200407T085551_TCI_10m.jp2
# Mask 130 of 210
# Applying L2A_T33NZD_A025601_20200517T091331_MSK_CLDPRB_20m.jp2 to processed_T33NZD_20200517T085601_TCI_10m.jp2
# Mask 131 of 210
# Applying L2A_T34MBB_A016721_20200519T090201_MSK_CLDPRB_20m.jp2 to processed_T34MBB_20200519T084559_TCI_10m.jp2
# Mask 132 of 210
# Applying L2A_T34MBB_A017436_20200708T090330_MSK_CLDPRB_20m.jp2 to processed_T34MBB_20200708T084559_TCI_10m.jp2
# Mask 133 of 210
# Applying L2A_T34MBB_A017722_20200728T085918_MSK_CLDPRB_20m.jp2 to processed_T34MBB_20200728T084559_TCI_10m.jp2
# Mask 134 of 210
# Applying L2A_T34MBB_A017865_20200807T090515_MSK_CLDPRB_20m.jp2 to processed_T34MBB_20200807T084559_TCI_10m.jp2
# Mask 135 of 210
# Applying L2A_T34MBB_A025415_20200504T090346_MSK_CLDPRB_20m.jp2 to processed_T34MBB_20200504T084601_TCI_10m.jp2
# Mask 136 of 210
# Applying L2A_T34MBB_A025701_20200524T090953_MSK_CLDPRB_20m.jp2 to processed_T34MBB_20200524T084601_TCI_10m.jp2
# Mask 137 of 210
# Applying L2A_T34MBB_A025987_20200613T090356_MSK_CLDPRB_20m.jp2 to processed_T34MBB_20200613T084611_TCI_10m.jp2
# Mask 138 of 210
# Applying L2A_T34MBB_A026273_20200703T090351_MSK_CLDPRB_20m.jp2 to processed_T34MBB_20200703T084601_TCI_10m.jp2
# Mask 139 of 210
# Applying L2A_T34MBB_A026559_20200723T090956_MSK_CLDPRB_20m.jp2 to processed_T34MBB_20200723T084601_TCI_10m.jp2
# Mask 140 of 210
# Applying L2A_T34MBB_A026845_20200812T090428_MSK_CLDPRB_20m.jp2 to processed_T34MBB_20200812T084601_TCI_10m.jp2
# Mask 141 of 210
# Applying L2A_T34MBC_A017336_20200701T091034_MSK_CLDPRB_20m.jp2 to processed_T34MBC_20200701T085559_TCI_10m.jp2
# Mask 142 of 210
# Applying L2A_T34MBC_A017436_20200708T090330_MSK_CLDPRB_20m.jp2 to processed_T34MBC_20200708T084559_TCI_10m.jp2
# Mask 143 of 210
# Applying L2A_T34MBC_A017722_20200728T085918_MSK_CLDPRB_20m.jp2 to processed_T34MBC_20200728T084559_TCI_10m.jp2
# Mask 144 of 210
# Applying L2A_T34MBC_A017765_20200731T091349_MSK_CLDPRB_20m.jp2 to processed_T34MBC_20200731T085559_TCI_10m.jp2
# Mask 145 of 210
# Applying L2A_T34MBC_A017865_20200807T090515_MSK_CLDPRB_20m.jp2 to processed_T34MBC_20200807T084559_TCI_10m.jp2
# Mask 146 of 210
# Applying L2A_T34MBC_A017908_20200810T091451_MSK_CLDPRB_20m.jp2 to processed_T34MBC_20200810T085559_TCI_10m.jp2
# Mask 147 of 210
# Applying L2A_T34MBC_A026273_20200703T090351_MSK_CLDPRB_20m.jp2 to processed_T34MBC_20200703T084601_TCI_10m.jp2
# Mask 148 of 210
# Applying L2A_T34MBC_A026745_20200805T091544_MSK_CLDPRB_20m.jp2 to processed_T34MBC_20200805T085601_TCI_10m.jp2
# Mask 149 of 210
# Applying L2A_T34MBC_A026845_20200812T090428_MSK_CLDPRB_20m.jp2 to processed_T34MBC_20200812T084601_TCI_10m.jp2
# Mask 150 of 210
# Applying L2A_T34MBC_A027031_20200825T092011_MSK_CLDPRB_20m.jp2 to processed_T34MBC_20200825T085601_TCI_10m.jp2
# Mask 151 of 210
# Applying L2A_T34MCB_A013861_20191101T090810_MSK_CLDPRB_20m.jp2 to processed_T34MCB_20191101T085019_TCI_10m.jp2
# Mask 152 of 210
# Applying L2A_T34MCB_A014576_20191221T090209_MSK_CLDPRB_20m.jp2 to processed_T34MCB_20191221T085259_TCI_10m.jp2
# Mask 153 of 210
# Applying L2A_T34MCB_A015577_20200229T091048_MSK_CLDPRB_20m.jp2 to processed_T34MCB_20200229T084809_TCI_10m.jp2
# Mask 154 of 210
# Applying L2A_T34MCB_A016435_20200429T085926_MSK_CLDPRB_20m.jp2 to processed_T34MCB_20200429T084559_TCI_10m.jp2
# Mask 155 of 210
# Applying L2A_T34MCB_A017722_20200728T085918_MSK_CLDPRB_20m.jp2 to processed_T34MCB_20200728T084559_TCI_10m.jp2
# Mask 156 of 210
# Applying L2A_T34MCB_A022412_20191007T090219_MSK_CLDPRB_20m.jp2 to processed_T34MCB_20191007T084831_TCI_10m.jp2
# Mask 157 of 210
# Applying L2A_T34MCB_A025272_20200424T091025_MSK_CLDPRB_20m.jp2 to processed_T34MCB_20200424T084601_TCI_10m.jp2
# Mask 158 of 210
# Applying L2A_T34MCB_A025415_20200504T090346_MSK_CLDPRB_20m.jp2 to processed_T34MCB_20200504T084601_TCI_10m.jp2
# Mask 159 of 210
# Applying L2A_T34MCB_A025987_20200613T090356_MSK_CLDPRB_20m.jp2 to processed_T34MCB_20200613T084611_TCI_10m.jp2
# Mask 160 of 210
# Applying L2A_T34MCB_A026845_20200812T090428_MSK_CLDPRB_20m.jp2 to processed_T34MCB_20200812T084601_TCI_10m.jp2
# Mask 161 of 210
# Applying L2A_T34NDF_A015577_20200229T085821_MSK_CLDPRB_20m.jp2 to processed_T34NDF_20200229T084809_TCI_10m.jp2
# Mask 162 of 210
# Applying L2A_T34NDF_A015720_20200310T090902_MSK_CLDPRB_20m.jp2 to processed_T34NDF_20200310T084709_TCI_10m.jp2
# Mask 163 of 210
# Applying L2A_T34NDF_A017436_20200708T090330_MSK_CLDPRB_20m.jp2 to processed_T34NDF_20200708T084559_TCI_10m.jp2
# Mask 164 of 210
# Applying L2A_T34NDF_A017865_20200807T090515_MSK_CLDPRB_20m.jp2 to processed_T34NDF_20200807T084559_TCI_10m.jp2
# Mask 165 of 210
# Applying L2A_T34NDF_A024271_20200214T090049_MSK_CLDPRB_20m.jp2 to processed_T34NDF_20200214T085041_TCI_10m.jp2
# Mask 166 of 210
# Applying L2A_T34NDF_A024557_20200305T090842_MSK_CLDPRB_20m.jp2 to processed_T34NDF_20200305T084831_TCI_10m.jp2
# Mask 167 of 210
# Applying L2A_T34NDF_A025129_20200414T090349_MSK_CLDPRB_20m.jp2 to processed_T34NDF_20200414T084601_TCI_10m.jp2
# Mask 168 of 210
# Applying L2A_T34NDF_A025272_20200424T090055_MSK_CLDPRB_20m.jp2 to processed_T34NDF_20200424T084601_TCI_10m.jp2
# Mask 169 of 210
# Applying L2A_T34NDF_A025272_20200424T091025_MSK_CLDPRB_20m.jp2 to processed_T34NDF_20200424T084601_TCI_10m.jp2
# Mask 170 of 210
# Applying L2A_T34NDF_A026273_20200703T090351_MSK_CLDPRB_20m.jp2 to processed_T34NDF_20200703T084601_TCI_10m.jp2
# Mask 171 of 210
# Applying L2A_T34NDH_A014719_20191231T090759_MSK_CLDPRB_20m.jp2 to processed_T34NDH_20191231T085259_TCI_10m.jp2
# Mask 172 of 210
# Applying L2A_T34NDH_A015577_20200229T085821_MSK_CLDPRB_20m.jp2 to processed_T34NDH_20200229T084809_TCI_10m.jp2
# Mask 173 of 210
# Applying L2A_T34NDH_A015720_20200310T090902_MSK_CLDPRB_20m.jp2 to processed_T34NDH_20200310T084709_TCI_10m.jp2
# Mask 174 of 210
# Applying L2A_T34NDH_A023127_20191126T085522_MSK_CLDPRB_20m.jp2 to processed_T34NDH_20191126T085311_TCI_10m.jp2
# Mask 175 of 210
# Applying L2A_T34NDH_A023842_20200115T090410_MSK_CLDPRB_20m.jp2 to processed_T34NDH_20200115T085311_TCI_10m.jp2
# Mask 176 of 210
# Applying L2A_T34NDH_A023985_20200125T085333_MSK_CLDPRB_20m.jp2 to processed_T34NDH_20200125T085241_TCI_10m.jp2
# Mask 177 of 210
# Applying L2A_T34NDH_A024128_20200204T090408_MSK_CLDPRB_20m.jp2 to processed_T34NDH_20200204T085141_TCI_10m.jp2
# Mask 178 of 210
# Applying L2A_T34NDH_A024271_20200214T090049_MSK_CLDPRB_20m.jp2 to processed_T34NDH_20200214T085041_TCI_10m.jp2
# Mask 179 of 210
# Applying L2A_T34NDH_A024557_20200305T090842_MSK_CLDPRB_20m.jp2 to processed_T34NDH_20200305T084831_TCI_10m.jp2
# Mask 180 of 210
# Applying L2A_T34NDH_A025129_20200414T090349_MSK_CLDPRB_20m.jp2 to processed_T34NDH_20200414T084601_TCI_10m.jp2
# Mask 181 of 210
# Applying L2A_T34NEF_A015720_20200310T090902_MSK_CLDPRB_20m.jp2 to processed_T34NEF_20200310T084709_TCI_10m.jp2
# Mask 182 of 210
# Applying L2A_T34NEF_A017436_20200708T090330_MSK_CLDPRB_20m.jp2 to processed_T34NEF_20200708T084559_TCI_10m.jp2
# Mask 183 of 210
# Applying L2A_T34NEF_A017865_20200807T090515_MSK_CLDPRB_20m.jp2 to processed_T34NEF_20200807T084559_TCI_10m.jp2
# Mask 184 of 210
# Applying L2A_T34NEF_A017965_20200814T085123_MSK_CLDPRB_20m.jp2 to processed_T34NEF_20200814T083609_TCI_10m.jp2
# Mask 185 of 210
# Applying L2A_T34NEF_A024557_20200305T090842_MSK_CLDPRB_20m.jp2 to processed_T34NEF_20200305T084831_TCI_10m.jp2
# Mask 186 of 210
# Applying L2A_T34NEF_A025129_20200414T090349_MSK_CLDPRB_20m.jp2 to processed_T34NEF_20200414T084601_TCI_10m.jp2
# Mask 187 of 210
# Applying L2A_T34NEF_A025272_20200424T090055_MSK_CLDPRB_20m.jp2 to processed_T34NEF_20200424T084601_TCI_10m.jp2
# Mask 188 of 210
# Applying L2A_T34NEF_A025415_20200504T090346_MSK_CLDPRB_20m.jp2 to processed_T34NEF_20200504T084601_TCI_10m.jp2
# Mask 189 of 210
# Applying L2A_T34NEF_A026273_20200703T090351_MSK_CLDPRB_20m.jp2 to processed_T34NEF_20200703T084601_TCI_10m.jp2
# Mask 190 of 210
# Applying L2A_T34NEF_A026945_20200819T084315_MSK_CLDPRB_20m.jp2 to processed_T34NEF_20200819T083611_TCI_10m.jp2
# Mask 191 of 210
# Applying L2A_T34NFG_A014390_20191208T085450_MSK_CLDPRB_20m.jp2 to processed_T34NFG_20191208T084239_TCI_10m.jp2
# Mask 192 of 210
# Applying L2A_T34NFG_A014676_20191228T085358_MSK_CLDPRB_20m.jp2 to processed_T34NFG_20191228T084249_TCI_10m.jp2
# Mask 193 of 210
# Applying L2A_T34NFG_A015105_20200127T085331_MSK_CLDPRB_20m.jp2 to processed_T34NFG_20200127T084119_TCI_10m.jp2
# Mask 194 of 210
# Applying L2A_T34NFG_A015248_20200206T085650_MSK_CLDPRB_20m.jp2 to processed_T34NFG_20200206T084029_TCI_10m.jp2
# Mask 195 of 210
# Applying L2A_T34NFG_A015963_20200327T085848_MSK_CLDPRB_20m.jp2 to processed_T34NFG_20200327T083559_TCI_10m.jp2
# Mask 196 of 210
# Applying L2A_T34NFG_A016249_20200416T084905_MSK_CLDPRB_20m.jp2 to processed_T34NFG_20200416T083559_TCI_10m.jp2
# Mask 197 of 210
# Applying L2A_T34NFG_A016535_20200506T085121_MSK_CLDPRB_20m.jp2 to processed_T34NFG_20200506T083559_TCI_10m.jp2
# Mask 198 of 210
# Applying L2A_T34NFG_A023513_20191223T085353_MSK_CLDPRB_20m.jp2 to processed_T34NFG_20191223T084351_TCI_10m.jp2
# Mask 199 of 210
# Applying L2A_T34NFG_A024228_20200211T085547_MSK_CLDPRB_20m.jp2 to processed_T34NFG_20200211T084101_TCI_10m.jp2
# Mask 200 of 210
# Applying L2A_T34NFG_A024514_20200302T085853_MSK_CLDPRB_20m.jp2 to processed_T34NFG_20200302T083841_TCI_10m.jp2
# Mask 201 of 210
# Applying L2A_T34NFH_A013961_20191108T084733_MSK_CLDPRB_20m.jp2 to processed_T34NFH_20191108T084059_TCI_10m.jp2
# Mask 202 of 210
# Applying L2A_T34NFH_A014390_20191208T085450_MSK_CLDPRB_20m.jp2 to processed_T34NFH_20191208T084239_TCI_10m.jp2
# Mask 203 of 210
# Applying L2A_T34NFH_A014533_20191218T084754_MSK_CLDPRB_20m.jp2 to processed_T34NFH_20191218T084249_TCI_10m.jp2
# Mask 204 of 210
# Applying L2A_T34NFH_A014676_20191228T085358_MSK_CLDPRB_20m.jp2 to processed_T34NFH_20191228T084249_TCI_10m.jp2
# Mask 205 of 210
# Applying L2A_T34NFH_A015105_20200127T085331_MSK_CLDPRB_20m.jp2 to processed_T34NFH_20200127T084119_TCI_10m.jp2
# Mask 206 of 210
# Applying L2A_T34NFH_A015963_20200327T085848_MSK_CLDPRB_20m.jp2 to processed_T34NFH_20200327T083559_TCI_10m.jp2
# Mask 207 of 210
# Applying L2A_T34NFH_A017107_20200615T084829_MSK_CLDPRB_20m.jp2 to processed_T34NFH_20200615T083559_TCI_10m.jp2
# Mask 208 of 210
# Applying L2A_T34NFH_A021511_20190805T085826_MSK_CLDPRB_20m.jp2 to processed_T34NFH_20190805T083601_TCI_10m.jp2
# Mask 209 of 210
# Applying L2A_T34NFH_A022798_20191103T085335_MSK_CLDPRB_20m.jp2 to processed_T34NFH_20191103T084121_TCI_10m.jp2
# Mask 210 of 210
# Applying L2A_T34NFH_A024228_20200211T085547_MSK_CLDPRB_20m.jp2 to processed_T34NFH_20200211T084101_TCI_10m.jp2
