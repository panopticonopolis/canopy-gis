# %%
import rasterio as rio
import numpy as np
import earthpy.plot as ep
import matplotlib.pyplot as plt
from rasterio.plot import plotting_extent

# %%
rast_path = "//Users/purgatorid/Downloads/S2_CloudFree_dynamic_date_range_v4_secondary_sort_using_area_full_band_output_1_dynamic_date_range_v4_secondary_sort_using_area_full_band_output_Dec__8_14_58_59_2020.tif"

with rio.open(rast_path) as rast_src:
    rast = rast_src.read(masked=False)
    rast_extent = plotting_extent(rast_src)

# %%
# ep.plot_rgb(rast,
#             rgb=[3, 2, 1],
#             extent=rast_extent)


plt.imshow(rast[27])

# %%
number_list = rast[27]

(unique, counts) = np.unique(number_list, return_counts=True)

# %%
unique[0]
# Out:
# -0.22686568

# %%
counts
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
ep.plot_bands(number_list, cmap="RdYlGn", cols=1, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %%
plt.show()
